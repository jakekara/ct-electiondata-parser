# %%
import pandas as pd
import json
import os

# %%
index = json.loads(open("data/index.json").read())
print ("These are the elections...")
for e in index:
    print ("%s\t%s" % (e['ID'],e["Name"]))
# Out:
# These are the elections...
# 35	02/26/2019 -- Special Election 3rd, 5th & 6th Senatorial Districts and 39th &
# 31	11/06/2018 -- November 2018 State Election
# 33	08/14/2018 -- August 2018 Democratic Primary
# 34	08/14/2018 -- August 2018 Republican Primary
# 18	11/07/2017 -- November 2017 Municipal Election
# 24	04/25/2017 -- Special Election Assembly Districts 7th & 68th
# 1	11/08/2016 -- November Presidential Election

# %%
def get_path(e_id, version=None):
    path = os.path.join("data", str(e_id))
    
    if version is not None:
        path = os.path.join("data", str(e_id), version)

    return path

def get_election_data(e_id, version=None):
    
    dir_path = get_path(e_id, version)
    
    return {
        "election_data":json.loads(open(os.path.join(dir_path,"Electiondata.json")).read()),
        "lookup_data":json.loads(open(os.path.join(dir_path,"Lookupdata.json")).read())
    }
        

general_2018 = get_election_data(31)
general_2018.keys()
# Out:
# dict_keys(['election_data', 'lookup_data'])

# %%
general_2018["lookup_data"].keys()
# Out:
# dict_keys(['election', 'townIds', 'counties', 'countyTowns', 'pollingplaceIds', 'townPollingPlaces', 'officeList', 'partyIds', 'townParties', 'candidateIds'])

# %%
general_2018["election_data"].keys()
# Out:
# dict_keys(['election', 'voterTurnout', 'townStatus', 'townVotes', 'stateVotes', 'reports', 'districts', 'officePrecincts'])

# %%
general_2018["election_data"]["election"]
# Out:
# {'ID': '31',
#  'BC': '1,421,953',
#  'PR': '744 of 744 (100%)',
#  'RV': '2,181,197',
#  'T': '169 of 169',
#  'PT': '0 of 169',
#  'TO': '65.19'}

# %%
general_2018["election_data"]["reports"]
# Out:
# {'IR': 'True', 'IO': 'True'}

# %%
general_2018["lookup_data"]["partyIds"]
# Out:
# {'1': {'CD': 'D', 'NM': 'Democratic Party', 'P': '250'},
#  '2': {'CD': 'C', 'NM': 'Conservative Party', 'P': '226'},
#  '3': {'CD': 'IND', 'NM': 'Independent Party', 'P': '204'},
#  '4': {'CD': 'NL', 'NM': 'Natural Law Party', 'P': '181'},
#  '5': {'CD': 'INDP', 'NM': 'Independance Party', 'P': '159'},
#  '6': {'CD': 'R', 'NM': 'Republican Party', 'P': '135'},
#  '7': {'CD': 'G', 'NM': 'Green Party', 'P': '112'},
#  '8': {'CD': 'LI', 'NM': 'Libertarian Party', 'P': '89'},
#  '9': {'CD': 'RE', 'NM': 'Reform Party', 'P': '65'},
#  '12': {'CD': 'WF', 'NM': 'Working Families Party', 'P': '22'},
#  '15': {'CD': 'PC', 'NM': 'Petitioning Candidate', 'P': '0'},
#  '1026': {'CD': 'WI', 'NM': 'Write In', 'P': '274'},
#  '1045': {'CD': 'GFCT', 'NM': 'Griebel Frank for CT Party', 'P': '0'},
#  '1046': {'CD': 'ACL', 'NM': 'Amigo Constitution Liberty Party', 'P': '0'}}

# %%
general_2018["lookup_data"]["election"]
# Out:
# {'ID': '31',
#  'NM': '11/06/2018 -- November 2018 State Election',
#  'DT': '11/06/2018',
#  'ET': 'G',
#  'EC': 'SE',
#  'P': '',
#  'DNM': 'November 2018 State Election'}

# %%
def set_cache_val(e_data, key, val):
    
    if "__CACHE" not in e_data:
        e_data["__CACHE"] = {}
    
    e_data["__CACHE"][key] = val
    
def get_cache_val(e_data, key):
    
    try:
        return e_data["__CACHE"][key]
    except:
        return 
    

print(get_cache_val(general_2018, "LOL"))
set_cache_val(general_2018, "LOL", "123")
print(get_cache_val(general_2018, "LOL"))
# Out:
# None
# 123

# %%
def get_party_name(e_data, party_id):
    
    ck = "party_id:%s" % party_id
    cv = get_cache_val(e_data, ck)
    if cv is not None: return cv
        
    try:
        ret = e_data["lookup_data"]["partyIds"][str(party_id)]["NM"]
    except:
        ret = None
        
    set_cache_val(e_data, ck, ret)
    
    return ret

get_party_name(general_2018, 1)
# Out:
# 'Democratic Party'

# %%
general_2018["lookup_data"]["candidateIds"]
# Out:
# {'8701': {'NM': 'Caitlin Riley',
#   'LN': 'Riley',
#   'FN': 'Caitlin',
#   'MN': '',
#   'P': '1',
#   'AD': '15 Winthrop Hill Road, Ivoryton, CT-06442',
#   'CO': '1'},
#  '8708': {'NM': 'Thomas Maffeo',
#   'LN': 'Maffeo',
#   'FN': 'Thomas',
#   'MN': '',
#   'P': '1',
#   'AD': '7 Ford Rd, Ansonia, CT-06401',
#   'CO': '0'},
#  '8710': {'NM': 'Kevin T. McCarthy',
#   'LN': 'McCarthy',
#   'FN': 'Kevin',
#   'MN': 'T.',
#   'P': '1',
#   'AD': '436 Bebbington Rd, Ashford, CT-06278',
#   'CO': '0'},
#  '8711': {'NM': 'Colleen DePercio',
#   'LN': 'DePercio',
#   'FN': 'Colleen',
#   'MN': '',
#   'P': '6',
#   'AD': '136 Moon Rd, Ashford, CT-06278',
#   'CO': '0'},
#  '8712': {'NM': 'Susan Wasik',
#   'LN': 'Wasik',
#   'FN': 'Susan',
#   'MN': '',
#   'P': '6',
#   'AD': '60 Magnolia Ln, East Berlin, CT-06023',
#   'CO': '0'},
#  '8713': {'NM': 'Christy Miano',
#   'LN': 'Miano',
#   'FN': 'Christy',
#   'MN': '',
#   'P': '1',
#   'AD': '19 Bayberry Circle, Kensington, CT-06037',
#   'CO': '0'},
#  '8714': {'NM': 'Allyson Rogers',
#   'LN': 'Rogers',
#   'FN': 'Allyson',
#   'MN': '',
#   'P': '1',
#   'AD': '10 Old Fairwood Rd Ext, Bethany, CT-06524',
#   'CO': '0'},
#  '8715': {'NM': 'Nancy J. Ryan',
#   'LN': 'Ryan',
#   'FN': 'Nancy',
#   'MN': 'J.',
#   'P': '1',
#   'AD': '25 Walnut Hill Rd., Bethel, CT-06801',
#   'CO': '0'},
#  '8716': {'NM': 'Sharon R. Dexler',
#   'LN': 'Dexler',
#   'FN': 'Sharon',
#   'MN': 'R',
#   'P': '1',
#   'AD': '195 Oliver Way, Bloomfield, CT-06002',
#   'CO': '0'},
#  '8717': {'NM': 'Robert W. Ike',
#   'LN': 'Ike',
#   'FN': 'Robert',
#   'MN': 'W',
#   'P': '6',
#   'AD': '90 Darby St, Bloomfield, CT-06002',
#   'CO': '0'},
#  '8718': {'NM': 'Daniel J. Hally',
#   'LN': 'Hally',
#   'FN': 'Daniel',
#   'MN': 'J',
#   'P': '1',
#   'AD': '122 Red Hill Rd, Branford, CT-06405',
#   'CO': '0'},
#  '8719': {'NM': 'Marion E Burkard',
#   'LN': 'Burkard',
#   'FN': 'Marion',
#   'MN': 'E',
#   'P': '6',
#   'AD': '20 Riverside Dr, Branford, CT-06405',
#   'CO': '0'},
#  '8720': {'NM': 'Linda A Grace',
#   'LN': 'Grace',
#   'FN': 'Linda',
#   'MN': 'A',
#   'P': '6',
#   'AD': '793 Broadbridge Rd., Bridgeport, CT-06610',
#   'CO': '0'},
#  '8721': {'NM': 'Santa I Ayala',
#   'LN': 'Ayala',
#   'FN': 'Santa',
#   'MN': 'I',
#   'P': '1',
#   'AD': '194 Marigold Ave., Bridgeport, CT-06606',
#   'CO': '0'},
#  '8722': {'NM': 'Margaret Judith Sullivan',
#   'LN': 'Sullivan',
#   'FN': 'Margaret',
#   'MN': 'Judith',
#   'P': '1',
#   'AD': '6 East Sarah Sanford Rd, PO Box 304, Bridgewater, CT-06752-0304',
#   'CO': '0'},
#  '8723': {'NM': 'Susan L. Patrick',
#   'LN': 'Patrick',
#   'FN': 'Susan',
#   'MN': 'L',
#   'P': '6',
#   'AD': '169 Christian St, Bridgewater, CT-06752',
#   'CO': '0'},
#  '8724': {'NM': 'Barbara MacFadyen',
#   'LN': 'MacFadyen',
#   'FN': 'Barbara',
#   'MN': '',
#   'P': '6',
#   'AD': '49 Cedar Ln, Bozrah, CT-06334',
#   'CO': '0'},
#  '8725': {'NM': 'Sharon M Krawiecki',
#   'LN': 'Krawiecki',
#   'FN': 'Sharon',
#   'MN': '',
#   'P': '6',
#   'AD': '203 Pinehurst Rd, Bristol, CT-06010',
#   'CO': '0'},
#  '8726': {'NM': 'Kevin McCauley',
#   'LN': 'McCauley',
#   'FN': 'Kevin',
#   'MN': '',
#   'P': '1',
#   'AD': '19 Spring St, Bristol, CT-06010',
#   'CO': '0'},
#  '8727': {'NM': 'Katlyn Gugliotti',
#   'LN': 'Gugliotti',
#   'FN': 'Katlyn',
#   'MN': '',
#   'P': '1',
#   'AD': '18 Providence Rd, Brooklyn, CT-06234',
#   'CO': '0'},
#  '8728': {'NM': 'Beverly Jackson',
#   'LN': 'Jackson',
#   'FN': 'Beverly',
#   'MN': '',
#   'P': '1',
#   'AD': '1 West Woods Rd, Burlington, CT-06013',
#   'CO': '0'},
#  '8729': {'NM': 'Linda Sangermano',
#   'LN': 'Sangermano',
#   'FN': 'Linda',
#   'MN': '',
#   'P': '6',
#   'AD': '51 Depot Rd, Canterbury, CT-06331',
#   'CO': '0'},
#  '8730': {'NM': 'Eugene V Boomer Jr',
#   'LN': 'Boomer Jr',
#   'FN': 'Eugene',
#   'MN': 'V',
#   'P': '6',
#   'AD': '137 Bedlam Rd, Chaplin, CT-06235',
#   'CO': '0'},
#  '8731': {'NM': 'Bruce J Raymond',
#   'LN': 'Raymond',
#   'FN': 'Bruce',
#   'MN': 'J',
#   'P': '1',
#   'AD': '35 Chaplin St, Chaplin, CT-06235',
#   'CO': '0'},
#  '8732': {'NM': 'Susan D Pappas',
#   'LN': 'Pappas',
#   'FN': 'Susan',
#   'MN': 'D',
#   'P': '6',
#   'AD': '133 Spring St, Cheshire, CT-06410',
#   'CO': '0'},
#  '8733': {'NM': 'Thomas Smith',
#   'LN': 'Smith',
#   'FN': 'Thomas',
#   'MN': '',
#   'P': '1',
#   'AD': '37 Wallingford Rd, Cheshire, CT-06410',
#   'CO': '0'},
#  '8734': {'NM': 'Leslie Ann Holbrook',
#   'LN': 'Holbrook',
#   'FN': 'Leslie',
#   'MN': 'Ann',
#   'P': '1',
#   'AD': '31 Spring St, Chester, CT-06412',
#   'CO': '0'},
#  '8735': {'NM': 'Tracey Ohaus',
#   'LN': 'Ohaus',
#   'FN': 'Tracey',
#   'MN': '',
#   'P': '6',
#   'AD': '91 Goose Hill Rd, Chester, CT-06412',
#   'CO': '0'},
#  '8736': {'NM': 'June T Hansen',
#   'LN': 'Hansen',
#   'FN': 'June',
#   'MN': 'T',
#   'P': '1',
#   'AD': '33 High St, Clinton, CT-06413',
#   'CO': '0'},
#  '8737': {'NM': 'Peter G Giannotti',
#   'LN': 'Giannotti',
#   'FN': 'Peter',
#   'MN': 'G',
#   'P': '6',
#   'AD': '23 Jefferson Circle, Clinton, CT-06413',
#   'CO': '0'},
#  '8738': {'NM': 'Dorothy A Mrowka',
#   'LN': 'Mrowka',
#   'FN': 'Dorothy',
#   'MN': 'A',
#   'P': '1',
#   'AD': '399 Lebanon Ave, Colchester, CT-06415',
#   'CO': '0'},
#  '8739': {'NM': 'Linda M Grzeika',
#   'LN': 'Grzeika',
#   'FN': 'Linda',
#   'MN': 'M',
#   'P': '6',
#   'AD': '54 Hi Lea Farm Rd, Colchester, CT-06415',
#   'CO': '0'},
#  '8740': {'NM': 'Karen Odell',
#   'LN': 'Odell',
#   'FN': 'Karen',
#   'MN': '',
#   'P': '1',
#   'AD': '189 Bunnell St, Colebrook, CT-06021',
#   'CO': '0'},
#  '8741': {'NM': 'Sherri P Gray',
#   'LN': 'Gray',
#   'FN': 'Sherri',
#   'MN': 'P',
#   'P': '6',
#   'AD': '23 Sandy Brook, PO Box 97, Colebrook, CT-06021',
#   'CO': '0'},
#  '8742': {'NM': 'Katherine A Morrison',
#   'LN': 'Morrison',
#   'FN': 'Katherine',
#   'MN': 'A',
#   'P': '6',
#   'AD': '14 Columbia Landing, Columbia, CT-06237',
#   'CO': '0'},
#  '8743': {'NM': 'Karen Butzgy',
#   'LN': 'Butzgy',
#   'FN': 'Karen',
#   'MN': '',
#   'P': '1',
#   'AD': '20 Wildwood Dr, Columbia, CT-06237',
#   'CO': '0'},
#  '8744': {'NM': 'Jayne Ridgway',
#   'LN': 'Ridgway',
#   'FN': 'Jayne',
#   'MN': '',
#   'P': '1',
#   'AD': '142 Town St, West Cornwall, CT-06796',
#   'CO': '0'},
#  '8745': {'NM': 'Cara Weigold',
#   'LN': 'Weigold',
#   'FN': 'Cara',
#   'MN': '',
#   'P': '6',
#   'AD': '158 Bunker Hill, West Cornwall, CT-06796',
#   'CO': '0'},
#  '8746': {'NM': 'Mary Ann Doran',
#   'LN': 'Doran',
#   'FN': 'Mary',
#   'MN': 'Ann',
#   'P': '6',
#   'AD': '5 Strawberry Hill Rd, Danbury, CT-06811',
#   'CO': '0'},
#  '8747': {'NM': 'Joan G Bielizna',
#   'LN': 'Bielizna',
#   'FN': 'Joan',
#   'MN': 'G',
#   'P': '1',
#   'AD': '179 Kohanza St, Danbury, CT-06811',
#   'CO': '0'},
#  '8748': {'NM': 'Susan K Gray',
#   'LN': 'Gray',
#   'FN': 'Susan',
#   'MN': 'K',
#   'P': '1',
#   'AD': '57 Brookside Rd, Darien, CT-06820',
#   'CO': '0'},
#  '8749': {'NM': 'Lucy Salicrup',
#   'LN': 'Salicrup',
#   'FN': 'Lucy',
#   'MN': '',
#   'P': '6',
#   'AD': '12 Juda Ln, East Haddam, CT-06423',
#   'CO': '0'},
#  '8750': {'NM': 'Martha Hansen',
#   'LN': 'Hansen',
#   'FN': 'Martha',
#   'MN': '',
#   'P': '1',
#   'AD': '56 Alexander Rd, East Haddam, CT-06415',
#   'CO': '0'},
#  '8751': {'NM': 'Lori A Wilcox',
#   'LN': 'Wilcox',
#   'FN': 'Lori',
#   'MN': 'A',
#   'P': '6',
#   'AD': '4 Hawthorne Rd, East Hampton, CT-06424',
#   'CO': '0'},
#  '8752': {'NM': 'Stephen I Watkins',
#   'LN': 'Watkins',
#   'FN': 'Stephen',
#   'MN': 'I',
#   'P': '1',
#   'AD': '11 Phillips Farm Rd, East Hartford, CT-06118',
#   'CO': '0'},
#  '8753': {'NM': 'Mary J Mourey',
#   'LN': 'Mourey',
#   'FN': 'Mary',
#   'MN': 'J',
#   'P': '6',
#   'AD': '785 Burnham St, East Hartford, CT-06108',
#   'CO': '0'},
#  '8754': {'NM': 'Albert Fucci',
#   'LN': 'Fucci',
#   'FN': 'Albert',
#   'MN': '',
#   'P': '1',
#   'AD': '20 Jardin Dr, East Haven, CT-06512',
#   'CO': '0'},
#  '8755': {'NM': 'Donna C Norman',
#   'LN': 'Norman',
#   'FN': 'Donna',
#   'MN': 'C',
#   'P': '6',
#   'AD': '15 Clancy St, East Haven, CT-06512',
#   'CO': '0'},
#  '8756': {'NM': 'Barbara Jo McGrath',
#   'LN': 'McGrath',
#   'FN': 'Barbara Jo',
#   'MN': '',
#   'P': '1',
#   'AD': '8 Bishop Bay Rd, Niantic, CT-06357',
#   'CO': '0'},
#  '8757': {'NM': 'Mary Devine Smith',
#   'LN': 'Smith',
#   'FN': 'Mary',
#   'MN': 'Devine',
#   'P': '6',
#   'AD': '8 Mostowy Rd, East Lyme, CT-06333',
#   'CO': '0'},
#  '8758': {'NM': 'Angelo P Sevarino',
#   'LN': 'Sevarino',
#   'FN': 'Angelo',
#   'MN': 'P',
#   'P': '1',
#   'AD': '26 Barber Hill Rd, Broad Brook, CT-06016',
#   'CO': '0'},
#  '8759': {'NM': 'Karen W Gaudreau',
#   'LN': 'Gaudreau',
#   'FN': 'Karen',
#   'MN': 'W',
#   'P': '6',
#   'AD': '167 Depot St, Broad Brook, CT-06016',
#   'CO': '0'},
#  '8760': {'NM': 'Nancy L Mayhew',
#   'LN': 'Mayhew',
#   'FN': 'Nancy',
#   'MN': 'L',
#   'P': '6',
#   'AD': '226 Eastford Rd, PO Box 185, Eastford, CT-06242',
#   'CO': '0'},
#  '8761': {'NM': 'Vincent Caprio',
#   'LN': 'Caprio',
#   'FN': 'Vincent',
#   'MN': '',
#   'P': '6',
#   'AD': '62 Marsh Rd, Easton, CT-06612',
#   'CO': '0'},
#  '8762': {'NM': 'Wanda DeLand',
#   'LN': 'DeLand',
#   'FN': 'Wanda',
#   'MN': '',
#   'P': '6',
#   'AD': '20 Brockway Rd, Ellington, CT-06029',
#   'CO': '0'},
#  '8763': {'NM': 'Lois Timms-Ferrara',
#   'LN': 'Timms-Ferrara',
#   'FN': 'Lois',
#   'MN': '',
#   'P': '1',
#   'AD': '23 Settlers Way, Ellington, CT-06029',
#   'CO': '0'},
#  '8764': {'NM': 'Tom Kienzler',
#   'LN': 'Kienzler',
#   'FN': 'Tom',
#   'MN': '',
#   'P': '6',
#   'AD': '359 Washington Rd, Enfield, CT-06082',
#   'CO': '0'},
#  '8765': {'NM': 'Lewis Fiore',
#   'LN': 'Fiore',
#   'FN': 'Lewis',
#   'MN': '',
#   'P': '1',
#   'AD': '14 Cartier Rd, Enfield, CT-06082',
#   'CO': '0'},
#  '8766': {'NM': 'Edward J Leary',
#   'LN': 'Leary',
#   'FN': 'Edward',
#   'MN': 'J',
#   'P': '6',
#   'AD': '19 Whispering Rod Rd, Unionville, CT-06085',
#   'CO': '0'},
#  '8767': {'NM': 'Barbara Brenneman',
#   'LN': 'Brenneman',
#   'FN': 'Barbara',
#   'MN': '',
#   'P': '1',
#   'AD': '15 Twin Ponds Dr, Unionville, CT-06085',
#   'CO': '0'},
#  '8768': {'NM': 'Eleanor W Dutcher',
#   'LN': 'Dutcher',
#   'FN': 'Eleanor',
#   'MN': 'W',
#   'P': '6',
#   'AD': '106 Robinson Hill Rd, Franklin, CT-06254',
#   'CO': '0'},
#  '8769': {'NM': 'Barbara A Konow',
#   'LN': 'Konow',
#   'FN': 'Barbara',
#   'MN': 'A',
#   'P': '1',
#   'AD': '2 Pond Rd, Franklin, CT-06254',
#   'CO': '0'},
#  '8770': {'NM': 'Charlie Murray',
#   'LN': 'Murray',
#   'FN': 'Charlie',
#   'MN': '',
#   'P': '1',
#   'AD': '118 Marilyn Dr, Glastonbury, CT-06033',
#   'CO': '0'},
#  '8771': {'NM': 'Lisbeth Becker',
#   'LN': 'Becker',
#   'FN': 'Lisbeth',
#   'MN': '',
#   'P': '6',
#   'AD': '184 Lincoln Dr, Glastonbury, CT-06033',
#   'CO': '0'},
#  '8772': {'NM': 'Nanci Howard',
#   'LN': 'Howard',
#   'FN': 'Nanci',
#   'MN': '',
#   'P': '1',
#   'AD': '95 Gray Ln, Goshen, CT-06756',
#   'CO': '0'},
#  '8773': {'NM': 'Lori Lynn Clinton',
#   'LN': 'Clinton',
#   'FN': 'Lori',
#   'MN': 'Lynn',
#   'P': '6',
#   'AD': '26 Milton Rd, Goshen, CT-06756',
#   'CO': '0'},
#  '8774': {'NM': 'Mary Hegarty',
#   'LN': 'Hegarty',
#   'FN': 'Mary',
#   'MN': '',
#   'P': '1',
#   'AD': '14A West End Ave, Old Greenwich, CT-06870',
#   'CO': '0'},
#  '8775': {'NM': 'Fred DeCaro III',
#   'LN': 'DeCaro III',
#   'FN': 'Fred',
#   'MN': '',
#   'P': '6',
#   'AD': '3 Sweet Briar Ln, Cos Cob, CT-06807',
#   'CO': '0'},
#  '8776': {'NM': 'Indigo Cohen',
#   'LN': 'Cohen',
#   'FN': 'Indigo',
#   'MN': '',
#   'P': '1',
#   'AD': '90 Ashland St Apt F, Griswold, CT-06351',
#   'CO': '0'},
#  '8777': {'NM': 'Gloria Nemczuk',
#   'LN': 'Nemczuk',
#   'FN': 'Gloria',
#   'MN': '',
#   'P': '6',
#   'AD': '284 Schoolside Ln, Guilford, CT-06437',
#   'CO': '0'},
#  '8778': {'NM': 'Lisa G Kops',
#   'LN': 'Kops',
#   'FN': 'Lisa',
#   'MN': 'G',
#   'P': '1',
#   'AD': '162 Sconset Ln, Guilford, CT-06437-4802',
#   'CO': '0'},
#  '8779': {'NM': 'Anthony V Esposito',
#   'LN': 'Esposito',
#   'FN': 'Anthony',
#   'MN': 'V',
#   'P': '6',
#   'AD': '1742 Whitney Ave, Hamden, CT-06517',
#   'CO': '0'},
#  '8780': {'NM': 'Rose V Mentone',
#   'LN': 'Mentone',
#   'FN': 'Rose',
#   'MN': 'V',
#   'P': '1',
#   'AD': '541 Hill St, Hamden, CT-06514',
#   'CO': '0'},
#  '8781': {'NM': 'Dayna McDermott Arriola',
#   'LN': 'Arriola',
#   'FN': 'Dayna',
#   'MN': 'McDermott',
#   'P': '6',
#   'AD': '218 W Old Rte 6, Hampton, CT-06247',
#   'CO': '0'},
#  '8782': {'NM': 'Catherine McCall',
#   'LN': 'McCall',
#   'FN': 'Catherine',
#   'MN': '',
#   'P': '6',
#   'AD': '147 McCall Rd, Lebanon, CT-06249',
#   'CO': '0'},
#  '8783': {'NM': 'Hazel M Gorman',
#   'LN': 'Gorman',
#   'FN': 'Hazel',
#   'MN': 'M',
#   'P': '1',
#   'AD': '23 Mathewson Mill Rd, Ledyard, CT-06339',
#   'CO': '0'},
#  '8784': {'NM': 'Nancy Lozier',
#   'LN': 'Lozier',
#   'FN': 'Nancy',
#   'MN': '',
#   'P': '6',
#   'AD': '198 Gallup Hill Rd, PO Box 275, Ledyard, CT-06339',
#   'CO': '0'},
#  '8785': {'NM': 'Dianne F Ahlberg',
#   'LN': 'Ahlberg',
#   'FN': 'Dianne',
#   'MN': 'F',
#   'P': '1',
#   'AD': '100 Mitchell Hill Rd, Lyme, CT-06371',
#   'CO': '0'},
#  '8786': {'NM': 'Judy Davies',
#   'LN': 'Davies',
#   'FN': 'Judy',
#   'MN': '',
#   'P': '6',
#   'AD': '332 Joshuatown Rd, Lyme, CT-06371',
#   'CO': '0'},
#  '8787': {'NM': 'Paula Perry',
#   'LN': 'Perry',
#   'FN': 'Paula',
#   'MN': '',
#   'P': '6',
#   'AD': '3 Madison Ave, Madison, CT-06443',
#   'CO': '0'},
#  '8788': {'NM': 'William Gowanlock',
#   'LN': 'Gowanlock',
#   'FN': 'William',
#   'MN': '',
#   'P': '1',
#   'AD': '16 Town Crier Ln, Madison, CT-06443',
#   'CO': '0'},
#  '8789': {'NM': 'Caroline Redding',
#   'LN': 'Redding',
#   'FN': 'Caroline',
#   'MN': '',
#   'P': '1',
#   'AD': '88 Cemetery Rd., Mansfield, CT-06250',
#   'CO': '0'},
#  '8790': {'NM': 'Ann M Kilby',
#   'LN': 'Kilby',
#   'FN': 'Ann',
#   'MN': 'M',
#   'P': '1',
#   'AD': '442 Jones Hollow Rd, Marlborough, CT-06447',
#   'CO': '0'},
#  '8791': {'NM': 'Dorothy Denniss',
#   'LN': 'Denniss',
#   'FN': 'Dorothy',
#   'MN': '',
#   'P': '6',
#   'AD': '111 Cheney Rd, Marlborough, CT-06447',
#   'CO': '0'},
#  '8792': {'NM': 'Catherine E Sarault',
#   'LN': 'Sarault',
#   'FN': 'Catherine',
#   'MN': 'E',
#   'P': '6',
#   'AD': '309 Bradley Ave, Meriden, CT-06451',
#   'CO': '0'},
#  '8793': {'NM': 'Maureen E Flynn',
#   'LN': 'Flynn',
#   'FN': 'Maureen',
#   'MN': 'E',
#   'P': '1',
#   'AD': '18 Breckenridge Ave, Meriden, CT-06450',
#   'CO': '0'},
#  '8794': {'NM': 'Michael F.P. Watkins',
#   'LN': 'Watkins',
#   'FN': 'Michael',
#   'MN': 'F.P.',
#   'P': '1',
#   'AD': '174 Country Club Rd, Middlebury, CT-06762',
#   'CO': '0'},
#  '8795': {'NM': 'Nancy S Robison',
#   'LN': 'Robison',
#   'FN': 'Nancy',
#   'MN': '',
#   'P': '6',
#   'AD': '240 Regan Rd, Middlebury, CT-06762',
#   'CO': '0'},
#  '8796': {'NM': 'Cathleen Hinsch',
#   'LN': 'Hinsch',
#   'FN': 'Cathleen',
#   'MN': '',
#   'P': '6',
#   'AD': '30 Whisper Wind Rd, Middlefield, CT-06455',
#   'CO': '0'},
#  '8797': {'NM': 'Barbara Jean DiMauro',
#   'LN': 'DiMauro',
#   'FN': 'Barbara',
#   'MN': 'Jean',
#   'P': '1',
#   'AD': '2 Oxford Dr, Middlefield, CT-06455',
#   'CO': '0'},
#  '8798': {'NM': 'Elizabeth N W Santangelo',
#   'LN': 'Santangelo',
#   'FN': 'Elizabeth',
#   'MN': 'N W',
#   'P': '1',
#   'AD': '11 Prospect St, Middletown, CT-06457',
#   'CO': '0'},
#  '8799': {'NM': 'David Bauer',
#   'LN': 'Bauer',
#   'FN': 'David',
#   'MN': '',
#   'P': '6',
#   'AD': '55 Dobson Circle, Middletown, CT-06457',
#   'CO': '0'},
#  '8800': {'NM': 'Debra Fellenbaum',
#   'LN': 'Fellenbaum',
#   'FN': 'Debra',
#   'MN': '',
#   'P': '6',
#   'AD': '182 Forest Rd, Milford, CT-06461',
#   'CO': '0'},
#  '8801': {'NM': 'Kerri T Rowland',
#   'LN': 'Rowland',
#   'FN': 'Kerri',
#   'MN': 'T',
#   'P': '1',
#   'AD': '161 Beach Ave, Milford, CT-06460',
#   'CO': '0'},
#  '8802': {'NM': 'Robin E Marquand',
#   'LN': 'Marquand',
#   'FN': 'Robin',
#   'MN': 'E',
#   'P': '1',
#   'AD': '853 Old Colchester Rd, Oakdale, CT-06370',
#   'CO': '0'},
#  '8803': {'NM': 'Dana McFee',
#   'LN': 'McFee',
#   'FN': 'Dana',
#   'MN': '',
#   'P': '6',
#   'AD': '27 Crestview Dr, Uncasville, CT-06352',
#   'CO': '0'},
#  '8804': {'NM': 'Louise Sheedy',
#   'LN': 'Sheedy',
#   'FN': 'Louise',
#   'MN': '',
#   'P': '1',
#   'AD': '6 Culver St, Naugatuck, CT-06770',
#   'CO': '0'},
#  '8805': {'NM': 'Matthew R Katra',
#   'LN': 'Katra',
#   'FN': 'Matthew',
#   'MN': 'R',
#   'P': '6',
#   'AD': '1346 Rubber Ave, Naugatuck, CT-06770',
#   'CO': '0'},
#  '8806': {'NM': 'Joan McLaughlin',
#   'LN': 'McLaughlin',
#   'FN': 'Joan',
#   'MN': '',
#   'P': '6',
#   'AD': '589 West Rd, New Canaan, CT-06840',
#   'CO': '0'},
#  '8807': {'NM': 'John A Amarilios',
#   'LN': 'Amarilios',
#   'FN': 'John',
#   'MN': 'A',
#   'P': '1',
#   'AD': '1222 Oenoke Dr, New Canaan, CT-06840',
#   'CO': '0'},
#  '8808': {'NM': 'Marcel Grenier',
#   'LN': 'Grenier',
#   'FN': 'Marcel',
#   'MN': '',
#   'P': '1',
#   'AD': '57 Sherman Rd, New Millford, CT-06776',
#   'CO': '0'},
#  '8809': {'NM': 'John C Gaiser',
#   'LN': 'Gaiser',
#   'FN': 'John',
#   'MN': 'C',
#   'P': '6',
#   'AD': '5 Robin Ridge, New Millford, CT-06776',
#   'CO': '0'},
#  '8810': {'NM': 'Linda B Cultrera',
#   'LN': 'Cultrera',
#   'FN': 'Linda',
#   'MN': 'B',
#   'P': '6',
#   'AD': '39 Eckert Rd, Newington, CT-06111',
#   'CO': '0'},
#  '8811': {'NM': 'Marie Montano Fox',
#   'LN': 'Fox',
#   'FN': 'Marie',
#   'MN': 'Montano',
#   'P': '1',
#   'AD': '1901 Main St, Newington, CT-06111',
#   'CO': '0'},
#  '8812': {'NM': 'Lisa D Fitch',
#   'LN': 'Fitch',
#   'FN': 'Lisa',
#   'MN': 'D',
#   'P': '6',
#   'AD': '77 Glen Meadow Dr, Northford, CT-06472',
#   'CO': '0'},
#  '8813': {'NM': 'Marlene K Esposito',
#   'LN': 'Esposito',
#   'FN': 'Marlene',
#   'MN': 'K',
#   'P': '1',
#   'AD': '50 Woodvale Dr, Northford, CT-06472',
#   'CO': '0'},
#  '8814': {'NM': 'Laurie Brangi',
#   'LN': 'Brangi',
#   'FN': 'Laurie',
#   'MN': '',
#   'P': '6',
#   'AD': '70 Bailey Rd, North Haven, CT-06473',
#   'CO': '0'},
#  '8815': {'NM': 'Patricia A Jackson-Marshall',
#   'LN': 'Jackson-Marshall',
#   'FN': 'Patricia',
#   'MN': 'A',
#   'P': '1',
#   'AD': '10 Watson Ave, North Haven, CT-06473',
#   'CO': '0'},
#  '8816': {'NM': 'Joan Kepler',
#   'LN': 'Kepler',
#   'FN': 'Joan',
#   'MN': '',
#   'P': '1',
#   'AD': '26 Hangman Hill Rd, North Stonington, CT-06359',
#   'CO': '0'},
#  '8817': {'NM': 'Karen Doyle Lyons',
#   'LN': 'Doyle Lyons',
#   'FN': 'Karen',
#   'MN': '',
#   'P': '6',
#   'AD': '58 Spring Hill Ave, Norwalk, CT-06850',
#   'CO': '0'},
#  '8818': {'NM': 'Stuart W Wells III',
#   'LN': 'Wells III',
#   'FN': 'Stuart',
#   'MN': 'W',
#   'P': '1',
#   'AD': '224 West Norwalk Rd, Norwalk, CT-06850',
#   'CO': '0'},
#  '8819': {'NM': 'Janice Casey',
#   'LN': 'Casey',
#   'FN': 'Janice',
#   'MN': '',
#   'P': '1',
#   'AD': '153 Ohman Ave, Orange, CT-06477',
#   'CO': '0'},
#  '8820': {'NM': 'Frederick A Kendrick',
#   'LN': 'Kendrick',
#   'FN': 'Frederick',
#   'MN': 'A',
#   'P': '6',
#   'AD': '194 Margaret Ln, Orange, CT-06477',
#   'CO': '0'},
#  '8821': {'NM': 'Joanne Jelenik',
#   'LN': 'Jelenik',
#   'FN': 'Joanne',
#   'MN': '',
#   'P': '1',
#   'AD': '124 Chestnut Tree Hill Rd Ext, Oxford, CT-06478',
#   'CO': '0'},
#  '8822': {'NM': 'Linda Crowe',
#   'LN': 'Crowe',
#   'FN': 'Linda',
#   'MN': '',
#   'P': '6',
#   'AD': '10 Palmer Ln, Oxford, CT-06478',
#   'CO': '0'},
#  '8823': {'NM': 'Irene A Bessette',
#   'LN': 'Bessette',
#   'FN': 'Irene',
#   'MN': 'A',
#   'P': '1',
#   'AD': '23 Major Dr, Plainfield, CT-06374',
#   'CO': '0'},
#  '8824': {'NM': 'Sonia S Chapman',
#   'LN': 'Chapman',
#   'FN': 'Sonia',
#   'MN': 'S',
#   'P': '6',
#   'AD': '70 Jackson Rd, Plainfield, CT-06374',
#   'CO': '0'},
#  '8826': {'NM': 'Barbara Deschaine',
#   'LN': 'Deschaine',
#   'FN': 'Barbara',
#   'MN': '',
#   'P': '6',
#   'AD': '17 Richmond Dr, Plymouth, CT-06782',
#   'CO': '0'},
#  '8827': {'NM': 'Athena Marie Neville',
#   'LN': 'Neville',
#   'FN': 'Athena',
#   'MN': 'Marie',
#   'P': '1',
#   'AD': '28 Summer St, Portland, CT-06480',
#   'CO': '0'},
#  '8828': {'NM': 'Pauline J Neumann',
#   'LN': 'Neumann',
#   'FN': 'Pauline',
#   'MN': 'J',
#   'P': '6',
#   'AD': '511 Main St, PO Box 527, Portland, CT-06480',
#   'CO': '0'},
#  '8829': {'NM': 'Desiree Majcher',
#   'LN': 'Majcher',
#   'FN': 'Desiree',
#   'MN': '',
#   'P': '6',
#   'AD': '165 Middle Rd, Preston, CT-06365',
#   'CO': '0'},
#  '8831': {'NM': 'Marianne W Byrne',
#   'LN': 'Byrne',
#   'FN': 'Marianne',
#   'MN': 'W',
#   'P': '6',
#   'AD': '29 Rockridge Terr, Prospect, CT-06712',
#   'CO': '0'},
#  '8832': {'NM': 'Katherine S Blinstrubas',
#   'LN': 'Blinstrubas',
#   'FN': 'Katherine',
#   'MN': 'S',
#   'P': '1',
#   'AD': '24 Maple Dr, Prospect, CT-06712',
#   'CO': '0'},
#  '8833': {'NM': 'Amy Alcott',
#   'LN': 'Alcott',
#   'FN': 'Amy',
#   'MN': '',
#   'P': '6',
#   'AD': '30 Peaceable St, Redding, CT-06896',
#   'CO': '0'},
#  '8834': {'NM': 'Joanne L Perlman',
#   'LN': 'Perlman',
#   'FN': 'Joanne',
#   'MN': 'L',
#   'P': '1',
#   'AD': '30 Mine Hill Rd, Redding, CT-06896',
#   'CO': '0'},
#  '8835': {'NM': 'Wayne S Floegel',
#   'LN': 'Floegel',
#   'FN': 'Wayne',
#   'MN': 'S',
#   'P': '6',
#   'AD': '294 West Mtn Rd, Ridgefield, CT-06877',
#   'CO': '0'},
#  '8836': {'NM': 'Cynthia A Bruno',
#   'LN': 'Bruno',
#   'FN': 'Cynthia',
#   'MN': 'A',
#   'P': '1',
#   'AD': '355 Bennetts Farm Rd, Ridgefield, CT-06877',
#   'CO': '0'},
#  '8837': {'NM': 'Geraldine Yoo',
#   'LN': 'Yoo',
#   'FN': 'Geraldine',
#   'MN': '',
#   'P': '6',
#   'AD': '83 Wyndingbrook Dr, Rocky Hill, CT-06067',
#   'CO': '0'},
#  '8838': {'NM': 'Donald R Francis',
#   'LN': 'Francis',
#   'FN': 'Donald',
#   'MN': 'R',
#   'P': '1',
#   'AD': '94 Terry Ln, Rocky Hill, CT-06067',
#   'CO': '0'},
#  '8839': {'NM': 'Georgia M Pech',
#   'LN': 'Pech',
#   'FN': 'Georgia',
#   'MN': 'M',
#   'P': '6',
#   'AD': '113 Horse Pond Rd Apt B, Salem, CT-06420-4044',
#   'CO': '0'},
#  '8840': {'NM': 'Betsy B Butts',
#   'LN': 'Butts',
#   'FN': 'Betsy',
#   'MN': 'B',
#   'P': '1',
#   'AD': '376 Hartford Rd, Salem, CT-06420',
#   'CO': '0'},
#  '8841': {'NM': 'Karin Gerstel',
#   'LN': 'Gerstel',
#   'FN': 'Karin',
#   'MN': '',
#   'P': '1',
#   'AD': '535 Undermountain Rd, Salisbury, CT-06068',
#   'CO': '0'},
#  '8842': {'NM': 'Maureen F Dell',
#   'LN': 'Dell',
#   'FN': 'Maureen',
#   'MN': 'F',
#   'P': '6',
#   'AD': '172 Farnum Rd, Lakeville, CT-06039',
#   'CO': '0'},
#  '8843': {'NM': "Wendy A O'Connor",
#   'LN': "O'Connor",
#   'FN': 'Wendy',
#   'MN': 'A',
#   'P': '1',
#   'AD': '44 Decker Hill Rd, Scotland, CT-06264',
#   'CO': '0'},
#  '8844': {'NM': 'Thomas Lapaglia',
#   'LN': 'Lapaglia',
#   'FN': 'Thomas',
#   'MN': '',
#   'P': '1',
#   'AD': '48 Birchwood Rd, Seymour, CT-06483',
#   'CO': '0'},
#  '8845': {'NM': 'Elise Wood',
#   'LN': 'Wood',
#   'FN': 'Elise',
#   'MN': '',
#   'P': '6',
#   'AD': '156 Great Hill Rd, Seymour, CT-06483',
#   'CO': '0'},
#  '8846': {'NM': 'Bob Lally',
#   'LN': 'Lally',
#   'FN': 'Bob',
#   'MN': '',
#   'P': '1',
#   'AD': '54 Brownson Dr, Shelton, CT-06484',
#   'CO': '0'},
#  '8847': {'NM': 'Peter R Pavone',
#   'LN': 'Pavone',
#   'FN': 'Peter',
#   'MN': 'R',
#   'P': '6',
#   'AD': '18 Coachmans Ln, Shelton, CT-06484',
#   'CO': '0'},
#  '8848': {'NM': 'Shelia J McMahon',
#   'LN': 'McMahon',
#   'FN': 'Sheila',
#   'MN': 'J',
#   'P': '6',
#   'AD': '4 B Timber Lake Rd, Sherman, CT-06784',
#   'CO': '0'},
#  '8849': {'NM': 'Karen Cortes',
#   'LN': 'Cortes',
#   'FN': 'Karen',
#   'MN': '',
#   'P': '1',
#   'AD': '17 Rosewood Dr, Simsbury, CT-06070',
#   'CO': '0'},
#  '8850': {'NM': 'Michele Potvin-Piecuch',
#   'LN': 'Potvin-Piecuch',
#   'FN': 'Michele',
#   'MN': '',
#   'P': '6',
#   'AD': '8 Oakland Terr, Simsbury, CT-06070',
#   'CO': '0'},
#  '8851': {'NM': 'Robert W Schmidt',
#   'LN': 'Schmidt',
#   'FN': 'Robert',
#   'MN': 'W',
#   'P': '1',
#   'AD': '62 Pond Circle, Somers, CT-06071',
#   'CO': '0'},
#  '8852': {'NM': 'David McCaffrey',
#   'LN': 'McCaffrey',
#   'FN': 'David',
#   'MN': '',
#   'P': '6',
#   'AD': '249 Ninth District Rd, Somers, CT-06071',
#   'CO': '0'},
#  '8854': {'NM': 'Katherine Hermonot',
#   'LN': 'Hermonot',
#   'FN': 'Katherine',
#   'MN': '',
#   'P': '6',
#   'AD': '227 Ekonk Hill Rd, Sterling, CT-06377',
#   'CO': '0'},
#  '8855': {'NM': 'Karen O Linehan',
#   'LN': 'Linehan',
#   'FN': 'Karen',
#   'MN': 'O',
#   'P': '6',
#   'AD': '12 Castle Hill Rd, Pawcatuck, CT-06379',
#   'CO': '0'},
#  '8856': {'NM': 'Peggy Cawley',
#   'LN': 'Cawley',
#   'FN': 'Peggy',
#   'MN': '',
#   'P': '1',
#   'AD': '67 Wolfneck Rd, Stonington, CT-06378',
#   'CO': '0'},
#  '8857': {'NM': 'Darlene Burrell',
#   'LN': 'Burrell',
#   'FN': 'Darlene',
#   'MN': '',
#   'P': '1',
#   'AD': '623 Forest Rd, West Suffield, CT-06093',
#   'CO': '0'},
#  '8858': {'NM': 'Lynn Joyal',
#   'LN': 'Joyal',
#   'FN': 'Lynn',
#   'MN': '',
#   'P': '6',
#   'AD': '365 Babbs Rd, West Suffield, CT-06093',
#   'CO': '0'},
#  '8859': {'NM': 'Mary Butkevich',
#   'LN': 'Butkevich',
#   'FN': 'Mary',
#   'MN': '',
#   'P': '6',
#   'AD': '449 Hickory Hill Rd, Thomaston, CT-06787',
#   'CO': '0'},
#  '8860': {'NM': 'Joyce Pichette',
#   'LN': 'Pichette',
#   'FN': 'Joyce',
#   'MN': '',
#   'P': '1',
#   'AD': '412 Walnut Hill Rd, Thomaston, CT-06787',
#   'CO': '0'},
#  '8861': {'NM': 'A Aileen Witkowski',
#   'LN': 'Witkowski',
#   'FN': 'A Aileen',
#   'MN': '',
#   'P': '1',
#   'AD': '334 West Thompson Rd, Thompson, CT-06277',
#   'CO': '0'},
#  '8862': {'NM': 'Francis J McGarry',
#   'LN': 'McGarry',
#   'FN': 'Francis',
#   'MN': 'J',
#   'P': '6',
#   'AD': '225 Chase Rd, Thompson, CT-06277',
#   'CO': '0'},
#  '8863': {'NM': 'John C Ciesco',
#   'LN': 'Ciesco',
#   'FN': 'John',
#   'MN': 'C',
#   'P': '1',
#   'AD': '267 Wind Tree, Torrington, CT-06790',
#   'CO': '0'},
#  '8864': {'NM': 'Edward Wilmot',
#   'LN': 'Wilmot',
#   'FN': 'Edward',
#   'MN': '',
#   'P': '6',
#   'AD': '22 Travis St, Torrington, CT-06790',
#   'CO': '0'},
#  '8865': {'NM': 'Mary Markham',
#   'LN': 'Markham',
#   'FN': 'Mary',
#   'MN': '',
#   'P': '1',
#   'AD': '3 Stony Brook Circle, Trumbull, CT-06611',
#   'CO': '0'},
#  '8866': {'NM': 'William S Holden',
#   'LN': 'Holden',
#   'FN': 'William',
#   'MN': 'S',
#   'P': '6',
#   'AD': '6 Woodfield Dr, Trumbull, CT-06611',
#   'CO': '0'},
#  '8867': {'NM': 'Joshua Lambert',
#   'LN': 'Lambert',
#   'FN': 'Joshua',
#   'MN': '',
#   'P': '1',
#   'AD': '621 Buckley Hwy, Union, CT-06076',
#   'CO': '0'},
#  '8868': {'NM': 'Deborah L Fletcher',
#   'LN': 'Fletcher',
#   'FN': 'Deborah',
#   'MN': 'L',
#   'P': '6',
#   'AD': '1001B Ekonk Hill Rd, Voluntown, CT-06384',
#   'CO': '0'},
#  '8869': {'NM': 'Joyce A Melgey',
#   'LN': 'Melgey',
#   'FN': 'Joyce',
#   'MN': 'A',
#   'P': '1',
#   'AD': '366 Beach Pond Rd, Voluntown, CT-06384',
#   'CO': '0'},
#  '8870': {'NM': 'Chet Miller',
#   'LN': 'Miller',
#   'FN': 'Chet',
#   'MN': '',
#   'P': '6',
#   'AD': '65B Masonic Ave #144, Wallingford, CT-06492',
#   'CO': '0'},
#  '8871': {'NM': 'Robert Avery',
#   'LN': 'Avery',
#   'FN': 'Robert',
#   'MN': '',
#   'P': '1',
#   'AD': '42 North Elm St, Wallingford, CT-06492',
#   'CO': '0'},
#  '8872': {'NM': 'Julie Watson Jones',
#   'LN': 'Jones',
#   'FN': 'Julie',
#   'MN': 'Watson',
#   'P': '1',
#   'AD': '37 Hickory Ln, Waterford, CT-06385',
#   'CO': '0'},
#  '8873': {'NM': 'Patti Waters',
#   'LN': 'Waters',
#   'FN': 'Patti',
#   'MN': '',
#   'P': '6',
#   'AD': '16 Jordan Terr, Waterford, CT-06385',
#   'CO': '0'},
#  '8874': {'NM': 'Debra A Hughes',
#   'LN': 'Hughes',
#   'FN': 'Debra',
#   'MN': 'A',
#   'P': '1',
#   'AD': '86 Westview Dr, Oakville, CT-06779',
#   'CO': '0'},
#  '8875': {'NM': 'Robert M Porter',
#   'LN': 'Porter',
#   'FN': 'Robert',
#   'MN': 'M',
#   'P': '6',
#   'AD': '71 Cherry Ave, Watertown, CT-06795',
#   'CO': '0'},
#  '8876': {'NM': 'Beth Kyle',
#   'LN': 'Kyle',
#   'FN': 'Beth',
#   'MN': '',
#   'P': '6',
#   'AD': '52 Arundel Ave, West Hartford, CT-06107',
#   'CO': '0'},
#  '8878': {'NM': 'Tammy L Herzog Roberts',
#   'LN': 'Herzog Roberts',
#   'FN': 'Tammy',
#   'MN': 'T',
#   'P': '6',
#   'AD': '159 Old Redding Rd., Weston, CT-06883',
#   'CO': '0'},
#  '8879': {'NM': 'Mike Zegers',
#   'LN': 'Zegers',
#   'FN': 'Mike',
#   'MN': '',
#   'P': '1',
#   'AD': '83 Lyons Plains Rd., Weston, CT-06883',
#   'CO': '0'},
#  '8880': {'NM': 'Marla J Cowden',
#   'LN': 'Cowden',
#   'FN': 'Marla',
#   'MN': 'J',
#   'P': '1',
#   'AD': '3 Laurel Lane, Westport, CT-06880-4914',
#   'CO': '0'},
#  '8881': {'NM': 'Richard Ruggiano',
#   'LN': 'Ruggiano',
#   'FN': 'Richard',
#   'MN': '',
#   'P': '6',
#   'AD': '88 Bayberry Ln Rd, Westport, CT-06880',
#   'CO': '0'},
#  '8882': {'NM': 'Barbara Braunstein',
#   'LN': 'Braunstein',
#   'FN': 'Barbara',
#   'MN': '',
#   'P': '1',
#   'AD': '150 Rugg Brook Rd, Winsted, CT-06098',
#   'CO': '0'},
#  '8883': {'NM': 'Deborah G Jones',
#   'LN': 'Jones',
#   'FN': 'Deborah',
#   'MN': 'G',
#   'P': '6',
#   'AD': '364 Platt Hill Rd, Winsted, CT-06098',
#   'CO': '0'},
#  '8884': {'NM': 'Paulann "Bunny" Lescoe',
#   'LN': 'Lescoe',
#   'FN': 'Paulann "Bunny"',
#   'MN': '',
#   'P': '1',
#   'AD': '33 Hewitt St, Willimantic, CT-06226',
#   'CO': '0'},
#  '8885': {'NM': 'Anita M Mips',
#   'LN': 'Mips',
#   'FN': 'Anita',
#   'MN': 'M',
#   'P': '1',
#   'AD': '14 Dudley Town Rd, Windsor, CT-06095-2635',
#   'CO': '0'},
#  '8886': {'NM': 'Karen A Andrews',
#   'LN': 'Andrews',
#   'FN': 'Karen',
#   'MN': 'A',
#   'P': '6',
#   'AD': '3 Sarah Anne Ln, Windsor, CT-06095',
#   'CO': '0'},
#  '8887': {'NM': 'John L Ferrari',
#   'LN': 'Ferrari',
#   'FN': 'John',
#   'MN': 'L',
#   'P': '1',
#   'AD': '29 Acorn Dr, Windsor Locks, CT-06096',
#   'CO': '0'},
#  '8888': {'NM': 'Rose Horan',
#   'LN': 'Horan',
#   'FN': 'Rose',
#   'MN': '',
#   'P': '6',
#   'AD': '31 Dickerman Ave, Windsor Locks, CT-06096',
#   'CO': '0'},
#  '8890': {'NM': 'Patricia B Najarian',
#   'LN': 'Najarian',
#   'FN': 'Patricia',
#   'MN': 'B',
#   'P': '6',
#   'AD': '43 Rocco Dr, Wolcott, CT-06716',
#   'CO': '0'},
#  '8891': {'NM': 'Elia Alexiades',
#   'LN': 'Alexiades',
#   'FN': 'Elia',
#   'MN': '',
#   'P': '1',
#   'AD': '14 Seymour Rd, Woodbridge, CT-06525',
#   'CO': '0'},
#  '8892': {'NM': 'Anna D Dickerson',
#   'LN': 'Dickerson',
#   'FN': 'Anna',
#   'MN': 'A',
#   'P': '6',
#   'AD': '425 Amity Rd, Woodbridge, CT-06525',
#   'CO': '0'},
#  '8893': {'NM': 'Suzanne Woodward',
#   'LN': 'Woodward',
#   'FN': 'Suzanne',
#   'MN': '',
#   'P': '1',
#   'AD': '19 Barlow Cemetery Rd, Woodstock Valley, CT-06282',
#   'CO': '0'},
#  '8894': {'NM': 'Heather Paquette',
#   'LN': 'Paquette',
#   'FN': 'Heather',
#   'MN': '',
#   'P': '6',
#   'AD': '34 Quarry Rd, PO Box 56, Woodstock, CT-06267',
#   'CO': '0'},
#  '8895': {'NM': 'Melody Savino',
#   'LN': 'Savino',
#   'FN': 'Melody',
#   'MN': '',
#   'P': '6',
#   'AD': '132 Hanover Rd, Scotland, CT-06264',
#   'CO': '0'},
#  '8896': {'NM': "Charlene Marquis O'Brien",
#   'LN': "O'Brien",
#   'FN': 'Charlene',
#   'MN': 'Marquis',
#   'P': '1',
#   'AD': '67 Blue Heron Dr., East Hampton, CT-06424',
#   'CO': '0'},
#  '8897': {'NM': 'Janice E Loomis',
#   'LN': 'Loomis',
#   'FN': 'Janice',
#   'MN': '',
#   'P': '6',
#   'AD': '11 Sabrina Dr, Bethany, CT-06524',
#   'CO': '0'},
#  '8898': {'NM': 'Carole K McGuire',
#   'LN': 'McGuire',
#   'FN': 'Carole',
#   'MN': 'K',
#   'P': '1',
#   'AD': '68 Amy Rd, PO Box 156, Falls Village, CT-06031',
#   'CO': '0'},
#  '8899': {'NM': 'Susan J. Kelsey',
#   'LN': 'Kelsey',
#   'FN': 'Susan',
#   'MN': 'J',
#   'P': '6',
#   'AD': '300 Music Mountain Rd, Falls Village, CT-06031',
#   'CO': '0'},
#  '8900': {'NM': 'Loreen Hegan',
#   'LN': 'Hegan',
#   'FN': 'Loreen',
#   'MN': '',
#   'P': '1',
#   'AD': '61 Raymond Schoolhouse Rd., Canterbury, CT-06331',
#   'CO': '0'},
#  '8901': {'NM': 'Joyce E Merlo',
#   'LN': 'Merlo',
#   'FN': 'Joyce',
#   'MN': 'E',
#   'P': '1',
#   'AD': '204 Ashford Rd, Eastford, CT-06242',
#   'CO': '0'},
#  '8903': {'NM': 'Berkeley Nowosad',
#   'LN': 'Nowosad',
#   'FN': 'Berkeley',
#   'MN': '',
#   'P': '1',
#   'AD': '888 Trumbull Hwy, Lebanon, CT-06249',
#   'CO': '0'},
#  '8904': {'NM': 'Gladys I Chase',
#   'LN': 'Chase',
#   'FN': 'Gladys',
#   'MN': 'I',
#   'P': '6',
#   'AD': '733 Pendleton Hill Rd, North Stonington, CT-06359',
#   'CO': '0'},
#  '8905': {'NM': 'Susan Ververis',
#   'LN': 'Ververis',
#   'FN': 'Susan',
#   'MN': '',
#   'P': '1',
#   'AD': '161 Bishop Rd., Bozrah, CT-06334',
#   'CO': '0'},
#  '8906': {'NM': 'Donna Rusgrove',
#   'LN': 'Rusgrove',
#   'FN': 'Donna',
#   'MN': '',
#   'P': '6',
#   'AD': '15 Polly Dan Rd, Burlington, CT-06013',
#   'CO': '0'},
#  '8907': {'NM': 'Dale Winchell',
#   'LN': 'Winchell',
#   'FN': 'Dale',
#   'MN': '',
#   'P': '6',
#   'AD': '143 Union St, Deep River, CT-06417',
#   'CO': '0'},
#  '8908': {'NM': 'Bill Petkanas',
#   'LN': 'Petkanas',
#   'FN': 'Bill',
#   'MN': '',
#   'P': '1',
#   'AD': '7 Hillside Dr, Sherman, CT-06784',
#   'CO': '0'},
#  '8909': {'NM': 'Barbara Richardson Crouch',
#   'LN': 'Richardson Crouch',
#   'FN': 'Barbara',
#   'MN': '',
#   'P': '6',
#   'AD': "3 Noah's Way, Baltic, CT-06330-1423",
#   'CO': '0'},
#  '8910': {'NM': 'David Smith',
#   'LN': 'Smith',
#   'FN': 'David',
#   'MN': '',
#   'P': '1',
#   'AD': '48 Woodland Dr, Easton, CT-06612',
#   'CO': '0'},
#  '8911': {'NM': 'John Visi',
#   'LN': 'Visi',
#   'FN': 'John',
#   'MN': '',
#   'P': '6',
#   'AD': '25 Littlebrook Rd, Darien, CT-06820',
#   'CO': '0'},
#  '8912': {'NM': 'Vera Stearns Ward',
#   'LN': 'Ward',
#   'FN': 'Vera',
#   'MN': 'Stearns',
#   'P': '6',
#   'AD': '45 Spring Hill Rd, Mansfield, CT-06268',
#   'CO': '0'},
#  '8913': {'NM': 'Kimberly Desaulniers',
#   'LN': 'Desaulniers',
#   'FN': 'Kimberly',
#   'MN': '',
#   'P': '6',
#   'AD': '9 Laurel Ln, Windham, CT-06280',
#   'CO': '0'},
#  '8914': {'NM': 'Mary Louise Oliver',
#   'LN': 'Oliver',
#   'FN': 'Mary',
#   'MN': 'Louise',
#   'P': '1',
#   'AD': '58 North Brook St, Hampton, CT-06247',
#   'CO': '0'},
#  '8915': {'NM': 'John V. Heiser',
#   'LN': 'Heiser',
#   'FN': 'John',
#   'MN': 'V.',
#   'P': '6',
#   'AD': '14 West Hills Rd., Ivoryton, CT-06442',
#   'CO': '0'},
#  '8921': {'NM': 'Christopher S Murphy',
#   'LN': 'Murphy',
#   'FN': 'Christopher',
#   'MN': 'S',
#   'P': '1',
#   'AD': '145 Paulney Rd, Cheshire, CT-06410',
#   'CO': '0'},
#  '8924': {'NM': 'Denise W Merrill',
#   'LN': 'Merrill',
#   'FN': 'Denise',
#   'MN': 'W',
#   'P': '1',
#   'AD': '135 Elizabeth St, Hartford, CT-06105',
#   'CO': '0'},
#  '8926': {'NM': 'Kevin Lembo',
#   'LN': 'Lembo',
#   'FN': 'Kevin',
#   'MN': '',
#   'P': '1',
#   'AD': '11 Redcot Ln, Guilford, CT-06437',
#   'CO': '0'},
#  '8935': {'NM': 'Susan Chapman',
#   'LN': 'Chapman',
#   'FN': 'Susan',
#   'MN': '',
#   'P': '6',
#   'AD': 'PO Box 8186, New Fairfield, CT-06812',
#   'CO': '0'},
#  '8951': {'NM': 'Jeff Russell',
#   'LN': 'Russell',
#   'FN': 'Jeff',
#   'MN': '',
#   'P': '7',
#   'AD': '538 Manchester Rd, Glastonbury, CT-06025',
#   'CO': '0'},
#  '8952': {'NM': 'Richard Lion',
#   'LN': 'Lion',
#   'FN': 'Richard',
#   'MN': '',
#   'P': '8',
#   'AD': '388 Hartford Rd, 1st Floor, Manchester, CT-06040',
#   'CO': '0'},
#  '8953': {'NM': 'John B Larson',
#   'LN': 'Larson',
#   'FN': 'John',
#   'MN': 'B',
#   'P': '1',
#   'AD': '1887 Main St, East Hartford, CT-06108',
#   'CO': '0'},
#  '8954': {'NM': 'Jennifer T Nye',
#   'LN': 'Nye',
#   'FN': 'Jennifer',
#   'MN': 'T',
#   'P': '6',
#   'AD': '15 French Rd, Manchester, CT-06042',
#   'CO': '0'},
#  '8955': {'NM': 'Thomas McCormick',
#   'LN': 'McCormick',
#   'FN': 'Thomas',
#   'MN': '',
#   'P': '7',
#   'AD': '40 Avondale Rd, West Hartford, CT-06117',
#   'CO': '0'},
#  '8956': {'NM': 'Barbara Barry',
#   'LN': 'Barry',
#   'FN': 'Barbara',
#   'MN': '',
#   'P': '7',
#   'AD': '48 Village Dr, Apt 204, Wethersfield, CT-06109-1072',
#   'CO': '0'},
#  '8957': {'NM': 'Joe Courtney',
#   'LN': 'Courtney',
#   'FN': 'Joe',
#   'MN': '',
#   'P': '1',
#   'AD': '9 Tobias Court, Vernon, CT-06066',
#   'CO': '0'},
#  '8958': {'NM': 'Danny Postemski Jr',
#   'LN': 'Postemski Jr',
#   'FN': 'Danny',
#   'MN': '',
#   'P': '6',
#   'AD': '30 Kenyon Rd, Hampton, CT-06247',
#   'CO': '0'},
#  '8959': {'NM': 'Daniel Reale',
#   'LN': 'Reale',
#   'FN': 'Daniel',
#   'MN': '',
#   'P': '8',
#   'AD': '20 Dougherty Ave, Plainfield, CT-06374',
#   'CO': '0'},
#  '8960': {'NM': 'Rosa L DeLauro',
#   'LN': 'DeLauro',
#   'FN': 'Rosa',
#   'MN': 'L',
#   'P': '1',
#   'AD': '227 Church St, Apt 2A, New Haven, CT-06510',
#   'CO': '0'},
#  '8961': {'NM': 'Angel Cadena',
#   'LN': 'Cadena',
#   'FN': 'Angel',
#   'MN': '',
#   'P': '6',
#   'AD': '67 Long Hill Ave, Shelton, CT-06484',
#   'CO': '0'},
#  '8962': {'NM': 'Jim Himes',
#   'LN': 'Himes',
#   'FN': 'Jim',
#   'MN': '',
#   'P': '1',
#   'AD': '197 Valley Rd, Cos Cob, CT-06807',
#   'CO': '0'},
#  '8963': {'NM': 'Harry Arora',
#   'LN': 'Arora',
#   'FN': 'Harry',
#   'MN': '',
#   'P': '6',
#   'AD': '56 Rockwood Lane, Greenwich, CT-06830',
#   'CO': '0'},
#  '8969': {'NM': 'John W Fonfara',
#   'LN': 'Fonfara',
#   'FN': 'John',
#   'MN': 'W',
#   'P': '1',
#   'AD': '99 Montowese St, Hartford, CT-06114',
#   'CO': '0'},
#  '8970': {'NM': 'Barbara Ruhe',
#   'LN': 'Ruhe',
#   'FN': 'Barbara',
#   'MN': '',
#   'P': '6',
#   'AD': '79 Main St, Wethersfield, CT-06109',
#   'CO': '0'},
#  '8971': {'NM': 'Douglas McCrory',
#   'LN': 'McCrory',
#   'FN': 'Douglas',
#   'MN': '',
#   'P': '1',
#   'AD': '235 Blue Hills Ave, Hartford, CT-06112',
#   'CO': '0'},
#  '8972': {'NM': 'Tim Larson',
#   'LN': 'Larson',
#   'FN': 'Tim',
#   'MN': '',
#   'P': '1',
#   'AD': '33 Gorman Place, East Hartford, CT-06108',
#   'CO': '0'},
#  '8973': {'NM': 'Jennifer L Lovett',
#   'LN': 'Lovett',
#   'FN': 'Jennifer',
#   'MN': 'L',
#   'P': '6',
#   'AD': '1 Snipsic View Hghts, Ellington, CT-06029',
#   'CO': '0'},
#  '8974': {'NM': 'Steve Cassano',
#   'LN': 'Cassano',
#   'FN': 'Steve',
#   'MN': '',
#   'P': '1',
#   'AD': '1109 East Middle Tpke, Manchester, CT-06040',
#   'CO': '0'},
#  '8975': {'NM': 'Mark Tweedie',
#   'LN': 'Tweedie',
#   'FN': 'Mark',
#   'MN': '',
#   'P': '6',
#   'AD': '107 Steep Hollow Ln, Manchester, CT-06040',
#   'CO': '0'},
#  '8976': {'NM': 'Beth Bye',
#   'LN': 'Bye',
#   'FN': 'Beth',
#   'MN': '',
#   'P': '1',
#   'AD': '251 Ridgewood Rd, West Hartford, CT-06107',
#   'CO': '0'},
#  '8977': {'NM': 'Phillip Chabot',
#   'LN': 'Chabot',
#   'FN': 'Phillip',
#   'MN': '',
#   'P': '6',
#   'AD': '718 Camp St, Farmington, CT-06032',
#   'CO': '0'},
#  '8978': {'NM': 'Terry Bielinski Gerratana',
#   'LN': 'Bielinski Gerratana',
#   'FN': 'Terri',
#   'MN': '',
#   'P': '1',
#   'AD': '674 Lincoln St, New Britain, CT-06052',
#   'CO': '0'},
#  '8979': {'NM': 'Robert Smedley',
#   'LN': 'Smedley',
#   'FN': 'Robert',
#   'MN': '',
#   'P': '6',
#   'AD': '37 Highland Terrace, New Britain, CT-06053',
#   'CO': '0'},
#  '8980': {'NM': 'Annie Hornish',
#   'LN': 'Hornish',
#   'FN': 'Annie',
#   'MN': '',
#   'P': '1',
#   'AD': '584 Thrall Ave, Suffield, CT-06078',
#   'CO': '0'},
#  '8981': {'NM': 'John A Kissel',
#   'LN': 'Kissel',
#   'FN': 'John',
#   'MN': 'A',
#   'P': '6',
#   'AD': '16 Frew Terrace, Enfield, CT-06082',
#   'CO': '0'},
#  '8982': {'NM': 'Melissa E Osborne',
#   'LN': 'Osborne',
#   'FN': 'Melissa',
#   'MN': 'E',
#   'P': '1',
#   'AD': '25 Orchard Lane, Simsbury, CT-06070',
#   'CO': '0'},
#  '8983': {'NM': 'Kevin Witkos',
#   'LN': 'Witkos',
#   'FN': 'Kevin',
#   'MN': '',
#   'P': '6',
#   'AD': '15 Highledge Rd, Canton, CT-06019',
#   'CO': '0'},
#  '8988': {'NM': 'Gary Winfield',
#   'LN': 'Winfield',
#   'FN': 'Gary',
#   'MN': '',
#   'P': '1',
#   'AD': '480 Winchester Ave, New Haven, CT-06511',
#   'CO': '0'},
#  '8989': {'NM': 'Douglas E Losty',
#   'LN': 'Losty',
#   'FN': 'Douglas',
#   'MN': 'E',
#   'P': '6',
#   'AD': '605 Valley Street, New Haven, CT-06515',
#   'CO': '0'},
#  '8990': {'NM': 'Martin M Looney',
#   'LN': 'Looney',
#   'FN': 'Martin',
#   'MN': 'M',
#   'P': '1',
#   'AD': '132 Fort Hale Rd, East Haven, CT-06512',
#   'CO': '0'},
#  '8991': {'NM': 'Erin Reilly',
#   'LN': 'Reilly',
#   'FN': 'Erin',
#   'MN': '',
#   'P': '6',
#   'AD': '1697 B Quinnipiac Ave, New Haven, CT-06513',
#   'CO': '0'},
#  '8992': {'NM': 'Christine Cohen',
#   'LN': 'Cohen',
#   'FN': 'Christine',
#   'MN': '',
#   'P': '1',
#   'AD': '308 No River St, Guilford, CT-06437',
#   'CO': '0'},
#  '8993': {'NM': 'Adam Greenberg',
#   'LN': 'Greenberg',
#   'FN': 'Adam',
#   'MN': '',
#   'P': '6',
#   'AD': '6 Patridge Lane, Branford, CT-06405',
#   'CO': '0'},
#  '8994': {'NM': 'Mary Daugherty Abrams',
#   'LN': 'Daugherty Abrams',
#   'FN': 'Mary',
#   'MN': '',
#   'P': '1',
#   'AD': '158 Hillcrest Terr, Meriden, CT-06450',
#   'CO': '0'},
#  '8995': {'NM': 'Len Suzio',
#   'LN': 'Suzio',
#   'FN': 'Len',
#   'MN': '',
#   'P': '6',
#   'AD': '35 Lyndale Place, Meriden, CT-06450',
#   'CO': '0'},
#  '8996': {'NM': 'James J Maroney',
#   'LN': 'Maroney',
#   'FN': 'James',
#   'MN': 'J',
#   'P': '1',
#   'AD': '22 Saranac Rd, Milford, CT-06461',
#   'CO': '0'},
#  '8999': {'NM': 'Joan V Hartley',
#   'LN': 'Hartley',
#   'FN': 'Joan',
#   'MN': 'V',
#   'P': '1',
#   'AD': '206 Columbia Blvd, Waterbury, CT-06710',
#   'CO': '0'},
#  '9001': {'NM': 'Rob Sampson',
#   'LN': 'Sampson',
#   'FN': 'Rob',
#   'MN': '',
#   'P': '6',
#   'AD': '276 Bound Line, Wolcott, CT-06716',
#   'CO': '0'},
#  '9005': {'NM': 'George S Logan',
#   'LN': 'Logan',
#   'FN': 'George',
#   'MN': 'S',
#   'P': '6',
#   'AD': '10 La Rovera Terr, Ansonia, CT-06401',
#   'CO': '0'},
#  '9006': {'NM': 'Robert R Statchen',
#   'LN': 'Statchen',
#   'FN': 'Robert',
#   'MN': 'R',
#   'P': '1',
#   'AD': '57 Brian Patch Rd, Stonington, CT-06378',
#   'CO': '0'},
#  '9007': {'NM': 'Heather Somers',
#   'LN': 'Somers',
#   'FN': 'Heather',
#   'MN': '',
#   'P': '6',
#   'AD': '67 Ramsdell St, Groton, CT-06340',
#   'CO': '0'},
#  '9008': {'NM': 'Catherine A Osten',
#   'LN': 'Osten',
#   'FN': 'Catherine',
#   'MN': 'A',
#   'P': '1',
#   'AD': '187 Scotland Rd, Scotland, CT-06330',
#   'CO': '0'},
#  '9009': {'NM': 'Mark A Lounsbury',
#   'LN': 'Lounsbury',
#   'FN': 'Mark',
#   'MN': 'A',
#   'P': '6',
#   'AD': '47 Noahs Way, Baltic, CT-06330',
#   'CO': '0'},
#  '9010': {'NM': 'Martha E Marx',
#   'LN': 'Marx',
#   'FN': 'Martha',
#   'MN': 'E',
#   'P': '1',
#   'AD': '4 Harbor Lane, New London, CT-06320',
#   'CO': '0'},
#  '9011': {'NM': 'Paul M Formica',
#   'LN': 'Formica',
#   'FN': 'Paul',
#   'MN': 'M',
#   'P': '6',
#   'AD': '20A Bush Hill Dr, Niantic, CT-06357',
#   'CO': '0'},
#  '9012': {'NM': 'Monica Tujak Brill',
#   'LN': 'Tujak Brill',
#   'FN': 'Monica',
#   'MN': '',
#   'P': '1',
#   'AD': '210 Anson St, Stratford, CT-06614',
#   'CO': '0'},
#  '9013': {'NM': 'Kevin C Kelly',
#   'LN': 'Kelly',
#   'FN': 'Kevin',
#   'MN': 'C',
#   'P': '6',
#   'AD': '240 York St, Stratford, CT-06615',
#   'CO': '0'},
#  '9014': {'NM': 'Marilyn Moore',
#   'LN': 'Moore',
#   'FN': 'Marilyn',
#   'MN': '',
#   'P': '1',
#   'AD': '666 Cleveland Ave, Bridgeport, CT-06604',
#   'CO': '0'},
#  '9015': {'NM': 'Rich Deecken',
#   'LN': 'Deecken',
#   'FN': 'Ric',
#   'MN': '',
#   'P': '6',
#   'AD': '1133 Avalon Gates, Trumbull, CT-06611',
#   'CO': '0'},
#  '9016': {'NM': 'Dennis Bradley',
#   'LN': 'Bradley',
#   'FN': 'Dennis',
#   'MN': '',
#   'P': '1',
#   'AD': '853 Fairfield Ave, Bridgeport, CT-06604',
#   'CO': '0'},
#  '9019': {'NM': 'Julie Kushner',
#   'LN': 'Kushner',
#   'FN': 'Julie',
#   'MN': '',
#   'P': '1',
#   'AD': '75 Old Ridgebury Rd, Danbury, CT-06810',
#   'CO': '0'},
#  '9020': {'NM': 'Michael A McLachlan',
#   'LN': 'McLachlan',
#   'FN': 'Michael',
#   'MN': 'A',
#   'P': '6',
#   'AD': '47 W Wooster St, Danbury, CT-06810',
#   'CO': '0'},
#  '9021': {'NM': 'Bob Duff',
#   'LN': 'Duff',
#   'FN': 'Bob',
#   'MN': '',
#   'P': '1',
#   'AD': '50 Toilsome Ave, Norwalk, CT-06851',
#   'CO': '0'},
#  '9022': {'NM': "Marc D'Amelio",
#   'LN': "D'Amelio",
#   'FN': 'Marc',
#   'MN': '',
#   'P': '6',
#   'AD': '15 Ellen St, Norwalk, CT-06851',
#   'CO': '0'},
#  '9023': {'NM': 'Will Haskell',
#   'LN': 'Haskell',
#   'FN': 'Will',
#   'MN': '',
#   'P': '1',
#   'AD': '21 Burtis Ave, New Canan, CT-06834',
#   'CO': '0'},
#  '9024': {'NM': 'Toni Boucher',
#   'LN': 'Boucher',
#   'FN': 'Toni',
#   'MN': '',
#   'P': '6',
#   'AD': '5 Wicks End Lane, Wilton, CT-06897',
#   'CO': '0'},
#  '9025': {'NM': 'Carlo Leone',
#   'LN': 'Leone',
#   'FN': 'Carlo',
#   'MN': '',
#   'P': '1',
#   'AD': '88 Houston Terrace, Stamford, CT-06902',
#   'CO': '0'},
#  '9026': {'NM': 'Jerry Bosak',
#   'LN': 'Bosak',
#   'FN': 'Jerry',
#   'MN': '',
#   'P': '6',
#   'AD': '453 Shippan Avenue, Stamford, CT-06902',
#   'CO': '0'},
#  '9027': {'NM': 'Cora M Santaguida',
#   'LN': 'Santaguida',
#   'FN': 'Cora',
#   'MN': 'M',
#   'P': '7',
#   'AD': '540 Liberty St, Apt 2B, Stamford, CT-06902',
#   'CO': '0'},
#  '9028': {'NM': 'Megan E Cassano',
#   'LN': 'Cassano',
#   'FN': 'Megan',
#   'MN': 'E',
#   'P': '7',
#   'AD': '18 Bridge St, Greenwich, CT-06830',
#   'CO': '0'},
#  '9029': {'NM': 'Michelle Lapine McCabe',
#   'LN': 'Lapine McCabe',
#   'FN': 'Michelle',
#   'MN': '',
#   'P': '1',
#   'AD': '2845 Park Ave, #2, Fairfield, CT-06825',
#   'CO': '0'},
#  '9030': {'NM': 'Tony Hwang',
#   'LN': 'Hwang',
#   'FN': 'Tony',
#   'MN': '',
#   'P': '6',
#   'AD': '80 Martingale Lane, Fairfield, CT-06824',
#   'CO': '0'},
#  '9031': {'NM': 'Mae Flexer',
#   'LN': 'Flexer',
#   'FN': 'Mae',
#   'MN': '',
#   'P': '1',
#   'AD': '452 Main St, Killingly, CT-06239',
#   'CO': '0'},
#  '9032': {'NM': 'David W Coderre',
#   'LN': 'Coderre',
#   'FN': 'David',
#   'MN': 'W',
#   'P': '6',
#   'AD': '15 Genevieve St, Putnam, CT-06260',
#   'CO': '0'},
#  '9033': {'NM': 'David A Lawson',
#   'LN': 'Lawson',
#   'FN': 'David',
#   'MN': 'A',
#   'P': '1',
#   'AD': '16 White Swan Dr, New Millford, CT-06776',
#   'CO': '0'},
#  '9034': {'NM': 'Craig A Miner',
#   'LN': 'Miner',
#   'FN': 'Craig',
#   'MN': 'A',
#   'P': '6',
#   'AD': '230 E Chestnut Hill Rd, Litchfield, CT-06759',
#   'CO': '0'},
#  '9035': {'NM': 'Christopher A Wright',
#   'LN': 'Wright',
#   'FN': 'Christopher',
#   'MN': 'A',
#   'P': '1',
#   'AD': '35 Ruth St, Unit 49, Bristol, CT-06010',
#   'CO': '0'},
#  '9036': {'NM': 'Henri Martin',
#   'LN': 'Martin',
#   'FN': 'Henri',
#   'MN': '',
#   'P': '6',
#   'AD': '7 Ipswitch Rd, Bristol, CT-06010',
#   'CO': '0'},
#  '9037': {'NM': 'Catherine P DeCarli',
#   'LN': 'DeCarlie',
#   'FN': 'Catherine',
#   'MN': 'P',
#   'P': '1',
#   'AD': '566 Flag Swamp Rd, Southbury, CT-06488',
#   'CO': '0'},
#  '9038': {'NM': 'Eric C Berthel',
#   'LN': 'Berthel',
#   'FN': 'Eric',
#   'MN': 'C',
#   'P': '6',
#   'AD': '92 Malvern Hill Rd, Watertown, CT-06795',
#   'CO': '0'},
#  '9039': {'NM': 'Norman Needleman',
#   'LN': 'Needleman',
#   'FN': 'Norman',
#   'MN': '',
#   'P': '1',
#   'AD': '24 Book Hill Woods, Essex, CT-06426',
#   'CO': '0'},
#  '9040': {'NM': 'Melissa Ziobron',
#   'LN': 'Ziobron',
#   'FN': 'Melissa',
#   'MN': '',
#   'P': '6',
#   'AD': '181 Petticoat Lane, East Haddam, CT-06423',
#   'CO': '0'},
#  '9043': {'NM': 'Len Fasano',
#   'LN': 'Fasano',
#   'FN': 'Len',
#   'MN': '',
#   'P': '6',
#   'AD': '7 Sycamore Lane, North Haven, CT-06473',
#   'CO': '0'},
#  '9044': {'NM': 'John Perrier',
#   'LN': 'Perrier',
#   'FN': 'John',
#   'MN': '',
#   'P': '1',
#   'AD': '18 Bradway Pond Rd, Stafford Springs, CT-06076',
#   'CO': '0'},
#  '9045': {'NM': 'Dan Champagne',
#   'LN': 'Champagne',
#   'FN': 'Dan',
#   'MN': '',
#   'P': '6',
#   'AD': '30 Lawler Rd, Vernon, CT-06066',
#   'CO': '0'},
#  '9046': {'NM': 'Alexandra "Alex" Bergstein',
#   'LN': 'Bergstein',
#   'FN': 'Alexandra',
#   'MN': '',
#   'P': '1',
#   'AD': '541 Lake Ave, Greenwich, CT-06830',
#   'CO': '0'},
#  '9047': {'NM': 'L Scott Frantz',
#   'LN': 'Frantz',
#   'FN': 'L Scott',
#   'MN': '',
#   'P': '6',
#   'AD': '123 Meadow Rd, Riverside, CT-06878',
#   'CO': '0'},
#  '9076': {'NM': 'Matthew Ritter',
#   'LN': 'Ritter',
#   'FN': 'Matthew',
#   'MN': '',
#   'P': '1',
#   'AD': '169 North Beacon St, Hartford, CT-06105',
#   'CO': '0'},
#  '9079': {'NM': 'Raghib Allie-Brennan',
#   'LN': 'Allie-Brennan',
#   'FN': 'Raghib',
#   'MN': '',
#   'P': '1',
#   'AD': '9 Cross Hill Rd, Bethel, CT-06801',
#   'CO': '0'},
#  '9082': {'NM': 'William Duff',
#   'LN': 'Duff',
#   'FN': 'William',
#   'MN': '',
#   'P': '6',
#   'AD': 'Long Meadow Lane, Bethel, CT-06801',
#   'CO': '0'},
#  '9090': {'NM': 'Julio A Concepcion',
#   'LN': 'Concepcion',
#   'FN': 'Julio',
#   'MN': 'A',
#   'P': '1',
#   'AD': '3 Linden Place, Unit 3A, Hartford, CT-06106',
#   'CO': '0'},
#  '9092': {'NM': 'Bryan C Nelson',
#   'LN': 'Nelson',
#   'FN': 'Bryan',
#   'MN': 'C',
#   'P': '6',
#   'AD': '221 Trumbull St, Apt. 707, Hartford, CT-06103',
#   'CO': '0'},
#  '9099': {'NM': 'Charles Jackson',
#   'LN': 'Jackson',
#   'FN': 'Charles',
#   'MN': '',
#   'P': '6',
#   'AD': '26 Wilson Avenue, Windsor, CT-06095',
#   'CO': '0'},
#  '9100': {'NM': 'Edwin Vargas',
#   'LN': 'Vargas',
#   'FN': 'Edwin',
#   'MN': '',
#   'P': '1',
#   'AD': '141 Douglas St, Hartford, CT-06114',
#   'CO': '0'},
#  '9101': {'NM': 'Michael P Barlowski',
#   'LN': 'Barlowski',
#   'FN': 'Michael',
#   'MN': 'P',
#   'P': '6',
#   'AD': '19 Waterford St, Hartford, CT-06106',
#   'CO': '0'},
#  '9102': {'NM': 'Joshua Malik Hall',
#   'LN': 'Hall',
#   'FN': 'Joshua',
#   'MN': 'Malik',
#   'P': '1',
#   'AD': '28 Canterbury St, Hartford, CT-06112',
#   'CO': '0'},
#  '9103': {'NM': 'Brenda Falusi',
#   'LN': 'Falusi',
#   'FN': 'Brenda',
#   'MN': '',
#   'P': '1',
#   'AD': '4 Laurel Ridge Rd, Tolland, CT-06084',
#   'CO': '0'},
#  '9104': {'NM': 'Tim Ackert',
#   'LN': 'Ackert',
#   'FN': 'Tim',
#   'MN': '',
#   'P': '6',
#   'AD': '67 Deer Hill Lane, Coventry, CT-06238',
#   'CO': '0'},
#  '9105': {'NM': 'Jason Rojas',
#   'LN': 'Rojas',
#   'FN': 'Jason',
#   'MN': '',
#   'P': '1',
#   'AD': '169 Langford Lane, East Hartford, CT-06118',
#   'CO': '0'},
#  '9106': {'NM': 'Henry J Genga',
#   'LN': 'Genga',
#   'FN': 'Henry',
#   'MN': 'J',
#   'P': '1',
#   'AD': '3 Elaine Dr, East Hartford, CT-06118',
#   'CO': '0'},
#  '9107': {'NM': 'Jeff Currey',
#   'LN': 'Currey',
#   'FN': 'Jeff',
#   'MN': '',
#   'P': '1',
#   'AD': '50 McKee St, East Hartford, CT-06108',
#   'CO': '0'},
#  '9108': {'NM': 'Geoff Luxenberg',
#   'LN': 'Luxenberg',
#   'FN': 'Geoff',
#   'MN': '',
#   'P': '1',
#   'AD': '265 Slater St, Apt 322, Manchester, CT-06042',
#   'CO': '0'},
#  '9109': {'NM': 'Thomas J Tierney',
#   'LN': 'Tierney',
#   'FN': 'Thomas',
#   'MN': 'J',
#   'P': '6',
#   'AD': '225 Kennedy Rd, Manchester, CT-06042',
#   'CO': '0'},
#  '9110': {'NM': 'Jason Doucette',
#   'LN': 'Doucette',
#   'FN': 'Jason',
#   'MN': '',
#   'P': '1',
#   'AD': '85 Stephanies Way, Manchester, CT-06040',
#   'CO': '0'},
#  '9111': {'NM': 'Jennifer Fiereck',
#   'LN': 'Fiereck',
#   'FN': 'Jennifer',
#   'MN': '',
#   'P': '6',
#   'AD': '600 South Main St, Manchester, CT-06040',
#   'CO': '0'},
#  '9112': {'NM': 'John P Pelkey',
#   'LN': 'Pelkey',
#   'FN': 'John',
#   'MN': 'P',
#   'P': '1',
#   'AD': '446 Pleasant Valley Rd, South Windsor, CT-06074',
#   'CO': '0'},
# ...
#   'CO': '0'},
#  '9931': {'NM': 'Phillip Chabot',
#   'LN': 'Chabot',
#   'FN': 'Phillip',
#   'MN': '',
#   'P': '3',
#   'AD': '718 Camp St, Farmington, CT-06032',
#   'CO': '0'},
#  '9932': {'NM': 'Mary M Fay',
#   'LN': 'Fay',
#   'FN': 'Mary',
#   'MN': 'M',
#   'P': '3',
#   'AD': '83 Craigmoor Rd, West Hartford, CT-06107',
#   'CO': '0'},
#  '9933': {'NM': 'Chris Forster',
#   'LN': 'Forster',
#   'FN': 'Chris',
#   'MN': '',
#   'P': '3',
#   'AD': '1773 Farmington Ave, Unionville, CT-06085',
#   'CO': '0'},
#  '9934': {'NM': 'Michael Hurley',
#   'LN': 'Hurley',
#   'FN': 'Michael',
#   'MN': '',
#   'P': '3',
#   'AD': '76 Black Birch Rd, Wethersfield, CT-06109',
#   'CO': '0'},
#  '9935': {'NM': 'Lillian Tanski',
#   'LN': 'Tanski',
#   'FN': 'Lillian',
#   'MN': '',
#   'P': '3',
#   'AD': '160 Southpond Rd, South Glastonbury, CT-06073',
#   'CO': '0'},
#  '9936': {'NM': 'Linda Szynkowicz',
#   'LN': 'Szynkowicz',
#   'FN': 'Linda',
#   'MN': '',
#   'P': '3',
#   'AD': '140 Knox Blvd, Middletown, CT-06457',
#   'CO': '0'},
#  '9937': {'NM': 'Samuel P Belsito Jr',
#   'LN': 'Belsito Jr',
#   'FN': 'Samuel',
#   'MN': 'P',
#   'P': '3',
#   'AD': '55 Lee Lane, Tolland, CT-06084',
#   'CO': '0'},
#  '9938': {'NM': 'Don Crouch',
#   'LN': 'Crouch',
#   'FN': 'Don',
#   'MN': '',
#   'P': '3',
#   'AD': '5 Lincoln Ave, Wallingford, CT-06492',
#   'CO': '0'},
#  '9939': {'NM': 'Veasna Roeun',
#   'LN': 'Roeun',
#   'FN': 'Veasna',
#   'MN': '',
#   'P': '3',
#   'AD': '17 Valley View Dr, Danbury, CT-06810',
#   'CO': '0'},
#  '9940': {'NM': 'Erin M Domenech',
#   'LN': 'Domenech',
#   'FN': 'Erin',
#   'MN': 'M',
#   'P': '3',
#   'AD': '14 South St, Unit 42, Danbury, CT-06810',
#   'CO': '0'},
#  '9941': {'NM': 'Michael S Ferguson',
#   'LN': 'Ferguson',
#   'FN': 'Michael',
#   'MN': 'S',
#   'P': '3',
#   'AD': '4 Old Hayrake Rd, Danbury, CT-06811',
#   'CO': '0'},
#  '9942': {'NM': 'Terrie E Wood',
#   'LN': 'Wood',
#   'FN': 'Terrie',
#   'MN': 'E',
#   'P': '3',
#   'AD': '50 St Nicholas Rd, Darien, CT-06820',
#   'CO': '0'},
#  '9943': {'NM': 'Christopher S Murphy',
#   'LN': 'Murphy',
#   'FN': 'Christopher',
#   'MN': 'S',
#   'P': '12',
#   'AD': '145 Paulney Rd, Cheshire, CT-06410',
#   'CO': '0'},
#  '9944': {'NM': 'Kennard Ray',
#   'LN': 'Ray',
#   'FN': 'Kennard',
#   'MN': '',
#   'P': '12',
#   'AD': '32 Elm St, Hartford, CT-06106',
#   'CO': '0'},
#  '9945': {'NM': 'Mary L Sanders',
#   'LN': 'Sanders',
#   'FN': 'Mary',
#   'MN': 'L',
#   'P': '7',
#   'AD': '184 Preston St, Hartford, CT-06114',
#   'CO': '0'},
#  '9946': {'NM': 'Anne Manusky',
#   'LN': 'Manusky',
#   'FN': 'Anne',
#   'MN': '',
#   'P': '15',
#   'AD': '20 Morning Glory Dr, Easton, CT-06612',
#   'CO': '0'},
#  '9947': {'NM': 'Eleni Kavros Degraw',
#   'LN': 'Degraw',
#   'FN': 'Eleni',
#   'MN': 'Kavros',
#   'P': '12',
#   'AD': '112 Westland Rd, Avon, CT-06001',
#   'CO': '0'},
#  '9948': {'NM': 'Shaun Mastroianni',
#   'LN': 'Mastroianni',
#   'FN': 'Shaun',
#   'MN': '',
#   'P': '3',
#   'AD': '5 Union St, Stonington, CT-06378',
#   'CO': '0'},
#  '9949': {'NM': 'Brian Lanoue',
#   'LN': 'Lanoue',
#   'FN': 'Brian',
#   'MN': '',
#   'P': '3',
#   'AD': '35 Kenwood Est, Griswold, CT-06351',
#   'CO': '0'},
#  '9950': {'NM': 'Manuel Bataguas',
#   'LN': 'Bataguas',
#   'FN': 'Manuel',
#   'MN': '',
#   'P': '6',
#   'AD': '36 Chatham Terrace, Bridgeport, CT-06606',
#   'CO': '0'},
#  '9951': {'NM': 'John J Flynn',
#   'LN': 'Flynn',
#   'FN': 'John',
#   'MN': 'J',
#   'P': '3',
#   'AD': '27 Quintard Ave, Norwalk, CT-06854',
#   'CO': '0'},
#  '9952': {'NM': 'Oz Griebel and Monte E Frank',
#   'LN': 'Griebel',
#   'FN': 'Oz',
#   'MN': '',
#   'P': '1045',
#   'AD': '266 Pearl St #210, Hartford, CT-06103',
#   'CO': '0'},
#  '9954': {'NM': 'Bob Stefanowski and Joe Markley',
#   'LN': 'Stefanowski',
#   'FN': 'Bob',
#   'MN': '',
#   'P': '3',
#   'AD': '1046 Boston Post Rd, Madison, CT-06443',
#   'CO': '4'},
#  '9955': {'NM': 'Rebekah Harriman-Stites',
#   'LN': 'Harriman-Stites',
#   'FN': 'Rebekah',
#   'MN': '',
#   'P': '12',
#   'AD': '5 Sealand Dr, Newtown, CT-06470',
#   'CO': '0'},
#  '9956': {'NM': 'Ruth Nadeau Dwyer',
#   'LN': 'Dwyer',
#   'FN': 'Ruth',
#   'MN': 'Nadeau',
#   'P': '1',
#   'AD': '223 Cedar Lane, Torrington, CT-06790',
#   'CO': '0'},
#  '9957': {'NM': 'Maria M Gladue',
#   'LN': 'Gladue',
#   'FN': 'Maria',
#   'MN': 'M',
#   'P': '1',
#   'AD': '61 Bushnell Hollow Road, Sprague, CT',
#   'CO': '0'},
#  '9958': {'NM': 'Jeannette C Brodeur',
#   'LN': 'Brodeur',
#   'FN': 'Jeannette',
#   'MN': 'C',
#   'P': '1',
#   'AD': '242 Bemis Street, Terryville, CT-06786',
#   'CO': '0'},
#  '9960': {'NM': 'Larry Groh Jr',
#   'LN': 'Groh Jr',
#   'FN': 'Larry',
#   'MN': '',
#   'P': '12',
#   'AD': '183 Wagher Rd, North Grosvenordale, CT-06255',
#   'CO': '0'},
#  '9961': {'NM': 'Elizabeth Schwebel',
#   'LN': 'Schwebel',
#   'FN': 'Elizabeth',
#   'MN': '',
#   'P': '12',
#   'AD': '110 Meeting House Lane, Ledyard, CT-06339',
#   'CO': '0'},
#  '9962': {'NM': 'Leslee B Hill',
#   'LN': 'Hill',
#   'FN': 'Leslee',
#   'MN': 'B',
#   'P': '3',
#   'AD': '91 Andrew Drive, Canton, CT-06019',
#   'CO': '0'},
#  '9964': {'NM': 'Ricky L Hayes',
#   'LN': 'Hayes',
#   'FN': 'Ricky',
#   'MN': 'L',
#   'P': '3',
#   'AD': '78 S Prospect St, Putnam, CT-06260',
#   'CO': '0'},
#  '9966': {'NM': 'Fred Camillo',
#   'LN': 'Camillo',
#   'FN': 'Fred',
#   'MN': '',
#   'P': '3',
#   'AD': '35 MacArthur Dr, Old Greenwich, CT-06870',
#   'CO': '0'},
#  '9967': {'NM': 'Brian N Gay',
#   'LN': 'Gay',
#   'FN': 'Brian',
#   'MN': 'N',
#   'P': '7',
#   'AD': '82 Main St, East Hampton, CT-06424',
#   'CO': '0'},
#  '9968': {'NM': 'Pamela Reinholtz',
#   'LN': 'Reinholtz',
#   'FN': 'Pamela',
#   'MN': '',
#   'P': '6',
#   'AD': '180 Pleasant View St, Griswold, CT-06351',
#   'CO': '0'},
#  '9971': {'NM': 'John Perrier',
#   'LN': 'Perrier',
#   'FN': 'John',
#   'MN': '',
#   'P': '12',
#   'AD': '18 Bradway Pond Rd, Stafford Springs, CT-06076',
#   'CO': '0'},
#  '9972': {'NM': 'John Perrier',
#   'LN': 'Perrier',
#   'FN': 'John',
#   'MN': '',
#   'P': '3',
#   'AD': '18 Bradway Pond Rd, Stafford Springs, CT-06076',
#   'CO': '0'},
#  '9974': {'NM': 'Robin E Comey',
#   'LN': 'Comey',
#   'FN': 'Robin',
#   'MN': 'E',
#   'P': '12',
#   'AD': '109 Shore Dr, Branford, CT-06405',
#   'CO': '0'},
#  '9975': {'NM': 'Timothy R Beeble',
#   'LN': 'Beeble',
#   'FN': 'Timothy',
#   'MN': 'R',
#   'P': '6',
#   'AD': '63 Grassy Plain St, Bethel, CT-06801',
#   'CO': '0'},
#  '9976': {'NM': 'Kathrine Stein',
#   'LN': 'Stein',
#   'FN': 'Kathrine',
#   'MN': '',
#   'P': '1',
#   'AD': '23 Cross Rd, Darien, CT-06820',
#   'CO': '0'},
#  '9977': {'NM': 'David Brown',
#   'LN': 'Brown',
#   'FN': 'David',
#   'MN': '',
#   'P': '6',
#   'AD': '15 Revere Rd, Darien, CT-06820',
#   'CO': '0'},
#  '9978': {'NM': 'Debra McGarry Ritchie',
#   'LN': 'McGarry Ritchie',
#   'FN': 'Debra',
#   'MN': '',
#   'P': '6',
#   'AD': '16 Stony Brook Rd South, Darien, CT-06820',
#   'CO': '0'},
#  '9979': {'NM': 'Joan V Davis',
#   'LN': 'Davis',
#   'FN': 'Joan',
#   'MN': 'V',
#   'P': '1033',
#   'AD': '29 Dubois St, Darien, CT-06820',
#   'CO': '0'},
#  '9980': {'NM': 'Joseph H Hardison, III',
#   'LN': 'Hardison, III',
#   'FN': 'Joseph',
#   'MN': 'J',
#   'P': '1033',
#   'AD': '11 Nearwater Ln, Darien, CT-06820',
#   'CO': '0'},
#  '9981': {'NM': 'Olive J Hauser',
#   'LN': 'Hauser',
#   'FN': 'Olive',
#   'MN': 'J',
#   'P': '1033',
#   'AD': '138 Hollow Tree Ridge Rd, Darien, CT-06820',
#   'CO': '0'},
#  '9982': {'NM': 'Michael G Heitz',
#   'LN': 'Heitz',
#   'FN': 'Michael',
#   'MN': 'G',
#   'P': '1033',
#   'AD': '4 Woodland Dr, Darien, CT-06820',
#   'CO': '0'},
#  '9983': {'NM': 'Sarah B Neumann',
#   'LN': 'Neumann',
#   'FN': 'Sarah',
#   'MN': 'B',
#   'P': '1033',
#   'AD': '94 Gardiner St, Darien, CT-06820',
#   'CO': '0'},
#  '9984': {'NM': 'Rolf C Obin',
#   'LN': 'Obin',
#   'FN': 'Rolf',
#   'MN': 'C',
#   'P': '1033',
#   'AD': '9 Archer Ln, Darien, CT-06820',
#   'CO': '0'},
#  '9985': {'NM': 'Brian J Rayhill',
#   'LN': 'Rayhill',
#   'FN': 'Brian',
#   'MN': 'J',
#   'P': '1033',
#   'AD': '6 Pleasant St, Darien, CT-06820',
#   'CO': '0'},
#  '9986': {'NM': 'Linda S Terhune',
#   'LN': 'Terhune',
#   'FN': 'Linda',
#   'MN': 'S',
#   'P': '1033',
#   'AD': '19 Patricia Ln, Darien, CT-06820',
#   'CO': '0'},
#  '9987': {'NM': 'Morgan B Whittier',
#   'LN': 'Whittier',
#   'FN': 'Morgan',
#   'MN': 'B',
#   'P': '1033',
#   'AD': '41 Walmsley Rd, Darien, CT-06820',
#   'CO': '0'},
#  '9988': {'NM': 'Mark R Adiletta',
#   'LN': 'Adiletta',
#   'FN': 'Mark',
#   'MN': 'R',
#   'P': '1033',
#   'AD': '69 Holly Ln, Darien, CT-06820',
#   'CO': '0'},
#  '9989': {'NM': 'David F Bayne',
#   'LN': 'Bayne',
#   'FN': 'David',
#   'MN': 'F',
#   'P': '1033',
#   'AD': '5 Windsor Rd, Darien, CT-06820',
#   'CO': '0'},
#  '9990': {'NM': 'John V Boulton',
#   'LN': 'Boulton',
#   'FN': 'John',
#   'MN': 'V',
#   'P': '1033',
#   'AD': '214 West Ave, Darien, CT-06820',
#   'CO': '0'},
#  '9991': {'NM': 'Janet F Grogan',
#   'LN': 'Grogan',
#   'FN': 'Janet',
#   'MN': 'F',
#   'P': '1033',
#   'AD': '137 Hollow Tree Rdge Rd #113, Darien, CT-06820',
#   'CO': '0'},
#  '9992': {'NM': 'Frederick R Hebert',
#   'LN': 'Hebert',
#   'FN': 'Frederick',
#   'MN': 'R',
#   'P': '1033',
#   'AD': '7 Tyler Dr, Darien, CT-06820',
#   'CO': '0'},
#  '9993': {'NM': 'Joanne K Hennessy',
#   'LN': 'Hennessy',
#   'FN': 'Joanne',
#   'MN': 'K',
#   'P': '1033',
#   'AD': '72 Holly Ln, Darien, CT-06820',
#   'CO': '0'},
#  '9994': {'NM': 'Lindsay Kelly',
#   'LN': 'Kelly',
#   'FN': 'Lindsay',
#   'MN': '',
#   'P': '1033',
#   'AD': '28 Intervale Rd, Darien, CT-06820',
#   'CO': '0'},
#  '9995': {'NM': 'David R Martin',
#   'LN': 'Martin',
#   'FN': 'David',
#   'MN': 'R',
#   'P': '1033',
#   'AD': '15 Libby Ln, Darien, CT-06820',
#   'CO': '0'},
#  '9996': {'NM': 'Laura R. Mosher',
#   'LN': 'Mosher',
#   'FN': 'Laura',
#   'MN': 'R',
#   'P': '1033',
#   'AD': '16 Edgerton St, Darien, CT-06820',
#   'CO': '0'},
#  '9997': {'NM': 'Sheila B Sherwood',
#   'LN': 'Sherwood',
#   'FN': 'Sheila',
#   'MN': 'B',
#   'P': '1033',
#   'AD': '266 Hollow Tree Rdge Rd, Darien, CT-06820',
#   'CO': '0'},
#  '9998': {'NM': 'Frank H Adelman',
#   'LN': 'Adelman',
#   'FN': 'Frank',
#   'MN': 'H',
#   'P': '1033',
#   'AD': '3 Harriett Lane East, Darien, CT-06820',
#   'CO': '0'},
#  '9999': {'NM': 'Carlo Cantavero',
#   'LN': 'Cantavero',
#   'FN': 'Carlo',
#   'MN': '',
#   'P': '1033',
#   'AD': '21 Pond Ln, Darien, CT-06820',
#   'CO': '0'},
#  '10000': {'NM': 'Edgar M Hawkins III',
#   'LN': 'Hawkins III',
#   'FN': 'Edgar',
#   'MN': 'M',
#   'P': '1033',
#   'AD': '65 Mansfield Ave, Darien, CT-06820',
#   'CO': '0'},
#  '10001': {'NM': 'Susan R Lauritzen',
#   'LN': 'Lauritzen',
#   'FN': 'Susan',
#   'MN': 'R',
#   'P': '1033',
#   'AD': '59 Hale Ln, Darien, CT-06820',
#   'CO': '0'},
#  '10002': {'NM': 'Richard Poli',
#   'LN': 'Poli',
#   'FN': 'Richard',
#   'MN': '',
#   'P': '1033',
#   'AD': '1 Little Brook Rd North, Darien, CT-06820',
#   'CO': '0'},
#  '10003': {'NM': 'Robert A Werner',
#   'LN': 'Werner',
#   'FN': 'Robert',
#   'MN': 'A',
#   'P': '1033',
#   'AD': '21 Bailey Ave, Darien, CT-06820',
#   'CO': '0'},
#  '10004': {'NM': 'Sarah M Baldwin',
#   'LN': 'Baldwin',
#   'FN': 'Sarah',
#   'MN': 'M',
#   'P': '1033',
#   'AD': '17 Maywood Rd, Darien, CT-06820',
#   'CO': '0'},
#  '10005': {'NM': 'Amy Barsanti',
#   'LN': 'Barsanti',
#   'FN': 'Amy',
#   'MN': '',
#   'P': '1033',
#   'AD': '16 Sunset Rd, Darien, CT-06820',
#   'CO': '0'},
#  '10006': {'NM': 'Taylor W Carter',
#   'LN': 'Carter',
#   'FN': 'Taylor',
#   'MN': 'W',
#   'P': '1033',
#   'AD': '385 Middlesex Rd, Darien, CT-06820',
#   'CO': '0'},
#  '10007': {'NM': 'Diane G Conologue',
#   'LN': 'Conologue',
#   'FN': 'Diane',
#   'MN': 'G',
#   'P': '1033',
#   'AD': '216 Leroy Ave, Darien, CT-06820',
#   'CO': '0'},
#  '10008': {'NM': 'Christopher Ezbiansky',
#   'LN': 'Ezbiansky',
#   'FN': 'Christopher',
#   'MN': '',
#   'P': '1033',
#   'AD': '2 Sylvan Rd, Darien, CT-06820',
#   'CO': '0'},
#  '10009': {'NM': 'Cassie Ann Mecsery',
#   'LN': 'Mecsery',
#   'FN': 'Cassie',
#   'MN': 'Ann',
#   'P': '1033',
#   'AD': '29 Indian Spring Trail, Darien, CT-06820',
#   'CO': '0'},
#  '10010': {'NM': 'Richard A Aponte',
#   'LN': 'Aponte',
#   'FN': 'Richard',
#   'MN': 'A',
#   'P': '1033',
#   'AD': '18 Wistar Court, Darien, CT-06820',
#   'CO': '0'},
#  '10011': {'NM': 'Vincent Arguimbau',
#   'LN': 'Arguimbau',
#   'FN': 'Vincent',
#   'MN': '',
#   'P': '1033',
#   'AD': '69 Salem Straits, Darien, CT-06820',
#   'CO': '0'},
#  '10012': {'NM': 'Elisabeth C Bacon',
#   'LN': 'Bacon',
#   'FN': 'Elisabeth',
#   'MN': 'C',
#   'P': '1033',
#   'AD': '59 Delafield Island Rd, Darien, CT-06820',
#   'CO': '0'},
#  '10013': {'NM': 'James Henry Howe',
#   'LN': 'Howe',
#   'FN': 'James',
#   'MN': 'Henry',
#   'P': '1033',
#   'AD': '52 Old Farm Rd, Darien, CT-06820',
#   'CO': '0'},
#  '10014': {'NM': 'Cheryl Russell',
#   'LN': 'Russell',
#   'FN': 'Cheryl',
#   'MN': '',
#   'P': '1033',
#   'AD': '18 Fitch Ave, Darien, CT-06820',
#   'CO': '0'},
#  '10015': {'NM': 'Clara C Sartori',
#   'LN': 'Sartori',
#   'FN': 'Clara',
#   'MN': 'C',
#   'P': '1033',
#   'AD': '161 Old Kings Highway South, Darien, CT-06820',
#   'CO': '0'},
#  '10016': {'NM': 'Barbara L Thorne',
#   'LN': 'Thorne',
#   'FN': 'Barbara',
#   'MN': 'L',
#   'P': '1033',
#   'AD': '37 Dickinson Rd, Darien, CT-06820',
#   'CO': '0'},
#  '10017': {'NM': 'Michael C Wheeler',
#   'LN': 'Wheeler',
#   'FN': 'Michael',
#   'MN': 'C',
#   'P': '1033',
#   'AD': '8 Tory Hole Rd, Darien, CT-06820',
#   'CO': '0'},
#  '10018': {'NM': 'Penelope Wilson',
#   'LN': 'Wilson',
#   'FN': 'Penelope',
#   'MN': '',
#   'P': '1033',
#   'AD': '44 Andrews Dr, Darien, CT-06820',
#   'CO': '0'},
#  '10019': {'NM': 'Jack H Davis',
#   'LN': 'Davis',
#   'FN': 'Jack',
#   'MN': 'H',
#   'P': '1033',
#   'AD': '197 Hoyt St, Darien, CT-06820',
#   'CO': '0'},
#  '10020': {'NM': 'Elise Feldman',
#   'LN': 'Feldman',
#   'FN': 'Elise',
#   'MN': '',
#   'P': '1033',
#   'AD': '24 Greenwood Ave, Darien, CT-06820',
#   'CO': '0'},
#  '10021': {'NM': 'Petr Marousek',
#   'LN': 'Marousek',
#   'FN': 'Petr',
#   'MN': '',
#   'P': '1033',
#   'AD': '36 Lake Dr, Darien, CT-06820',
#   'CO': '0'},
#  '10022': {'NM': 'Edward A Washecka',
#   'LN': 'Washecka',
#   'FN': 'Edward',
#   'MN': 'A',
#   'P': '1033',
#   'AD': '7 Leeuwarden Ln, Darien, CT-06820',
#   'CO': '0'},
#  '10023': {'NM': 'Lisa Yarnell',
#   'LN': 'Yarnell',
#   'FN': 'Lisa',
#   'MN': '',
#   'P': '1033',
#   'AD': '15 Kensett Ln, Darien, CT-06820',
#   'CO': '0'},
#  '10024': {'NM': 'Scott Zimmerman',
#   'LN': 'Zimmerman',
#   'FN': 'Scott',
#   'MN': '',
#   'P': '1033',
#   'AD': '14 Hillcrest Ave, Darien, CT-06820',
#   'CO': '0'},
#  '10025': {'NM': 'Ned Lamont and Susan Bysiewicz',
#   'LN': 'Lamont',
#   'FN': 'Ned',
#   'MN': '',
#   'P': '12',
#   'AD': '4 Ashton Dr, Greenwich, CT-06831',
#   'CO': '0'},
#  '10028': {'NM': 'David Mannis',
#   'LN': 'Mannis',
#   'FN': 'David',
#   'MN': 'A',
#   'P': '1',
#   'AD': '34 Greenbriar Lane, Stamford, CT-06903',
#   'CO': '0'},
#  '10029': {'NM': 'Jon Carlo Gallup',
#   'LN': 'Gallup',
#   'FN': 'Jon',
#   'MN': 'Carlo',
#   'P': '1',
#   'AD': '21 Dartley Street, Stamford, CT-06905',
#   'CO': '2'},
#  '10030': {'NM': 'Jackie Pioli',
#   'LN': 'Pioli',
#   'FN': 'Jacki',
#   'MN': '',
#   'P': '1',
#   'AD': '25 Glenbrook Road, Unit 335, Stamford, CT-06902',
#   'CO': '3'},
#  '10031': {'NM': 'Frank Cerasoli',
#   'LN': 'Cerasoli',
#   'FN': 'Frank',
#   'MN': '',
#   'P': '15',
#   'AD': '25 Todd Lane, Stamford, CT-06905',
#   'CO': '0'},
#  '10032': {'NM': 'Mike Altamura',
#   'LN': 'Altamura',
#   'FN': 'Mike',
#   'MN': '',
#   'P': '15',
#   'AD': '1603 Newfield Avenue, Stamford, CT-06905',
#   'CO': '0'},
#  '10033': {'NM': 'L Scott Frantz',
#   'LN': 'Frantz',
#   'FN': 'L Scott',
#   'MN': '',
#   'P': '3',
#   'AD': '123 Meadow Rd, Riverside, CT-06878',
#   'CO': '0'},
#  '10034': {'NM': 'John H Frey',
#   'LN': 'Frey',
#   'FN': 'John',
#   'MN': 'H',
#   'P': '3',
#   'AD': '193 Wilton Road West, Ridgefield, CT-06877',
#   'CO': '0'},
#  '10035': {'NM': 'Kristi L Sogofsky',
#   'LN': 'Sogofsky',
#   'FN': 'Kristi',
#   'MN': 'L',
#   'P': '6',
#   'AD': '181 Adams Road, Easton, CT-06612',
#   'CO': '0'},
#  '10036': {'NM': 'Ira Kaplan',
#   'LN': 'Kaplan',
#   'FN': 'Ira',
#   'MN': '',
#   'P': '1',
#   'AD': '14 Morning Glory Road, Easton, CT-06612',
#   'CO': '0'},
#  '10037': {'NM': 'Michael Schmidt',
#   'LN': 'Schmidt',
#   'FN': 'Michael',
#   'MN': '',
#   'P': '7',
#   'AD': '50 Constance Lane, Stamford, CT-06903',
#   'CO': '0'},
#  '10038': {'NM': 'Patrice M Peterson',
#   'LN': 'Peterson',
#   'FN': 'Patrice',
#   'MN': 'M',
#   'P': '1',
#   'AD': '212 Warrenton Ave, West Hartford, CT-06119',
#   'CO': '0'},
#  '10039': {'NM': 'Mark Stewart Greenstein and John Demitrus',
#   'LN': 'Greenstein',
#   'FN': 'Mark',
#   'MN': 'Stewart',
#   'P': '1046',
#   'AD': '381 S Main St, West Hartford, CT-06107',
#   'CO': '0'},
#  ...}

# %%
def get_candidate(e_data, candidate_id):
    
    return e_data["lookup_data"]["candidateIds"][candidate_id]

def get_candidate_party_name(e_data, candidate_id):
    
    return get_party_name(e_data, get_candidate(e_data, candidate_id)["P"])

def get_candidate_name(e_data, candidate_id):
    
    return get_candidate(e_data, candidate_id)["NM"]

print (get_candidate_party_name(general_2018,'8701'))
print (get_candidate_name(general_2018, '8701'))
# Out:
# Democratic Party
# Caitlin Riley

# %%
general_2018["lookup_data"]["officeList"]
# Out:
# [{'2901': {'ID': '2901',
#    'NM': 'Governor and Lieutenant Governor',
#    'OT': 'SW',
#    'OO': '1',
#    'DT': '',
#    'D': '0'}},
#  {'2903': {'ID': '2903',
#    'NM': 'United States Senator',
#    'OT': 'SW',
#    'OO': '2',
#    'DT': '',
#    'D': '0'}},
#  {'2910': {'ID': '2910',
#    'NM': 'Representative in Congress 01',
#    'OT': 'C',
#    'OO': '3',
#    'DT': 'Connecticut 01',
#    'D': '1'}},
#  {'2911': {'ID': '2911',
#    'NM': 'Representative in Congress 02',
#    'OT': 'C',
#    'OO': '4',
#    'DT': 'Connecticut 02',
#    'D': '2'}},
#  {'2912': {'ID': '2912',
#    'NM': 'Representative in Congress 03',
#    'OT': 'C',
#    'OO': '5',
#    'DT': 'Connecticut 03',
#    'D': '3'}},
#  {'2913': {'ID': '2913',
#    'NM': 'Representative in Congress 04',
#    'OT': 'C',
#    'OO': '6',
#    'DT': 'Connecticut 04',
#    'D': '4'}},
#  {'2914': {'ID': '2914',
#    'NM': 'Representative in Congress 05',
#    'OT': 'C',
#    'OO': '7',
#    'DT': 'Connecticut 05',
#    'D': '5'}},
#  {'2915': {'ID': '2915',
#    'NM': 'State Senator 01',
#    'OT': 'S',
#    'OO': '8',
#    'DT': 'Connecticut 01',
#    'D': '1'}},
#  {'3182': {'ID': '3182',
#    'NM': 'State Senator 02',
#    'OT': 'S',
#    'OO': '9',
#    'DT': 'Connecticut 02',
#    'D': '2'}},
#  {'2917': {'ID': '2917',
#    'NM': 'State Senator 03',
#    'OT': 'S',
#    'OO': '10',
#    'DT': 'Connecticut 03',
#    'D': '3'}},
#  {'2918': {'ID': '2918',
#    'NM': 'State Senator 04',
#    'OT': 'S',
#    'OO': '11',
#    'DT': 'Connecticut 04',
#    'D': '4'}},
#  {'2919': {'ID': '2919',
#    'NM': 'State Senator 05',
#    'OT': 'S',
#    'OO': '12',
#    'DT': 'Connecticut 05',
#    'D': '5'}},
#  {'2920': {'ID': '2920',
#    'NM': 'State Senator 06',
#    'OT': 'S',
#    'OO': '13',
#    'DT': 'Connecticut 06',
#    'D': '6'}},
#  {'2921': {'ID': '2921',
#    'NM': 'State Senator 07',
#    'OT': 'S',
#    'OO': '14',
#    'DT': 'Connecticut 07',
#    'D': '7'}},
#  {'2922': {'ID': '2922',
#    'NM': 'State Senator 08',
#    'OT': 'S',
#    'OO': '15',
#    'DT': 'Connecticut 08',
#    'D': '8'}},
#  {'2923': {'ID': '2923',
#    'NM': 'State Senator 09',
#    'OT': 'S',
#    'OO': '16',
#    'DT': 'Connecticut 09',
#    'D': '9'}},
#  {'2924': {'ID': '2924',
#    'NM': 'State Senator 10',
#    'OT': 'S',
#    'OO': '17',
#    'DT': 'Connecticut 10',
#    'D': '10'}},
#  {'2925': {'ID': '2925',
#    'NM': 'State Senator 11',
#    'OT': 'S',
#    'OO': '18',
#    'DT': 'Connecticut 11',
#    'D': '11'}},
#  {'2926': {'ID': '2926',
#    'NM': 'State Senator 12',
#    'OT': 'S',
#    'OO': '19',
#    'DT': 'Connecticut 12',
#    'D': '12'}},
#  {'2927': {'ID': '2927',
#    'NM': 'State Senator 13',
#    'OT': 'S',
#    'OO': '20',
#    'DT': 'Connecticut 13',
#    'D': '13'}},
#  {'2928': {'ID': '2928',
#    'NM': 'State Senator 14',
#    'OT': 'S',
#    'OO': '21',
#    'DT': 'Connecticut 14',
#    'D': '14'}},
#  {'2929': {'ID': '2929',
#    'NM': 'State Senator 15',
#    'OT': 'S',
#    'OO': '22',
#    'DT': 'Connecticut 15',
#    'D': '15'}},
#  {'2930': {'ID': '2930',
#    'NM': 'State Senator 16',
#    'OT': 'S',
#    'OO': '23',
#    'DT': 'Connecticut 16',
#    'D': '16'}},
#  {'2931': {'ID': '2931',
#    'NM': 'State Senator 17',
#    'OT': 'S',
#    'OO': '24',
#    'DT': 'Connecticut 17',
#    'D': '17'}},
#  {'2932': {'ID': '2932',
#    'NM': 'State Senator 18',
#    'OT': 'S',
#    'OO': '25',
#    'DT': 'Connecticut 18',
#    'D': '18'}},
#  {'2933': {'ID': '2933',
#    'NM': 'State Senator 19',
#    'OT': 'S',
#    'OO': '26',
#    'DT': 'Connecticut 19',
#    'D': '19'}},
#  {'2934': {'ID': '2934',
#    'NM': 'State Senator 20',
#    'OT': 'S',
#    'OO': '27',
#    'DT': 'Connecticut 20',
#    'D': '20'}},
#  {'2935': {'ID': '2935',
#    'NM': 'State Senator 21',
#    'OT': 'S',
#    'OO': '28',
#    'DT': 'Connecticut 21',
#    'D': '21'}},
#  {'2936': {'ID': '2936',
#    'NM': 'State Senator 22',
#    'OT': 'S',
#    'OO': '29',
#    'DT': 'Connecticut 22',
#    'D': '22'}},
#  {'2937': {'ID': '2937',
#    'NM': 'State Senator 23',
#    'OT': 'S',
#    'OO': '30',
#    'DT': 'Connecticut 23',
#    'D': '23'}},
#  {'2938': {'ID': '2938',
#    'NM': 'State Senator 24',
#    'OT': 'S',
#    'OO': '31',
#    'DT': 'Connecticut 24',
#    'D': '24'}},
#  {'2939': {'ID': '2939',
#    'NM': 'State Senator 25',
#    'OT': 'S',
#    'OO': '32',
#    'DT': 'Connecticut 25',
#    'D': '25'}},
#  {'2940': {'ID': '2940',
#    'NM': 'State Senator 26',
#    'OT': 'S',
#    'OO': '33',
#    'DT': 'Connecticut 26',
#    'D': '26'}},
#  {'2941': {'ID': '2941',
#    'NM': 'State Senator 27',
#    'OT': 'S',
#    'OO': '34',
#    'DT': 'Connecticut 27',
#    'D': '27'}},
#  {'2942': {'ID': '2942',
#    'NM': 'State Senator 28',
#    'OT': 'S',
#    'OO': '35',
#    'DT': 'Connecticut 28',
#    'D': '28'}},
#  {'2943': {'ID': '2943',
#    'NM': 'State Senator 29',
#    'OT': 'S',
#    'OO': '36',
#    'DT': 'Connecticut 29',
#    'D': '29'}},
#  {'2944': {'ID': '2944',
#    'NM': 'State Senator 30',
#    'OT': 'S',
#    'OO': '37',
#    'DT': 'Connecticut 30',
#    'D': '30'}},
#  {'2945': {'ID': '2945',
#    'NM': 'State Senator 31',
#    'OT': 'S',
#    'OO': '38',
#    'DT': 'Connecticut 31',
#    'D': '31'}},
#  {'2946': {'ID': '2946',
#    'NM': 'State Senator 32',
#    'OT': 'S',
#    'OO': '39',
#    'DT': 'Connecticut 32',
#    'D': '32'}},
#  {'2947': {'ID': '2947',
#    'NM': 'State Senator 33',
#    'OT': 'S',
#    'OO': '40',
#    'DT': 'Connecticut 33',
#    'D': '33'}},
#  {'2948': {'ID': '2948',
#    'NM': 'State Senator 34',
#    'OT': 'S',
#    'OO': '41',
#    'DT': 'Connecticut 34',
#    'D': '34'}},
#  {'2949': {'ID': '2949',
#    'NM': 'State Senator 35',
#    'OT': 'S',
#    'OO': '42',
#    'DT': 'Connecticut 35',
#    'D': '35'}},
#  {'2950': {'ID': '2950',
#    'NM': 'State Senator 36',
#    'OT': 'S',
#    'OO': '43',
#    'DT': 'Connecticut 36',
#    'D': '36'}},
#  {'2951': {'ID': '2951',
#    'NM': 'State Representative 01',
#    'OT': 'A',
#    'OO': '44',
#    'DT': 'Connecticut 01',
#    'D': '1'}},
#  {'3068': {'ID': '3068',
#    'NM': 'State Representative 02',
#    'OT': 'A',
#    'OO': '45',
#    'DT': 'Connecticut 02',
#    'D': '2'}},
#  {'3079': {'ID': '3079',
#    'NM': 'State Representative 03',
#    'OT': 'A',
#    'OO': '46',
#    'DT': 'Connecticut 03',
#    'D': '3'}},
#  {'3083': {'ID': '3083',
#    'NM': 'State Representative 04',
#    'OT': 'A',
#    'OO': '47',
#    'DT': 'Connecticut 04',
#    'D': '4'}},
#  {'3086': {'ID': '3086',
#    'NM': 'State Representative 05',
#    'OT': 'A',
#    'OO': '48',
#    'DT': 'Connecticut 05',
#    'D': '5'}},
#  {'3089': {'ID': '3089',
#    'NM': 'State Representative 06',
#    'OT': 'A',
#    'OO': '49',
#    'DT': 'Connecticut 06',
#    'D': '6'}},
#  {'3092': {'ID': '3092',
#    'NM': 'State Representative 07',
#    'OT': 'A',
#    'OO': '50',
#    'DT': 'Connecticut 07',
#    'D': '7'}},
#  {'3094': {'ID': '3094',
#    'NM': 'State Representative 08',
#    'OT': 'A',
#    'OO': '51',
#    'DT': 'Connecticut 08',
#    'D': '8'}},
#  {'3097': {'ID': '3097',
#    'NM': 'State Representative 09',
#    'OT': 'A',
#    'OO': '52',
#    'DT': 'Connecticut 09',
#    'D': '9'}},
#  {'3102': {'ID': '3102',
#    'NM': 'State Representative 10',
#    'OT': 'A',
#    'OO': '53',
#    'DT': 'Connecticut 10',
#    'D': '10'}},
#  {'3103': {'ID': '3103',
#    'NM': 'State Representative 11',
#    'OT': 'A',
#    'OO': '54',
#    'DT': 'Connecticut 11',
#    'D': '11'}},
#  {'3104': {'ID': '3104',
#    'NM': 'State Representative 12',
#    'OT': 'A',
#    'OO': '55',
#    'DT': 'Connecticut 12',
#    'D': '12'}},
#  {'3105': {'ID': '3105',
#    'NM': 'State Representative 13',
#    'OT': 'A',
#    'OO': '56',
#    'DT': 'Connecticut 13',
#    'D': '13'}},
#  {'3106': {'ID': '3106',
#    'NM': 'State Representative 14',
#    'OT': 'A',
#    'OO': '57',
#    'DT': 'Connecticut 14',
#    'D': '14'}},
#  {'3107': {'ID': '3107',
#    'NM': 'State Representative 15',
#    'OT': 'A',
#    'OO': '58',
#    'DT': 'Connecticut 15',
#    'D': '15'}},
#  {'3108': {'ID': '3108',
#    'NM': 'State Representative 16',
#    'OT': 'A',
#    'OO': '59',
#    'DT': 'Connecticut 16',
#    'D': '16'}},
#  {'3109': {'ID': '3109',
#    'NM': 'State Representative 17',
#    'OT': 'A',
#    'OO': '60',
#    'DT': 'Connecticut 17',
#    'D': '17'}},
#  {'3110': {'ID': '3110',
#    'NM': 'State Representative 18',
#    'OT': 'A',
#    'OO': '61',
#    'DT': 'Connecticut 18',
#    'D': '18'}},
#  {'3123': {'ID': '3123',
#    'NM': 'State Representative 19',
#    'OT': 'A',
#    'OO': '62',
#    'DT': 'Connecticut 19',
#    'D': '19'}},
#  {'3124': {'ID': '3124',
#    'NM': 'State Representative 20',
#    'OT': 'A',
#    'OO': '63',
#    'DT': 'Connecticut 20',
#    'D': '20'}},
#  {'3125': {'ID': '3125',
#    'NM': 'State Representative 21',
#    'OT': 'A',
#    'OO': '64',
#    'DT': 'Connecticut 21',
#    'D': '21'}},
#  {'3126': {'ID': '3126',
#    'NM': 'State Representative 22',
#    'OT': 'A',
#    'OO': '65',
#    'DT': 'Connecticut 22',
#    'D': '22'}},
#  {'3127': {'ID': '3127',
#    'NM': 'State Representative 23',
#    'OT': 'A',
#    'OO': '66',
#    'DT': 'Connecticut 23',
#    'D': '23'}},
#  {'3128': {'ID': '3128',
#    'NM': 'State Representative 24',
#    'OT': 'A',
#    'OO': '67',
#    'DT': 'Connecticut 24',
#    'D': '24'}},
#  {'3129': {'ID': '3129',
#    'NM': 'State Representative 25',
#    'OT': 'A',
#    'OO': '68',
#    'DT': 'Connecticut 25',
#    'D': '25'}},
#  {'3130': {'ID': '3130',
#    'NM': 'State Representative 26',
#    'OT': 'A',
#    'OO': '69',
#    'DT': 'Connecticut 26',
#    'D': '26'}},
#  {'3131': {'ID': '3131',
#    'NM': 'State Representative 27',
#    'OT': 'A',
#    'OO': '70',
#    'DT': 'Connecticut 27',
#    'D': '27'}},
#  {'3132': {'ID': '3132',
#    'NM': 'State Representative 28',
#    'OT': 'A',
#    'OO': '71',
#    'DT': 'Connecticut 28',
#    'D': '28'}},
#  {'3133': {'ID': '3133',
#    'NM': 'State Representative 29',
#    'OT': 'A',
#    'OO': '72',
#    'DT': 'Connecticut 29',
#    'D': '29'}},
#  {'3134': {'ID': '3134',
#    'NM': 'State Representative 30',
#    'OT': 'A',
#    'OO': '73',
#    'DT': 'Connecticut 30',
#    'D': '30'}},
#  {'3135': {'ID': '3135',
#    'NM': 'State Representative 31',
#    'OT': 'A',
#    'OO': '74',
#    'DT': 'Connecticut 31',
#    'D': '31'}},
#  {'3136': {'ID': '3136',
#    'NM': 'State Representative 32',
#    'OT': 'A',
#    'OO': '75',
#    'DT': 'Connecticut 32',
#    'D': '32'}},
#  {'3137': {'ID': '3137',
#    'NM': 'State Representative 33',
#    'OT': 'A',
#    'OO': '76',
#    'DT': 'Connecticut 33',
#    'D': '33'}},
#  {'3138': {'ID': '3138',
#    'NM': 'State Representative 34',
#    'OT': 'A',
#    'OO': '77',
#    'DT': 'Connecticut 34',
#    'D': '34'}},
#  {'3139': {'ID': '3139',
#    'NM': 'State Representative 35',
#    'OT': 'A',
#    'OO': '78',
#    'DT': 'Connecticut 35',
#    'D': '35'}},
#  {'3140': {'ID': '3140',
#    'NM': 'State Representative 36',
#    'OT': 'A',
#    'OO': '79',
#    'DT': 'Connecticut 36',
#    'D': '36'}},
#  {'3141': {'ID': '3141',
#    'NM': 'State Representative 37',
#    'OT': 'A',
#    'OO': '80',
#    'DT': 'Connecticut 37',
#    'D': '37'}},
#  {'3142': {'ID': '3142',
#    'NM': 'State Representative 38',
#    'OT': 'A',
#    'OO': '81',
#    'DT': 'Connecticut 38',
#    'D': '38'}},
#  {'3143': {'ID': '3143',
#    'NM': 'State Representative 39',
#    'OT': 'A',
#    'OO': '82',
#    'DT': 'Connecticut 39',
#    'D': '39'}},
#  {'3144': {'ID': '3144',
#    'NM': 'State Representative 40',
#    'OT': 'A',
#    'OO': '83',
#    'DT': 'Connecticut 40',
#    'D': '40'}},
#  {'3145': {'ID': '3145',
#    'NM': 'State Representative 41',
#    'OT': 'A',
#    'OO': '84',
#    'DT': 'Connecticut 41',
#    'D': '41'}},
#  {'3146': {'ID': '3146',
#    'NM': 'State Representative 42',
#    'OT': 'A',
#    'OO': '85',
#    'DT': 'Connecticut 42',
#    'D': '42'}},
#  {'3147': {'ID': '3147',
#    'NM': 'State Representative 43',
#    'OT': 'A',
#    'OO': '86',
#    'DT': 'Connecticut 43',
#    'D': '43'}},
#  {'3148': {'ID': '3148',
#    'NM': 'State Representative 44',
#    'OT': 'A',
#    'OO': '87',
#    'DT': 'Connecticut 44',
#    'D': '44'}},
#  {'3149': {'ID': '3149',
#    'NM': 'State Representative 45',
#    'OT': 'A',
#    'OO': '88',
#    'DT': 'Connecticut 45',
#    'D': '45'}},
#  {'3150': {'ID': '3150',
#    'NM': 'State Representative 46',
#    'OT': 'A',
#    'OO': '89',
#    'DT': 'Connecticut 46',
#    'D': '46'}},
#  {'3151': {'ID': '3151',
#    'NM': 'State Representative 47',
#    'OT': 'A',
#    'OO': '90',
#    'DT': 'Connecticut 47',
#    'D': '47'}},
#  {'3152': {'ID': '3152',
#    'NM': 'State Representative 48',
#    'OT': 'A',
#    'OO': '91',
#    'DT': 'Connecticut 48',
#    'D': '48'}},
#  {'3153': {'ID': '3153',
#    'NM': 'State Representative 49',
#    'OT': 'A',
#    'OO': '92',
#    'DT': 'Connecticut 49',
#    'D': '49'}},
#  {'3154': {'ID': '3154',
#    'NM': 'State Representative 50',
#    'OT': 'A',
#    'OO': '93',
#    'DT': 'Connecticut 50',
#    'D': '50'}},
#  {'3155': {'ID': '3155',
#    'NM': 'State Representative 51',
#    'OT': 'A',
#    'OO': '94',
#    'DT': 'Connecticut 51',
#    'D': '51'}},
#  {'3156': {'ID': '3156',
#    'NM': 'State Representative 52',
#    'OT': 'A',
#    'OO': '95',
#    'DT': 'Connecticut 52',
#    'D': '52'}},
#  {'3157': {'ID': '3157',
#    'NM': 'State Representative 53',
#    'OT': 'A',
#    'OO': '96',
#    'DT': 'Connecticut 53',
#    'D': '53'}},
#  {'3158': {'ID': '3158',
#    'NM': 'State Representative 54',
#    'OT': 'A',
#    'OO': '97',
#    'DT': 'Connecticut 54',
#    'D': '54'}},
#  {'3159': {'ID': '3159',
#    'NM': 'State Representative 55',
#    'OT': 'A',
#    'OO': '98',
#    'DT': 'Connecticut 55',
#    'D': '55'}},
#  {'3160': {'ID': '3160',
#    'NM': 'State Representative 56',
#    'OT': 'A',
#    'OO': '99',
#    'DT': 'Connecticut 56',
#    'D': '56'}},
#  {'3161': {'ID': '3161',
#    'NM': 'State Representative 57',
#    'OT': 'A',
#    'OO': '100',
#    'DT': 'Connecticut 57',
#    'D': '57'}},
#  {'3162': {'ID': '3162',
#    'NM': 'State Representative 58',
#    'OT': 'A',
#    'OO': '101',
#    'DT': 'Connecticut 58',
#    'D': '58'}},
#  {'3163': {'ID': '3163',
#    'NM': 'State Representative 59',
#    'OT': 'A',
#    'OO': '102',
#    'DT': 'Connecticut 59',
#    'D': '59'}},
#  {'3164': {'ID': '3164',
#    'NM': 'State Representative 60',
#    'OT': 'A',
#    'OO': '103',
#    'DT': 'Connecticut 60',
#    'D': '60'}},
#  {'3165': {'ID': '3165',
#    'NM': 'State Representative 61',
#    'OT': 'A',
#    'OO': '104',
#    'DT': 'Connecticut 61',
#    'D': '61'}},
#  {'3166': {'ID': '3166',
#    'NM': 'State Representative 62',
#    'OT': 'A',
#    'OO': '105',
#    'DT': 'Connecticut 62',
#    'D': '62'}},
#  {'3167': {'ID': '3167',
#    'NM': 'State Representative 63',
#    'OT': 'A',
#    'OO': '106',
#    'DT': 'Connecticut 63',
#    'D': '63'}},
#  {'3168': {'ID': '3168',
#    'NM': 'State Representative 64',
#    'OT': 'A',
#    'OO': '107',
#    'DT': 'Connecticut 64',
#    'D': '64'}},
#  {'3169': {'ID': '3169',
#    'NM': 'State Representative 65',
#    'OT': 'A',
#    'OO': '108',
#    'DT': 'Connecticut 65',
#    'D': '65'}},
#  {'3170': {'ID': '3170',
#    'NM': 'State Representative 66',
#    'OT': 'A',
#    'OO': '109',
#    'DT': 'Connecticut 66',
#    'D': '66'}},
#  {'3171': {'ID': '3171',
#    'NM': 'State Representative 67',
#    'OT': 'A',
#    'OO': '110',
#    'DT': 'Connecticut 67',
#    'D': '67'}},
#  {'3172': {'ID': '3172',
#    'NM': 'State Representative 68',
#    'OT': 'A',
#    'OO': '111',
#    'DT': 'Connecticut 68',
#    'D': '68'}},
#  {'3173': {'ID': '3173',
#    'NM': 'State Representative 69',
#    'OT': 'A',
#    'OO': '112',
#    'DT': 'Connecticut 69',
#    'D': '69'}},
#  {'3174': {'ID': '3174',
#    'NM': 'State Representative 70',
#    'OT': 'A',
#    'OO': '113',
#    'DT': 'Connecticut 70',
#    'D': '70'}},
#  {'3175': {'ID': '3175',
#    'NM': 'State Representative 71',
#    'OT': 'A',
#    'OO': '114',
#    'DT': 'Connecticut 71',
#    'D': '71'}},
#  {'3176': {'ID': '3176',
#    'NM': 'State Representative 72',
#    'OT': 'A',
#    'OO': '115',
#    'DT': 'Connecticut 72',
#    'D': '72'}},
#  {'3177': {'ID': '3177',
#    'NM': 'State Representative 73',
#    'OT': 'A',
#    'OO': '116',
#    'DT': 'Connecticut 73',
#    'D': '73'}},
#  {'3178': {'ID': '3178',
#    'NM': 'State Representative 74',
#    'OT': 'A',
#    'OO': '117',
#    'DT': 'Connecticut 74',
#    'D': '74'}},
#  {'3179': {'ID': '3179',
#    'NM': 'State Representative 75',
#    'OT': 'A',
#    'OO': '118',
#    'DT': 'Connecticut 75',
#    'D': '75'}},
#  {'2985': {'ID': '2985',
#    'NM': 'State Representative 76',
#    'OT': 'A',
#    'OO': '119',
#    'DT': 'Connecticut 76',
#    'D': '76'}},
#  {'2983': {'ID': '2983',
#    'NM': 'State Representative 77',
#    'OT': 'A',
#    'OO': '120',
#    'DT': 'Connecticut 77',
#    'D': '77'}},
#  {'2981': {'ID': '2981',
#    'NM': 'State Representative 78',
#    'OT': 'A',
#    'OO': '121',
#    'DT': 'Connecticut 78',
#    'D': '78'}},
#  {'2986': {'ID': '2986',
#    'NM': 'State Representative 79',
#    'OT': 'A',
#    'OO': '122',
#    'DT': 'Connecticut 79',
#    'D': '79'}},
#  {'2987': {'ID': '2987',
#    'NM': 'State Representative 80',
#    'OT': 'A',
#    'OO': '123',
#    'DT': 'Connecticut 80',
#    'D': '80'}},
#  {'2989': {'ID': '2989',
#    'NM': 'State Representative 81',
#    'OT': 'A',
#    'OO': '124',
#    'DT': 'Connecticut 81',
#    'D': '81'}},
#  {'2991': {'ID': '2991',
#    'NM': 'State Representative 82',
#    'OT': 'A',
#    'OO': '125',
#    'DT': 'Connecticut 82',
#    'D': '82'}},
#  {'2993': {'ID': '2993',
#    'NM': 'State Representative 83',
#    'OT': 'A',
#    'OO': '126',
#    'DT': 'Connecticut 83',
#    'D': '83'}},
#  {'2996': {'ID': '2996',
#    'NM': 'State Representative 84',
#    'OT': 'A',
#    'OO': '127',
#    'DT': 'Connecticut 84',
#    'D': '84'}},
#  {'2998': {'ID': '2998',
#    'NM': 'State Representative 85',
#    'OT': 'A',
#    'OO': '128',
#    'DT': 'Connecticut 85',
#    'D': '85'}},
#  {'3001': {'ID': '3001',
#    'NM': 'State Representative 86',
#    'OT': 'A',
#    'OO': '129',
#    'DT': 'Connecticut 86',
#    'D': '86'}},
#  {'3002': {'ID': '3002',
#    'NM': 'State Representative 87',
#    'OT': 'A',
#    'OO': '130',
#    'DT': 'Connecticut 87',
#    'D': '87'}},
#  {'3004': {'ID': '3004',
#    'NM': 'State Representative 88',
#    'OT': 'A',
#    'OO': '131',
#    'DT': 'Connecticut 88',
#    'D': '88'}},
#  {'3005': {'ID': '3005',
#    'NM': 'State Representative 89',
#    'OT': 'A',
#    'OO': '132',
#    'DT': 'Connecticut 89',
#    'D': '89'}},
#  {'3006': {'ID': '3006',
#    'NM': 'State Representative 90',
#    'OT': 'A',
#    'OO': '133',
#    'DT': 'Connecticut 90',
#    'D': '90'}},
#  {'3008': {'ID': '3008',
#    'NM': 'State Representative 91',
#    'OT': 'A',
#    'OO': '134',
#    'DT': 'Connecticut 91',
#    'D': '91'}},
#  {'3012': {'ID': '3012',
#    'NM': 'State Representative 92',
#    'OT': 'A',
#    'OO': '135',
#    'DT': 'Connecticut 92',
#    'D': '92'}},
#  {'3015': {'ID': '3015',
#    'NM': 'State Representative 93',
#    'OT': 'A',
#    'OO': '136',
#    'DT': 'Connecticut 93',
#    'D': '93'}},
#  {'3020': {'ID': '3020',
#    'NM': 'State Representative 94',
#    'OT': 'A',
#    'OO': '137',
#    'DT': 'Connecticut 94',
#    'D': '94'}},
#  {'3023': {'ID': '3023',
#    'NM': 'State Representative 95',
#    'OT': 'A',
#    'OO': '138',
#    'DT': 'Connecticut 95',
#    'D': '95'}},
#  {'3025': {'ID': '3025',
#    'NM': 'State Representative 96',
#    'OT': 'A',
#    'OO': '139',
#    'DT': 'Connecticut 96',
#    'D': '96'}},
#  {'3028': {'ID': '3028',
#    'NM': 'State Representative 97',
#    'OT': 'A',
#    'OO': '140',
#    'DT': 'Connecticut 97',
#    'D': '97'}},
#  {'3030': {'ID': '3030',
#    'NM': 'State Representative 98',
#    'OT': 'A',
#    'OO': '141',
#    'DT': 'Connecticut 98',
#    'D': '98'}},
#  {'3033': {'ID': '3033',
#    'NM': 'State Representative 99',
#    'OT': 'A',
#    'OO': '142',
#    'DT': 'Connecticut 99',
#    'D': '99'}},
#  {'3035': {'ID': '3035',
#    'NM': 'State Representative 100',
#    'OT': 'A',
#    'OO': '143',
#    'DT': 'Connecticut 100',
#    'D': '100'}},
#  {'3037': {'ID': '3037',
#    'NM': 'State Representative 101',
#    'OT': 'A',
#    'OO': '144',
#    'DT': 'Connecticut 101',
#    'D': '101'}},
#  {'3040': {'ID': '3040',
#    'NM': 'State Representative 102',
#    'OT': 'A',
#    'OO': '145',
#    'DT': 'Connecticut 102',
#    'D': '102'}},
#  {'3042': {'ID': '3042',
#    'NM': 'State Representative 103',
#    'OT': 'A',
#    'OO': '146',
#    'DT': 'Connecticut 103',
#    'D': '103'}},
#  {'3180': {'ID': '3180',
#    'NM': 'State Representative 104',
#    'OT': 'A',
#    'OO': '147',
#    'DT': 'Connecticut 104',
#    'D': '104'}},
#  {'3047': {'ID': '3047',
#    'NM': 'State Representative 105',
#    'OT': 'A',
#    'OO': '148',
#    'DT': 'Connecticut 105',
#    'D': '105'}},
#  {'3048': {'ID': '3048',
#    'NM': 'State Representative 106',
#    'OT': 'A',
#    'OO': '149',
#    'DT': 'Connecticut 106',
#    'D': '106'}},
#  {'3049': {'ID': '3049',
#    'NM': 'State Representative 107',
#    'OT': 'A',
#    'OO': '150',
#    'DT': 'Connecticut 107',
#    'D': '107'}},
#  {'3050': {'ID': '3050',
#    'NM': 'State Representative 108',
#    'OT': 'A',
#    'OO': '151',
#    'DT': 'Connecticut 108',
#    'D': '108'}},
#  {'3051': {'ID': '3051',
#    'NM': 'State Representative 109',
#    'OT': 'A',
#    'OO': '152',
#    'DT': 'Connecticut 109',
#    'D': '109'}},
#  {'3052': {'ID': '3052',
#    'NM': 'State Representative 110',
#    'OT': 'A',
#    'OO': '153',
#    'DT': 'Connecticut 110',
#    'D': '110'}},
#  {'3053': {'ID': '3053',
#    'NM': 'State Representative 111',
#    'OT': 'A',
#    'OO': '154',
#    'DT': 'Connecticut 111',
#    'D': '111'}},
#  {'3054': {'ID': '3054',
#    'NM': 'State Representative 112',
#    'OT': 'A',
#    'OO': '155',
#    'DT': 'Connecticut 112',
#    'D': '112'}},
#  {'3055': {'ID': '3055',
#    'NM': 'State Representative 113',
#    'OT': 'A',
#    'OO': '156',
#    'DT': 'Connecticut 113',
#    'D': '113'}},
#  {'3056': {'ID': '3056',
#    'NM': 'State Representative 114',
#    'OT': 'A',
#    'OO': '157',
#    'DT': 'Connecticut 114',
#    'D': '114'}},
#  {'3057': {'ID': '3057',
#    'NM': 'State Representative 115',
#    'OT': 'A',
#    'OO': '158',
#    'DT': 'Connecticut 115',
#    'D': '115'}},
#  {'3058': {'ID': '3058',
#    'NM': 'State Representative 116',
#    'OT': 'A',
#    'OO': '159',
#    'DT': 'Connecticut 116',
#    'D': '116'}},
#  {'3059': {'ID': '3059',
#    'NM': 'State Representative 117',
#    'OT': 'A',
#    'OO': '160',
#    'DT': 'Connecticut 117',
#    'D': '117'}},
#  {'3060': {'ID': '3060',
#    'NM': 'State Representative 118',
#    'OT': 'A',
#    'OO': '161',
#    'DT': 'Connecticut 118',
#    'D': '118'}},
#  {'3061': {'ID': '3061',
#    'NM': 'State Representative 119',
#    'OT': 'A',
#    'OO': '162',
#    'DT': 'Connecticut 119',
#    'D': '119'}},
#  {'3062': {'ID': '3062',
#    'NM': 'State Representative 120',
#    'OT': 'A',
#    'OO': '163',
#    'DT': 'Connecticut 120',
#    'D': '120'}},
#  {'3063': {'ID': '3063',
#    'NM': 'State Representative 121',
#    'OT': 'A',
#    'OO': '164',
#    'DT': 'Connecticut 121',
#    'D': '121'}},
#  {'3064': {'ID': '3064',
#    'NM': 'State Representative 122',
#    'OT': 'A',
#    'OO': '165',
#    'DT': 'Connecticut 122',
#    'D': '122'}},
#  {'3065': {'ID': '3065',
#    'NM': 'State Representative 123',
#    'OT': 'A',
#    'OO': '166',
#    'DT': 'Connecticut 123',
#    'D': '123'}},
#  {'3066': {'ID': '3066',
#    'NM': 'State Representative 124',
#    'OT': 'A',
#    'OO': '167',
#    'DT': 'Connecticut 124',
#    'D': '124'}},
#  {'3067': {'ID': '3067',
#    'NM': 'State Representative 125',
#    'OT': 'A',
#    'OO': '168',
#    'DT': 'Connecticut 125',
#    'D': '125'}},
#  {'3069': {'ID': '3069',
#    'NM': 'State Representative 126',
#    'OT': 'A',
#    'OO': '169',
#    'DT': 'Connecticut 126',
#    'D': '126'}},
#  {'3070': {'ID': '3070',
#    'NM': 'State Representative 127',
#    'OT': 'A',
#    'OO': '170',
#    'DT': 'Connecticut 127',
#    'D': '127'}},
#  {'3071': {'ID': '3071',
#    'NM': 'State Representative 128',
#    'OT': 'A',
#    'OO': '171',
#    'DT': 'Connecticut 128',
#    'D': '128'}},
#  {'3072': {'ID': '3072',
#    'NM': 'State Representative 129',
#    'OT': 'A',
#    'OO': '172',
#    'DT': 'Connecticut 129',
#    'D': '129'}},
#  {'3073': {'ID': '3073',
#    'NM': 'State Representative 130',
#    'OT': 'A',
#    'OO': '173',
#    'DT': 'Connecticut 130',
#    'D': '130'}},
#  {'3074': {'ID': '3074',
#    'NM': 'State Representative 131',
#    'OT': 'A',
#    'OO': '174',
#    'DT': 'Connecticut 131',
#    'D': '131'}},
#  {'3075': {'ID': '3075',
#    'NM': 'State Representative 132',
#    'OT': 'A',
#    'OO': '175',
#    'DT': 'Connecticut 132',
#    'D': '132'}},
#  {'3076': {'ID': '3076',
#    'NM': 'State Representative 133',
#    'OT': 'A',
#    'OO': '176',
#    'DT': 'Connecticut 133',
#    'D': '133'}},
#  {'3077': {'ID': '3077',
#    'NM': 'State Representative 134',
#    'OT': 'A',
#    'OO': '177',
#    'DT': 'Connecticut 134',
#    'D': '134'}},
#  {'3078': {'ID': '3078',
#    'NM': 'State Representative 135',
#    'OT': 'A',
#    'OO': '178',
#    'DT': 'Connecticut 135',
#    'D': '135'}},
#  {'3080': {'ID': '3080',
#    'NM': 'State Representative 136',
#    'OT': 'A',
#    'OO': '179',
#    'DT': 'Connecticut 136',
#    'D': '136'}},
#  {'3081': {'ID': '3081',
#    'NM': 'State Representative 137',
#    'OT': 'A',
#    'OO': '180',
#    'DT': 'Connecticut 137',
#    'D': '137'}},
#  {'3082': {'ID': '3082',
#    'NM': 'State Representative 138',
#    'OT': 'A',
#    'OO': '181',
#    'DT': 'Connecticut 138',
#    'D': '138'}},
#  {'3084': {'ID': '3084',
#    'NM': 'State Representative 139',
#    'OT': 'A',
#    'OO': '182',
#    'DT': 'Connecticut 139',
#    'D': '139'}},
#  {'3085': {'ID': '3085',
#    'NM': 'State Representative 140',
#    'OT': 'A',
#    'OO': '183',
#    'DT': 'Connecticut 140',
#    'D': '140'}},
#  {'3087': {'ID': '3087',
#    'NM': 'State Representative 141',
#    'OT': 'A',
#    'OO': '184',
#    'DT': 'Connecticut 141',
#    'D': '141'}},
#  {'3088': {'ID': '3088',
#    'NM': 'State Representative 142',
#    'OT': 'A',
#    'OO': '185',
#    'DT': 'Connecticut 142',
#    'D': '142'}},
#  {'3090': {'ID': '3090',
#    'NM': 'State Representative 143',
#    'OT': 'A',
#    'OO': '186',
#    'DT': 'Connecticut 143',
#    'D': '143'}},
#  {'3091': {'ID': '3091',
#    'NM': 'State Representative 144',
#    'OT': 'A',
#    'OO': '187',
#    'DT': 'Connecticut 144',
#    'D': '144'}},
#  {'3093': {'ID': '3093',
#    'NM': 'State Representative 145',
#    'OT': 'A',
#    'OO': '188',
#    'DT': 'Connecticut 145',
#    'D': '145'}},
#  {'3095': {'ID': '3095',
#    'NM': 'State Representative 146',
#    'OT': 'A',
#    'OO': '189',
#    'DT': 'Connecticut 146',
#    'D': '146'}},
#  {'3096': {'ID': '3096',
#    'NM': 'State Representative 147',
#    'OT': 'A',
#    'OO': '190',
#    'DT': 'Connecticut 147',
#    'D': '147'}},
#  {'3098': {'ID': '3098',
#    'NM': 'State Representative 148',
#    'OT': 'A',
#    'OO': '191',
#    'DT': 'Connecticut 148',
#    'D': '148'}},
#  {'3099': {'ID': '3099',
#    'NM': 'State Representative 149',
#    'OT': 'A',
#    'OO': '192',
#    'DT': 'Connecticut 149',
#    'D': '149'}},
#  {'3100': {'ID': '3100',
#    'NM': 'State Representative 150',
#    'OT': 'A',
#    'OO': '193',
#    'DT': 'Connecticut 150',
#    'D': '150'}},
#  {'3101': {'ID': '3101',
#    'NM': 'State Representative 151',
#    'OT': 'A',
#    'OO': '194',
#    'DT': 'Connecticut 151',
#    'D': '151'}},
#  {'2952': {'ID': '2952',
#    'NM': 'Secretary of the State',
#    'OT': 'SW',
#    'OO': '195',
#    'DT': '',
#    'D': '0'}},
#  {'2953': {'ID': '2953',
#    'NM': 'Treasurer',
#    'OT': 'SW',
#    'OO': '196',
#    'DT': '',
#    'D': '0'}},
#  {'2954': {'ID': '2954',
#    'NM': 'Comptroller',
#    'OT': 'SW',
#    'OO': '197',
#    'DT': '',
#    'D': '0'}},
#  {'2955': {'ID': '2955',
#    'NM': 'Attorney General',
#    'OT': 'SW',
#    'OO': '198',
#    'DT': '',
#    'D': '0'}},
#  {'3183': {'ID': '3183',
#    'NM': 'Judge of Probate 01',
#    'OT': 'PD',
#    'OO': '199',
#    'DT': 'Connecticut 01',
#    'D': '1'}},
#  {'2957': {'ID': '2957',
#    'NM': 'Judge of Probate 02',
#    'OT': 'PD',
#    'OO': '200',
#    'DT': 'Connecticut 02',
#    'D': '2'}},
#  {'2958': {'ID': '2958',
#    'NM': 'Judge of Probate 03',
#    'OT': 'PD',
#    'OO': '201',
#    'DT': 'Connecticut 03',
#    'D': '3'}},
#  {'2959': {'ID': '2959',
#    'NM': 'Judge of Probate 04',
#    'OT': 'PD',
#    'OO': '202',
#    'DT': 'Connecticut 04',
#    'D': '4'}},
#  {'2960': {'ID': '2960',
#    'NM': 'Judge of Probate 05',
#    'OT': 'PD',
#    'OO': '203',
#    'DT': 'Connecticut 05',
#    'D': '5'}},
#  {'2961': {'ID': '2961',
#    'NM': 'Judge of Probate 06',
#    'OT': 'PD',
#    'OO': '204',
#    'DT': 'Connecticut 06',
#    'D': '6'}},
#  {'2962': {'ID': '2962',
#    'NM': 'Judge of Probate 07',
#    'OT': 'PD',
#    'OO': '205',
#    'DT': 'Connecticut 07',
#    'D': '7'}},
#  {'2963': {'ID': '2963',
#    'NM': 'Judge of Probate 08',
#    'OT': 'PD',
#    'OO': '206',
#    'DT': 'Connecticut 08',
#    'D': '8'}},
#  {'2964': {'ID': '2964',
#    'NM': 'Judge of Probate 09',
#    'OT': 'PD',
#    'OO': '207',
#    'DT': 'Connecticut 09',
#    'D': '9'}},
#  {'2965': {'ID': '2965',
#    'NM': 'Judge of Probate 10',
#    'OT': 'PD',
#    'OO': '208',
#    'DT': 'Connecticut 10',
#    'D': '10'}},
#  {'2966': {'ID': '2966',
#    'NM': 'Judge of Probate 11',
#    'OT': 'PD',
#    'OO': '209',
#    'DT': 'Connecticut 11',
#    'D': '11'}},
#  {'3293': {'ID': '3293',
#    'NM': 'Judge of Probate to Fill Vacancy 11',
#    'OT': 'PD',
#    'OO': '210',
#    'DT': 'Connecticut 11',
#    'D': '11'}},
#  {'2967': {'ID': '2967',
#    'NM': 'Judge of Probate 12',
#    'OT': 'PD',
#    'OO': '211',
#    'DT': 'Connecticut 12',
#    'D': '12'}},
#  {'2968': {'ID': '2968',
#    'NM': 'Judge of Probate 13',
#    'OT': 'PD',
#    'OO': '212',
#    'DT': 'Connecticut 13',
#    'D': '13'}},
#  {'3230': {'ID': '3230',
#    'NM': 'Judge of Probate 14',
#    'OT': 'PD',
#    'OO': '213',
#    'DT': 'Connecticut 14',
#    'D': '14'}},
#  {'2970': {'ID': '2970',
#    'NM': 'Judge of Probate 15',
#    'OT': 'PD',
#    'OO': '214',
#    'DT': 'Connecticut 15',
#    'D': '15'}},
#  {'2971': {'ID': '2971',
#    'NM': 'Judge of Probate 16',
#    'OT': 'PD',
#    'OO': '215',
#    'DT': 'Connecticut 16',
#    'D': '16'}},
#  {'2979': {'ID': '2979',
#    'NM': 'Judge of Probate 17',
#    'OT': 'PD',
#    'OO': '216',
#    'DT': 'Connecticut 17',
#    'D': '17'}},
#  {'2974': {'ID': '2974',
#    'NM': 'Judge of Probate 18',
#    'OT': 'PD',
#    'OO': '217',
#    'DT': 'Connecticut 18',
#    'D': '18'}},
#  {'2980': {'ID': '2980',
#    'NM': 'Judge of Probate 19',
#    'OT': 'PD',
#    'OO': '218',
#    'DT': 'Connecticut 19',
#    'D': '19'}},
#  {'2982': {'ID': '2982',
#    'NM': 'Judge of Probate 20',
#    'OT': 'PD',
#    'OO': '219',
#    'DT': 'Connecticut 20',
#    'D': '20'}},
#  {'2984': {'ID': '2984',
#    'NM': 'Judge of Probate 21',
#    'OT': 'PD',
#    'OO': '220',
#    'DT': 'Connecticut 21',
#    'D': '21'}},
#  {'2988': {'ID': '2988',
#    'NM': 'Judge of Probate 22',
#    'OT': 'PD',
#    'OO': '221',
#    'DT': 'Connecticut 22',
#    'D': '22'}},
#  {'2992': {'ID': '2992',
#    'NM': 'Judge of Probate 24',
#    'OT': 'PD',
#    'OO': '222',
#    'DT': 'Connecticut 24',
#    'D': '24'}},
#  {'2994': {'ID': '2994',
#    'NM': 'Judge of Probate 25',
#    'OT': 'PD',
#    'OO': '223',
#    'DT': 'Connecticut 25',
#    'D': '25'}},
#  {'2995': {'ID': '2995',
#    'NM': 'Judge of Probate 26',
#    'OT': 'PD',
#    'OO': '224',
#    'DT': 'Connecticut 26',
#    'D': '26'}},
#  {'2997': {'ID': '2997',
#    'NM': 'Judge of Probate 27',
#    'OT': 'PD',
#    'OO': '225',
#    'DT': 'Connecticut 27',
#    'D': '27'}},
#  {'2999': {'ID': '2999',
#    'NM': 'Judge of Probate 28',
#    'OT': 'PD',
#    'OO': '226',
#    'DT': 'Connecticut 28',
#    'D': '28'}},
#  {'3000': {'ID': '3000',
#    'NM': 'Judge of Probate 29',
#    'OT': 'PD',
#    'OO': '227',
#    'DT': 'Connecticut 29',
#    'D': '29'}},
#  {'2990': {'ID': '2990',
#    'NM': 'Judge of Probate 23',
#    'OT': 'PD',
#    'OO': '228',
#    'DT': 'Connecticut 23',
#    'D': '23'}},
#  {'3003': {'ID': '3003',
#    'NM': 'Judge of Probate 30',
#    'OT': 'PD',
#    'OO': '229',
#    'DT': 'Connecticut 30',
#    'D': '30'}},
#  {'3007': {'ID': '3007',
#    'NM': 'Judge of Probate 31',
#    'OT': 'PD',
#    'OO': '230',
#    'DT': 'Connecticut 31',
#    'D': '31'}},
#  {'3009': {'ID': '3009',
#    'NM': 'Judge of Probate 32',
#    'OT': 'PD',
#    'OO': '231',
#    'DT': 'Connecticut 32',
#    'D': '32'}},
#  {'3010': {'ID': '3010',
#    'NM': 'Judge of Probate 33',
#    'OT': 'PD',
#    'OO': '232',
#    'DT': 'Connecticut 33',
#    'D': '33'}},
#  {'3011': {'ID': '3011',
#    'NM': 'Judge of Probate 34',
#    'OT': 'PD',
#    'OO': '233',
#    'DT': 'Connecticut 34',
#    'D': '34'}},
#  {'3013': {'ID': '3013',
#    'NM': 'Judge of Probate 35',
#    'OT': 'PD',
#    'OO': '234',
#    'DT': 'Connecticut 35',
#    'D': '35'}},
#  {'3014': {'ID': '3014',
#    'NM': 'Judge of Probate 36',
#    'OT': 'PD',
#    'OO': '235',
#    'DT': 'Connecticut 36',
#    'D': '36'}},
#  {'3016': {'ID': '3016',
#    'NM': 'Judge of Probate 37',
#    'OT': 'PD',
#    'OO': '236',
#    'DT': 'Connecticut 37',
#    'D': '37'}},
#  {'3017': {'ID': '3017',
#    'NM': 'Judge of Probate 38',
#    'OT': 'PD',
#    'OO': '237',
#    'DT': 'Connecticut 38',
#    'D': '38'}},
#  {'3018': {'ID': '3018',
#    'NM': 'Judge of Probate 39',
#    'OT': 'PD',
#    'OO': '238',
#    'DT': 'Connecticut 39',
#    'D': '39'}},
#  {'3019': {'ID': '3019',
#    'NM': 'Judge of Probate 40',
#    'OT': 'PD',
#    'OO': '239',
#    'DT': 'Connecticut 40',
#    'D': '40'}},
#  {'3021': {'ID': '3021',
#    'NM': 'Judge of Probate 41',
#    'OT': 'PD',
#    'OO': '240',
#    'DT': 'Connecticut 41',
#    'D': '41'}},
#  {'3046': {'ID': '3046',
#    'NM': 'Judge of Probate 42',
#    'OT': 'PD',
#    'OO': '241',
#    'DT': 'Connecticut 42',
#    'D': '42'}},
#  {'3024': {'ID': '3024',
#    'NM': 'Judge of Probate 43',
#    'OT': 'PD',
#    'OO': '242',
#    'DT': 'Connecticut 43',
#    'D': '43'}},
#  {'3026': {'ID': '3026',
#    'NM': 'Judge of Probate 44',
#    'OT': 'PD',
#    'OO': '243',
#    'DT': 'Connecticut 44',
#    'D': '44'}},
#  {'3027': {'ID': '3027',
#    'NM': 'Judge of Probate 45',
#    'OT': 'PD',
#    'OO': '244',
#    'DT': 'Connecticut 45',
#    'D': '45'}},
#  {'3029': {'ID': '3029',
#    'NM': 'Judge of Probate 46',
#    'OT': 'PD',
#    'OO': '245',
#    'DT': 'Connecticut 46',
#    'D': '46'}},
#  {'3031': {'ID': '3031',
#    'NM': 'Judge of Probate 47',
#    'OT': 'PD',
#    'OO': '246',
#    'DT': 'Connecticut 47',
#    'D': '47'}},
#  {'3032': {'ID': '3032',
#    'NM': 'Judge of Probate 48',
#    'OT': 'PD',
#    'OO': '247',
#    'DT': 'Connecticut 48',
#    'D': '48'}},
#  {'3034': {'ID': '3034',
#    'NM': 'Judge of Probate 49',
#    'OT': 'PD',
#    'OO': '248',
#    'DT': 'Connecticut 49',
#    'D': '49'}},
#  {'3292': {'ID': '3292',
#    'NM': 'Judge of Probate to Fill Vacancy 49',
#    'OT': 'PD',
#    'OO': '249',
#    'DT': 'Connecticut 49',
#    'D': '49'}},
#  {'3036': {'ID': '3036',
#    'NM': 'Judge of Probate 50',
#    'OT': 'PD',
#    'OO': '250',
#    'DT': 'Connecticut 50',
#    'D': '50'}},
#  {'3038': {'ID': '3038',
#    'NM': 'Judge of Probate 51',
#    'OT': 'PD',
#    'OO': '251',
#    'DT': 'Connecticut 51',
#    'D': '51'}},
#  {'3039': {'ID': '3039',
#    'NM': 'Judge of Probate 52',
#    'OT': 'PD',
#    'OO': '252',
#    'DT': 'Connecticut 52',
#    'D': '52'}},
#  {'3041': {'ID': '3041',
#    'NM': 'Judge of Probate 53',
#    'OT': 'PD',
#    'OO': '253',
#    'DT': 'Connecticut 53',
#    'D': '53'}},
#  {'3043': {'ID': '3043',
#    'NM': 'Judge of Probate 54',
#    'OT': 'PD',
#    'OO': '254',
#    'DT': 'Connecticut 54',
#    'D': '54'}},
#  {'3316': {'ID': '3316',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '255',
#    'DT': '',
#    'D': '0'}},
#  {'3367': {'ID': '3367',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '256',
#    'DT': '',
#    'D': '0'}},
#  {'3195': {'ID': '3195',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '257',
#    'DT': '',
#    'D': '0'}},
#  {'3347': {'ID': '3347',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '258',
#    'DT': '',
#    'D': '0'}},
#  {'3196': {'ID': '3196',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '259',
#    'DT': '',
#    'D': '0'}},
#  {'3187': {'ID': '3187',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '260',
#    'DT': '',
#    'D': '0'}},
#  {'3192': {'ID': '3192',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '261',
#    'DT': '',
#    'D': '0'}},
#  {'3205': {'ID': '3205',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '262',
#    'DT': '',
#    'D': '0'}},
#  {'2879': {'ID': '2879',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '263',
#    'DT': '',
#    'D': '0'}},
#  {'3365': {'ID': '3365',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '264',
#    'DT': '',
#    'D': '0'}},
#  {'3185': {'ID': '3185',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '265',
#    'DT': '',
#    'D': '0'}},
#  {'3189': {'ID': '3189',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '266',
#    'DT': '',
#    'D': '0'}},
#  {'3197': {'ID': '3197',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '267',
#    'DT': '',
#    'D': '0'}},
#  {'3194': {'ID': '3194',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '268',
#    'DT': '',
#    'D': '0'}},
#  {'3198': {'ID': '3198',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '269',
#    'DT': '',
#    'D': '0'}},
#  {'3361': {'ID': '3361',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '270',
#    'DT': '',
#    'D': '0'}},
#  {'3223': {'ID': '3223',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '271',
#    'DT': '',
#    'D': '0'}},
#  {'3218': {'ID': '3218',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '272',
#    'DT': '',
#    'D': '0'}},
#  {'3217': {'ID': '3217',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '273',
#    'DT': '',
#    'D': '0'}},
#  {'2883': {'ID': '2883',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '274',
#    'DT': '',
#    'D': '0'}},
#  {'3377': {'ID': '3377',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '275',
#    'DT': '',
#    'D': '0'}},
#  {'3204': {'ID': '3204',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '276',
#    'DT': '',
#    'D': '0'}},
#  {'3219': {'ID': '3219',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '277',
#    'DT': '',
#    'D': '0'}},
#  {'3222': {'ID': '3222',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '278',
#    'DT': '',
#    'D': '0'}},
#  {'3224': {'ID': '3224',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '279',
#    'DT': '',
#    'D': '0'}},
#  {'3226': {'ID': '3226',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '280',
#    'DT': '',
#    'D': '0'}},
#  {'3228': {'ID': '3228',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '281',
#    'DT': '',
#    'D': '0'}},
#  {'3215': {'ID': '3215',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '282',
#    'DT': '',
#    'D': '0'}},
#  {'3233': {'ID': '3233',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '283',
#    'DT': '',
#    'D': '0'}},
#  {'3235': {'ID': '3235',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '284',
#    'DT': '',
#    'D': '0'}},
#  {'3190': {'ID': '3190',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '285',
#    'DT': '',
#    'D': '0'}},
#  {'3238': {'ID': '3238',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '286',
#    'DT': '',
#    'D': '0'}},
#  {'3243': {'ID': '3243',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '287',
#    'DT': '',
#    'D': '0'}},
#  {'3245': {'ID': '3245',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '288',
#    'DT': '',
#    'D': '0'}},
#  {'3247': {'ID': '3247',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '289',
#    'DT': '',
#    'D': '0'}},
#  {'3248': {'ID': '3248',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '290',
#    'DT': '',
#    'D': '0'}},
#  {'3249': {'ID': '3249',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '291',
#    'DT': '',
#    'D': '0'}},
#  {'3252': {'ID': '3252',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '292',
#    'DT': '',
#    'D': '0'}},
#  {'3253': {'ID': '3253',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '293',
#    'DT': '',
#    'D': '0'}},
#  {'3254': {'ID': '3254',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '294',
#    'DT': '',
#    'D': '0'}},
#  {'3265': {'ID': '3265',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '295',
#    'DT': '',
#    'D': '0'}},
#  {'3266': {'ID': '3266',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '296',
#    'DT': '',
#    'D': '0'}},
#  {'3297': {'ID': '3297',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '297',
#    'DT': '',
#    'D': '0'}},
#  {'3269': {'ID': '3269',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '298',
#    'DT': '',
#    'D': '0'}},
#  {'3272': {'ID': '3272',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '299',
#    'DT': '',
#    'D': '0'}},
#  {'3276': {'ID': '3276',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '300',
#    'DT': '',
#    'D': '0'}},
#  {'3277': {'ID': '3277',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '301',
#    'DT': '',
#    'D': '0'}},
#  {'3280': {'ID': '3280',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '302',
#    'DT': '',
#    'D': '0'}},
#  {'3281': {'ID': '3281',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '303',
#    'DT': '',
#    'D': '0'}},
#  {'3283': {'ID': '3283',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '304',
#    'DT': '',
#    'D': '0'}},
#  {'3284': {'ID': '3284',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '305',
#    'DT': '',
#    'D': '0'}},
#  {'3286': {'ID': '3286',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '306',
#    'DT': '',
#    'D': '0'}},
#  {'3287': {'ID': '3287',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '307',
#    'DT': '',
#    'D': '0'}},
#  {'3288': {'ID': '3288',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '308',
#    'DT': '',
#    'D': '0'}},
#  {'3289': {'ID': '3289',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '309',
#    'DT': '',
#    'D': '0'}},
#  {'3294': {'ID': '3294',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '310',
#    'DT': '',
#    'D': '0'}},
#  {'3295': {'ID': '3295',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '311',
#    'DT': '',
#    'D': '0'}},
#  {'3296': {'ID': '3296',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '312',
#    'DT': '',
#    'D': '0'}},
#  {'3298': {'ID': '3298',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '313',
#    'DT': '',
#    'D': '0'}},
#  {'3299': {'ID': '3299',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '314',
#    'DT': '',
#    'D': '0'}},
#  {'3300': {'ID': '3300',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '315',
#    'DT': '',
#    'D': '0'}},
#  {'3302': {'ID': '3302',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '316',
#    'DT': '',
#    'D': '0'}},
#  {'3303': {'ID': '3303',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '317',
#    'DT': '',
#    'D': '0'}},
#  {'3304': {'ID': '3304',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '318',
#    'DT': '',
#    'D': '0'}},
#  {'3306': {'ID': '3306',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '319',
#    'DT': '',
#    'D': '0'}},
#  {'3307': {'ID': '3307',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '320',
#    'DT': '',
#    'D': '0'}},
#  {'3309': {'ID': '3309',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '321',
#    'DT': '',
#    'D': '0'}},
#  {'3311': {'ID': '3311',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '322',
#    'DT': '',
#    'D': '0'}},
#  {'3313': {'ID': '3313',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '323',
#    'DT': '',
#    'D': '0'}},
#  {'3314': {'ID': '3314',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '324',
#    'DT': '',
#    'D': '0'}},
#  {'3315': {'ID': '3315',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '325',
#    'DT': '',
#    'D': '0'}},
#  {'3317': {'ID': '3317',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '326',
#    'DT': '',
#    'D': '0'}},
#  {'3318': {'ID': '3318',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '327',
#    'DT': '',
#    'D': '0'}},
#  {'3320': {'ID': '3320',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '328',
#    'DT': '',
#    'D': '0'}},
#  {'3321': {'ID': '3321',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '329',
#    'DT': '',
#    'D': '0'}},
#  {'3259': {'ID': '3259',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '330',
#    'DT': '',
#    'D': '0'}},
#  {'3333': {'ID': '3333',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '331',
#    'DT': '',
#    'D': '0'}},
#  {'3339': {'ID': '3339',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '332',
#    'DT': '',
#    'D': '0'}},
#  {'3340': {'ID': '3340',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '333',
#    'DT': '',
#    'D': '0'}},
#  {'3341': {'ID': '3341',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '334',
#    'DT': '',
#    'D': '0'}},
#  {'3348': {'ID': '3348',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '335',
#    'DT': '',
#    'D': '0'}},
#  {'3349': {'ID': '3349',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '336',
#    'DT': '',
#    'D': '0'}},
#  {'3285': {'ID': '3285',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '337',
#    'DT': '',
#    'D': '0'}},
#  {'3350': {'ID': '3350',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '338',
#    'DT': '',
#    'D': '0'}},
#  {'3301': {'ID': '3301',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '339',
#    'DT': '',
#    'D': '0'}},
#  {'3357': {'ID': '3357',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '340',
#    'DT': '',
#    'D': '0'}},
#  {'3212': {'ID': '3212',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '341',
#    'DT': '',
#    'D': '0'}},
#  {'3214': {'ID': '3214',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '342',
#    'DT': '',
#    'D': '0'}},
#  {'3370': {'ID': '3370',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '343',
#    'DT': '',
#    'D': '0'}},
#  {'3371': {'ID': '3371',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '344',
#    'DT': '',
#    'D': '0'}},
#  {'3372': {'ID': '3372',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '345',
#    'DT': '',
#    'D': '0'}},
#  {'3346': {'ID': '3346',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '346',
#    'DT': '',
#    'D': '0'}},
#  {'3355': {'ID': '3355',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '347',
#    'DT': '',
#    'D': '0'}},
#  {'3356': {'ID': '3356',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '348',
#    'DT': '',
#    'D': '0'}},
#  {'3345': {'ID': '3345',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '349',
#    'DT': '',
#    'D': '0'}},
#  {'3362': {'ID': '3362',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '350',
#    'DT': '',
#    'D': '0'}},
#  {'3343': {'ID': '3343',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '351',
#    'DT': '',
#    'D': '0'}},
#  {'3358': {'ID': '3358',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '352',
#    'DT': '',
#    'D': '0'}},
#  {'3363': {'ID': '3363',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '353',
#    'DT': '',
#    'D': '0'}},
#  {'3376': {'ID': '3376',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '354',
#    'DT': '',
#    'D': '0'}},
#  {'3186': {'ID': '3186',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '355',
#    'DT': '',
#    'D': '0'}},
#  {'3378': {'ID': '3378',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '356',
#    'DT': '',
#    'D': '0'}},
#  {'3380': {'ID': '3380',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '357',
#    'DT': '',
#    'D': '0'}},
#  {'3366': {'ID': '3366',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '358',
#    'DT': '',
#    'D': '0'}},
#  {'3373': {'ID': '3373',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '359',
#    'DT': '',
#    'D': '0'}},
#  {'3270': {'ID': '3270',
#    'NM': 'NonPartisan Board of Education',
#    'OT': 'SM',
#    'OO': '360',
#    'DT': '',
#    'D': '0'}},
#  {'3351': {'ID': '3351',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '361',
#    'DT': '',
#    'D': '0'}},
#  {'3382': {'ID': '3382',
#    'NM': 'Registrar of Voters',
#    'OT': 'SM',
#    'OO': '362',
#    'DT': '',
#    'D': '0'}},
#  {'3322': {'ID': '3322',
#    'NM': 'Board of Education',
#    'OT': 'SM',
#    'OO': '363',
#    'DT': '',
#    'D': '0'}},
#  {'3330': {'ID': '3330',
#    'NM': 'Non Partisan Representative Town Meeting District I',
#    'OT': 'SM',
#    'OO': '364',
#    'DT': '',
#    'D': '0'}},
#  {'3331': {'ID': '3331',
#    'NM': 'Non Partisan Representative Town Meeting District II',
#    'OT': 'SM',
#    'OO': '365',
#    'DT': '',
#    'D': '0'}},
#  {'3328': {'ID': '3328',
#    'NM': 'Non Partisan Representative Town Meeting District III',
#    'OT': 'SM',
#    'OO': '366',
#    'DT': '',
#    'D': '0'}},
#  {'3329': {'ID': '3329',
#    'NM': 'Non Partisan Representative Town Meeting District IV',
#    'OT': 'SM',
#    'OO': '367',
#    'DT': '',
#    'D': '0'}},
#  {'3327': {'ID': '3327',
#    'NM': 'Non Partisan Representative Town Meeting District V',
#    'OT': 'SM',
#    'OO': '368',
#    'DT': '',
#    'D': '0'}},
#  {'3332': {'ID': '3332',
#    'NM': 'Non Partisan Representative Town Meeting District VI',
#    'OT': 'SM',
#    'OO': '369',
#    'DT': '',
#    'D': '0'}},
#  {'3383': {'ID': '3383',
#    'NM': 'Selectman',
#    'OT': 'SM',
#    'OO': '370',
#    'DT': '',
#    'D': '0'}},
#  {'3344': {'ID': '3344',
#    'NM': 'Board of Education',
#    'OT': 'SM',
#    'OO': '371',
#    'DT': '',
#    'D': '0'}}]

# %%
list({'2901': {'ID': '2901',
   'NM': 'Governor and Lieutenant Governor',
   'OT': 'SW',
   'OO': '1',
   'DT': '',
   'D': '0'}}.keys())[0]
# Out:
# '2901'

# %%
def findobj(obj_arr, k):
    return list(filter(lambda x: list(x.keys())[0] == k,obj_arr))

findobj(general_2018["lookup_data"]["officeList"], '2901')
# Out:
# [{'2901': {'ID': '2901',
#    'NM': 'Governor and Lieutenant Governor',
#    'OT': 'SW',
#    'OO': '1',
#    'DT': '',
#    'D': '0'}}]

# %%
def dictify(obj):
    ret = {}
    
    keys = list(map(lambda x: list(x.keys())[0], obj))
    
    for k in keys:
        ret[k] = findobj(obj, k)[0][k]
    
    return ret

dictify(general_2018["lookup_data"]["officeList"])
# Out:
# {'2901': {'ID': '2901',
#   'NM': 'Governor and Lieutenant Governor',
#   'OT': 'SW',
#   'OO': '1',
#   'DT': '',
#   'D': '0'},
#  '2903': {'ID': '2903',
#   'NM': 'United States Senator',
#   'OT': 'SW',
#   'OO': '2',
#   'DT': '',
#   'D': '0'},
#  '2910': {'ID': '2910',
#   'NM': 'Representative in Congress 01',
#   'OT': 'C',
#   'OO': '3',
#   'DT': 'Connecticut 01',
#   'D': '1'},
#  '2911': {'ID': '2911',
#   'NM': 'Representative in Congress 02',
#   'OT': 'C',
#   'OO': '4',
#   'DT': 'Connecticut 02',
#   'D': '2'},
#  '2912': {'ID': '2912',
#   'NM': 'Representative in Congress 03',
#   'OT': 'C',
#   'OO': '5',
#   'DT': 'Connecticut 03',
#   'D': '3'},
#  '2913': {'ID': '2913',
#   'NM': 'Representative in Congress 04',
#   'OT': 'C',
#   'OO': '6',
#   'DT': 'Connecticut 04',
#   'D': '4'},
#  '2914': {'ID': '2914',
#   'NM': 'Representative in Congress 05',
#   'OT': 'C',
#   'OO': '7',
#   'DT': 'Connecticut 05',
#   'D': '5'},
#  '2915': {'ID': '2915',
#   'NM': 'State Senator 01',
#   'OT': 'S',
#   'OO': '8',
#   'DT': 'Connecticut 01',
#   'D': '1'},
#  '3182': {'ID': '3182',
#   'NM': 'State Senator 02',
#   'OT': 'S',
#   'OO': '9',
#   'DT': 'Connecticut 02',
#   'D': '2'},
#  '2917': {'ID': '2917',
#   'NM': 'State Senator 03',
#   'OT': 'S',
#   'OO': '10',
#   'DT': 'Connecticut 03',
#   'D': '3'},
#  '2918': {'ID': '2918',
#   'NM': 'State Senator 04',
#   'OT': 'S',
#   'OO': '11',
#   'DT': 'Connecticut 04',
#   'D': '4'},
#  '2919': {'ID': '2919',
#   'NM': 'State Senator 05',
#   'OT': 'S',
#   'OO': '12',
#   'DT': 'Connecticut 05',
#   'D': '5'},
#  '2920': {'ID': '2920',
#   'NM': 'State Senator 06',
#   'OT': 'S',
#   'OO': '13',
#   'DT': 'Connecticut 06',
#   'D': '6'},
#  '2921': {'ID': '2921',
#   'NM': 'State Senator 07',
#   'OT': 'S',
#   'OO': '14',
#   'DT': 'Connecticut 07',
#   'D': '7'},
#  '2922': {'ID': '2922',
#   'NM': 'State Senator 08',
#   'OT': 'S',
#   'OO': '15',
#   'DT': 'Connecticut 08',
#   'D': '8'},
#  '2923': {'ID': '2923',
#   'NM': 'State Senator 09',
#   'OT': 'S',
#   'OO': '16',
#   'DT': 'Connecticut 09',
#   'D': '9'},
#  '2924': {'ID': '2924',
#   'NM': 'State Senator 10',
#   'OT': 'S',
#   'OO': '17',
#   'DT': 'Connecticut 10',
#   'D': '10'},
#  '2925': {'ID': '2925',
#   'NM': 'State Senator 11',
#   'OT': 'S',
#   'OO': '18',
#   'DT': 'Connecticut 11',
#   'D': '11'},
#  '2926': {'ID': '2926',
#   'NM': 'State Senator 12',
#   'OT': 'S',
#   'OO': '19',
#   'DT': 'Connecticut 12',
#   'D': '12'},
#  '2927': {'ID': '2927',
#   'NM': 'State Senator 13',
#   'OT': 'S',
#   'OO': '20',
#   'DT': 'Connecticut 13',
#   'D': '13'},
#  '2928': {'ID': '2928',
#   'NM': 'State Senator 14',
#   'OT': 'S',
#   'OO': '21',
#   'DT': 'Connecticut 14',
#   'D': '14'},
#  '2929': {'ID': '2929',
#   'NM': 'State Senator 15',
#   'OT': 'S',
#   'OO': '22',
#   'DT': 'Connecticut 15',
#   'D': '15'},
#  '2930': {'ID': '2930',
#   'NM': 'State Senator 16',
#   'OT': 'S',
#   'OO': '23',
#   'DT': 'Connecticut 16',
#   'D': '16'},
#  '2931': {'ID': '2931',
#   'NM': 'State Senator 17',
#   'OT': 'S',
#   'OO': '24',
#   'DT': 'Connecticut 17',
#   'D': '17'},
#  '2932': {'ID': '2932',
#   'NM': 'State Senator 18',
#   'OT': 'S',
#   'OO': '25',
#   'DT': 'Connecticut 18',
#   'D': '18'},
#  '2933': {'ID': '2933',
#   'NM': 'State Senator 19',
#   'OT': 'S',
#   'OO': '26',
#   'DT': 'Connecticut 19',
#   'D': '19'},
#  '2934': {'ID': '2934',
#   'NM': 'State Senator 20',
#   'OT': 'S',
#   'OO': '27',
#   'DT': 'Connecticut 20',
#   'D': '20'},
#  '2935': {'ID': '2935',
#   'NM': 'State Senator 21',
#   'OT': 'S',
#   'OO': '28',
#   'DT': 'Connecticut 21',
#   'D': '21'},
#  '2936': {'ID': '2936',
#   'NM': 'State Senator 22',
#   'OT': 'S',
#   'OO': '29',
#   'DT': 'Connecticut 22',
#   'D': '22'},
#  '2937': {'ID': '2937',
#   'NM': 'State Senator 23',
#   'OT': 'S',
#   'OO': '30',
#   'DT': 'Connecticut 23',
#   'D': '23'},
#  '2938': {'ID': '2938',
#   'NM': 'State Senator 24',
#   'OT': 'S',
#   'OO': '31',
#   'DT': 'Connecticut 24',
#   'D': '24'},
#  '2939': {'ID': '2939',
#   'NM': 'State Senator 25',
#   'OT': 'S',
#   'OO': '32',
#   'DT': 'Connecticut 25',
#   'D': '25'},
#  '2940': {'ID': '2940',
#   'NM': 'State Senator 26',
#   'OT': 'S',
#   'OO': '33',
#   'DT': 'Connecticut 26',
#   'D': '26'},
#  '2941': {'ID': '2941',
#   'NM': 'State Senator 27',
#   'OT': 'S',
#   'OO': '34',
#   'DT': 'Connecticut 27',
#   'D': '27'},
#  '2942': {'ID': '2942',
#   'NM': 'State Senator 28',
#   'OT': 'S',
#   'OO': '35',
#   'DT': 'Connecticut 28',
#   'D': '28'},
#  '2943': {'ID': '2943',
#   'NM': 'State Senator 29',
#   'OT': 'S',
#   'OO': '36',
#   'DT': 'Connecticut 29',
#   'D': '29'},
#  '2944': {'ID': '2944',
#   'NM': 'State Senator 30',
#   'OT': 'S',
#   'OO': '37',
#   'DT': 'Connecticut 30',
#   'D': '30'},
#  '2945': {'ID': '2945',
#   'NM': 'State Senator 31',
#   'OT': 'S',
#   'OO': '38',
#   'DT': 'Connecticut 31',
#   'D': '31'},
#  '2946': {'ID': '2946',
#   'NM': 'State Senator 32',
#   'OT': 'S',
#   'OO': '39',
#   'DT': 'Connecticut 32',
#   'D': '32'},
#  '2947': {'ID': '2947',
#   'NM': 'State Senator 33',
#   'OT': 'S',
#   'OO': '40',
#   'DT': 'Connecticut 33',
#   'D': '33'},
#  '2948': {'ID': '2948',
#   'NM': 'State Senator 34',
#   'OT': 'S',
#   'OO': '41',
#   'DT': 'Connecticut 34',
#   'D': '34'},
#  '2949': {'ID': '2949',
#   'NM': 'State Senator 35',
#   'OT': 'S',
#   'OO': '42',
#   'DT': 'Connecticut 35',
#   'D': '35'},
#  '2950': {'ID': '2950',
#   'NM': 'State Senator 36',
#   'OT': 'S',
#   'OO': '43',
#   'DT': 'Connecticut 36',
#   'D': '36'},
#  '2951': {'ID': '2951',
#   'NM': 'State Representative 01',
#   'OT': 'A',
#   'OO': '44',
#   'DT': 'Connecticut 01',
#   'D': '1'},
#  '3068': {'ID': '3068',
#   'NM': 'State Representative 02',
#   'OT': 'A',
#   'OO': '45',
#   'DT': 'Connecticut 02',
#   'D': '2'},
#  '3079': {'ID': '3079',
#   'NM': 'State Representative 03',
#   'OT': 'A',
#   'OO': '46',
#   'DT': 'Connecticut 03',
#   'D': '3'},
#  '3083': {'ID': '3083',
#   'NM': 'State Representative 04',
#   'OT': 'A',
#   'OO': '47',
#   'DT': 'Connecticut 04',
#   'D': '4'},
#  '3086': {'ID': '3086',
#   'NM': 'State Representative 05',
#   'OT': 'A',
#   'OO': '48',
#   'DT': 'Connecticut 05',
#   'D': '5'},
#  '3089': {'ID': '3089',
#   'NM': 'State Representative 06',
#   'OT': 'A',
#   'OO': '49',
#   'DT': 'Connecticut 06',
#   'D': '6'},
#  '3092': {'ID': '3092',
#   'NM': 'State Representative 07',
#   'OT': 'A',
#   'OO': '50',
#   'DT': 'Connecticut 07',
#   'D': '7'},
#  '3094': {'ID': '3094',
#   'NM': 'State Representative 08',
#   'OT': 'A',
#   'OO': '51',
#   'DT': 'Connecticut 08',
#   'D': '8'},
#  '3097': {'ID': '3097',
#   'NM': 'State Representative 09',
#   'OT': 'A',
#   'OO': '52',
#   'DT': 'Connecticut 09',
#   'D': '9'},
#  '3102': {'ID': '3102',
#   'NM': 'State Representative 10',
#   'OT': 'A',
#   'OO': '53',
#   'DT': 'Connecticut 10',
#   'D': '10'},
#  '3103': {'ID': '3103',
#   'NM': 'State Representative 11',
#   'OT': 'A',
#   'OO': '54',
#   'DT': 'Connecticut 11',
#   'D': '11'},
#  '3104': {'ID': '3104',
#   'NM': 'State Representative 12',
#   'OT': 'A',
#   'OO': '55',
#   'DT': 'Connecticut 12',
#   'D': '12'},
#  '3105': {'ID': '3105',
#   'NM': 'State Representative 13',
#   'OT': 'A',
#   'OO': '56',
#   'DT': 'Connecticut 13',
#   'D': '13'},
#  '3106': {'ID': '3106',
#   'NM': 'State Representative 14',
#   'OT': 'A',
#   'OO': '57',
#   'DT': 'Connecticut 14',
#   'D': '14'},
#  '3107': {'ID': '3107',
#   'NM': 'State Representative 15',
#   'OT': 'A',
#   'OO': '58',
#   'DT': 'Connecticut 15',
#   'D': '15'},
#  '3108': {'ID': '3108',
#   'NM': 'State Representative 16',
#   'OT': 'A',
#   'OO': '59',
#   'DT': 'Connecticut 16',
#   'D': '16'},
#  '3109': {'ID': '3109',
#   'NM': 'State Representative 17',
#   'OT': 'A',
#   'OO': '60',
#   'DT': 'Connecticut 17',
#   'D': '17'},
#  '3110': {'ID': '3110',
#   'NM': 'State Representative 18',
#   'OT': 'A',
#   'OO': '61',
#   'DT': 'Connecticut 18',
#   'D': '18'},
#  '3123': {'ID': '3123',
#   'NM': 'State Representative 19',
#   'OT': 'A',
#   'OO': '62',
#   'DT': 'Connecticut 19',
#   'D': '19'},
#  '3124': {'ID': '3124',
#   'NM': 'State Representative 20',
#   'OT': 'A',
#   'OO': '63',
#   'DT': 'Connecticut 20',
#   'D': '20'},
#  '3125': {'ID': '3125',
#   'NM': 'State Representative 21',
#   'OT': 'A',
#   'OO': '64',
#   'DT': 'Connecticut 21',
#   'D': '21'},
#  '3126': {'ID': '3126',
#   'NM': 'State Representative 22',
#   'OT': 'A',
#   'OO': '65',
#   'DT': 'Connecticut 22',
#   'D': '22'},
#  '3127': {'ID': '3127',
#   'NM': 'State Representative 23',
#   'OT': 'A',
#   'OO': '66',
#   'DT': 'Connecticut 23',
#   'D': '23'},
#  '3128': {'ID': '3128',
#   'NM': 'State Representative 24',
#   'OT': 'A',
#   'OO': '67',
#   'DT': 'Connecticut 24',
#   'D': '24'},
#  '3129': {'ID': '3129',
#   'NM': 'State Representative 25',
#   'OT': 'A',
#   'OO': '68',
#   'DT': 'Connecticut 25',
#   'D': '25'},
#  '3130': {'ID': '3130',
#   'NM': 'State Representative 26',
#   'OT': 'A',
#   'OO': '69',
#   'DT': 'Connecticut 26',
#   'D': '26'},
#  '3131': {'ID': '3131',
#   'NM': 'State Representative 27',
#   'OT': 'A',
#   'OO': '70',
#   'DT': 'Connecticut 27',
#   'D': '27'},
#  '3132': {'ID': '3132',
#   'NM': 'State Representative 28',
#   'OT': 'A',
#   'OO': '71',
#   'DT': 'Connecticut 28',
#   'D': '28'},
#  '3133': {'ID': '3133',
#   'NM': 'State Representative 29',
#   'OT': 'A',
#   'OO': '72',
#   'DT': 'Connecticut 29',
#   'D': '29'},
#  '3134': {'ID': '3134',
#   'NM': 'State Representative 30',
#   'OT': 'A',
#   'OO': '73',
#   'DT': 'Connecticut 30',
#   'D': '30'},
#  '3135': {'ID': '3135',
#   'NM': 'State Representative 31',
#   'OT': 'A',
#   'OO': '74',
#   'DT': 'Connecticut 31',
#   'D': '31'},
#  '3136': {'ID': '3136',
#   'NM': 'State Representative 32',
#   'OT': 'A',
#   'OO': '75',
#   'DT': 'Connecticut 32',
#   'D': '32'},
#  '3137': {'ID': '3137',
#   'NM': 'State Representative 33',
#   'OT': 'A',
#   'OO': '76',
#   'DT': 'Connecticut 33',
#   'D': '33'},
#  '3138': {'ID': '3138',
#   'NM': 'State Representative 34',
#   'OT': 'A',
#   'OO': '77',
#   'DT': 'Connecticut 34',
#   'D': '34'},
#  '3139': {'ID': '3139',
#   'NM': 'State Representative 35',
#   'OT': 'A',
#   'OO': '78',
#   'DT': 'Connecticut 35',
#   'D': '35'},
#  '3140': {'ID': '3140',
#   'NM': 'State Representative 36',
#   'OT': 'A',
#   'OO': '79',
#   'DT': 'Connecticut 36',
#   'D': '36'},
#  '3141': {'ID': '3141',
#   'NM': 'State Representative 37',
#   'OT': 'A',
#   'OO': '80',
#   'DT': 'Connecticut 37',
#   'D': '37'},
#  '3142': {'ID': '3142',
#   'NM': 'State Representative 38',
#   'OT': 'A',
#   'OO': '81',
#   'DT': 'Connecticut 38',
#   'D': '38'},
#  '3143': {'ID': '3143',
#   'NM': 'State Representative 39',
#   'OT': 'A',
#   'OO': '82',
#   'DT': 'Connecticut 39',
#   'D': '39'},
#  '3144': {'ID': '3144',
#   'NM': 'State Representative 40',
#   'OT': 'A',
#   'OO': '83',
#   'DT': 'Connecticut 40',
#   'D': '40'},
#  '3145': {'ID': '3145',
#   'NM': 'State Representative 41',
#   'OT': 'A',
#   'OO': '84',
#   'DT': 'Connecticut 41',
#   'D': '41'},
#  '3146': {'ID': '3146',
#   'NM': 'State Representative 42',
#   'OT': 'A',
#   'OO': '85',
#   'DT': 'Connecticut 42',
#   'D': '42'},
#  '3147': {'ID': '3147',
#   'NM': 'State Representative 43',
#   'OT': 'A',
#   'OO': '86',
#   'DT': 'Connecticut 43',
#   'D': '43'},
#  '3148': {'ID': '3148',
#   'NM': 'State Representative 44',
#   'OT': 'A',
#   'OO': '87',
#   'DT': 'Connecticut 44',
#   'D': '44'},
#  '3149': {'ID': '3149',
#   'NM': 'State Representative 45',
#   'OT': 'A',
#   'OO': '88',
#   'DT': 'Connecticut 45',
#   'D': '45'},
#  '3150': {'ID': '3150',
#   'NM': 'State Representative 46',
#   'OT': 'A',
#   'OO': '89',
#   'DT': 'Connecticut 46',
#   'D': '46'},
#  '3151': {'ID': '3151',
#   'NM': 'State Representative 47',
#   'OT': 'A',
#   'OO': '90',
#   'DT': 'Connecticut 47',
#   'D': '47'},
#  '3152': {'ID': '3152',
#   'NM': 'State Representative 48',
#   'OT': 'A',
#   'OO': '91',
#   'DT': 'Connecticut 48',
#   'D': '48'},
#  '3153': {'ID': '3153',
#   'NM': 'State Representative 49',
#   'OT': 'A',
#   'OO': '92',
#   'DT': 'Connecticut 49',
#   'D': '49'},
#  '3154': {'ID': '3154',
#   'NM': 'State Representative 50',
#   'OT': 'A',
#   'OO': '93',
#   'DT': 'Connecticut 50',
#   'D': '50'},
#  '3155': {'ID': '3155',
#   'NM': 'State Representative 51',
#   'OT': 'A',
#   'OO': '94',
#   'DT': 'Connecticut 51',
#   'D': '51'},
#  '3156': {'ID': '3156',
#   'NM': 'State Representative 52',
#   'OT': 'A',
#   'OO': '95',
#   'DT': 'Connecticut 52',
#   'D': '52'},
#  '3157': {'ID': '3157',
#   'NM': 'State Representative 53',
#   'OT': 'A',
#   'OO': '96',
#   'DT': 'Connecticut 53',
#   'D': '53'},
#  '3158': {'ID': '3158',
#   'NM': 'State Representative 54',
#   'OT': 'A',
#   'OO': '97',
#   'DT': 'Connecticut 54',
#   'D': '54'},
#  '3159': {'ID': '3159',
#   'NM': 'State Representative 55',
#   'OT': 'A',
#   'OO': '98',
#   'DT': 'Connecticut 55',
#   'D': '55'},
#  '3160': {'ID': '3160',
#   'NM': 'State Representative 56',
#   'OT': 'A',
#   'OO': '99',
#   'DT': 'Connecticut 56',
#   'D': '56'},
#  '3161': {'ID': '3161',
#   'NM': 'State Representative 57',
#   'OT': 'A',
#   'OO': '100',
#   'DT': 'Connecticut 57',
#   'D': '57'},
#  '3162': {'ID': '3162',
#   'NM': 'State Representative 58',
#   'OT': 'A',
#   'OO': '101',
#   'DT': 'Connecticut 58',
#   'D': '58'},
#  '3163': {'ID': '3163',
#   'NM': 'State Representative 59',
#   'OT': 'A',
#   'OO': '102',
#   'DT': 'Connecticut 59',
#   'D': '59'},
#  '3164': {'ID': '3164',
#   'NM': 'State Representative 60',
#   'OT': 'A',
#   'OO': '103',
#   'DT': 'Connecticut 60',
#   'D': '60'},
#  '3165': {'ID': '3165',
#   'NM': 'State Representative 61',
#   'OT': 'A',
#   'OO': '104',
#   'DT': 'Connecticut 61',
#   'D': '61'},
#  '3166': {'ID': '3166',
#   'NM': 'State Representative 62',
#   'OT': 'A',
#   'OO': '105',
#   'DT': 'Connecticut 62',
#   'D': '62'},
#  '3167': {'ID': '3167',
#   'NM': 'State Representative 63',
#   'OT': 'A',
#   'OO': '106',
#   'DT': 'Connecticut 63',
#   'D': '63'},
#  '3168': {'ID': '3168',
#   'NM': 'State Representative 64',
#   'OT': 'A',
#   'OO': '107',
#   'DT': 'Connecticut 64',
#   'D': '64'},
#  '3169': {'ID': '3169',
#   'NM': 'State Representative 65',
#   'OT': 'A',
#   'OO': '108',
#   'DT': 'Connecticut 65',
#   'D': '65'},
#  '3170': {'ID': '3170',
#   'NM': 'State Representative 66',
#   'OT': 'A',
#   'OO': '109',
#   'DT': 'Connecticut 66',
#   'D': '66'},
#  '3171': {'ID': '3171',
#   'NM': 'State Representative 67',
#   'OT': 'A',
#   'OO': '110',
#   'DT': 'Connecticut 67',
#   'D': '67'},
#  '3172': {'ID': '3172',
#   'NM': 'State Representative 68',
#   'OT': 'A',
#   'OO': '111',
#   'DT': 'Connecticut 68',
#   'D': '68'},
#  '3173': {'ID': '3173',
#   'NM': 'State Representative 69',
#   'OT': 'A',
#   'OO': '112',
#   'DT': 'Connecticut 69',
#   'D': '69'},
#  '3174': {'ID': '3174',
#   'NM': 'State Representative 70',
#   'OT': 'A',
#   'OO': '113',
#   'DT': 'Connecticut 70',
#   'D': '70'},
#  '3175': {'ID': '3175',
#   'NM': 'State Representative 71',
#   'OT': 'A',
#   'OO': '114',
#   'DT': 'Connecticut 71',
#   'D': '71'},
#  '3176': {'ID': '3176',
#   'NM': 'State Representative 72',
#   'OT': 'A',
#   'OO': '115',
#   'DT': 'Connecticut 72',
#   'D': '72'},
#  '3177': {'ID': '3177',
#   'NM': 'State Representative 73',
#   'OT': 'A',
#   'OO': '116',
#   'DT': 'Connecticut 73',
#   'D': '73'},
#  '3178': {'ID': '3178',
#   'NM': 'State Representative 74',
#   'OT': 'A',
#   'OO': '117',
#   'DT': 'Connecticut 74',
#   'D': '74'},
#  '3179': {'ID': '3179',
#   'NM': 'State Representative 75',
#   'OT': 'A',
#   'OO': '118',
#   'DT': 'Connecticut 75',
#   'D': '75'},
#  '2985': {'ID': '2985',
#   'NM': 'State Representative 76',
#   'OT': 'A',
#   'OO': '119',
#   'DT': 'Connecticut 76',
#   'D': '76'},
#  '2983': {'ID': '2983',
#   'NM': 'State Representative 77',
#   'OT': 'A',
#   'OO': '120',
#   'DT': 'Connecticut 77',
#   'D': '77'},
#  '2981': {'ID': '2981',
#   'NM': 'State Representative 78',
#   'OT': 'A',
#   'OO': '121',
#   'DT': 'Connecticut 78',
#   'D': '78'},
#  '2986': {'ID': '2986',
#   'NM': 'State Representative 79',
#   'OT': 'A',
#   'OO': '122',
#   'DT': 'Connecticut 79',
#   'D': '79'},
#  '2987': {'ID': '2987',
#   'NM': 'State Representative 80',
#   'OT': 'A',
#   'OO': '123',
#   'DT': 'Connecticut 80',
#   'D': '80'},
#  '2989': {'ID': '2989',
#   'NM': 'State Representative 81',
#   'OT': 'A',
#   'OO': '124',
#   'DT': 'Connecticut 81',
#   'D': '81'},
#  '2991': {'ID': '2991',
#   'NM': 'State Representative 82',
#   'OT': 'A',
#   'OO': '125',
#   'DT': 'Connecticut 82',
#   'D': '82'},
#  '2993': {'ID': '2993',
#   'NM': 'State Representative 83',
#   'OT': 'A',
#   'OO': '126',
#   'DT': 'Connecticut 83',
#   'D': '83'},
#  '2996': {'ID': '2996',
#   'NM': 'State Representative 84',
#   'OT': 'A',
#   'OO': '127',
#   'DT': 'Connecticut 84',
#   'D': '84'},
#  '2998': {'ID': '2998',
#   'NM': 'State Representative 85',
#   'OT': 'A',
#   'OO': '128',
#   'DT': 'Connecticut 85',
#   'D': '85'},
#  '3001': {'ID': '3001',
#   'NM': 'State Representative 86',
#   'OT': 'A',
#   'OO': '129',
#   'DT': 'Connecticut 86',
#   'D': '86'},
#  '3002': {'ID': '3002',
#   'NM': 'State Representative 87',
#   'OT': 'A',
#   'OO': '130',
#   'DT': 'Connecticut 87',
#   'D': '87'},
#  '3004': {'ID': '3004',
#   'NM': 'State Representative 88',
#   'OT': 'A',
#   'OO': '131',
#   'DT': 'Connecticut 88',
#   'D': '88'},
#  '3005': {'ID': '3005',
#   'NM': 'State Representative 89',
#   'OT': 'A',
#   'OO': '132',
#   'DT': 'Connecticut 89',
#   'D': '89'},
#  '3006': {'ID': '3006',
#   'NM': 'State Representative 90',
#   'OT': 'A',
#   'OO': '133',
#   'DT': 'Connecticut 90',
#   'D': '90'},
#  '3008': {'ID': '3008',
#   'NM': 'State Representative 91',
#   'OT': 'A',
#   'OO': '134',
#   'DT': 'Connecticut 91',
#   'D': '91'},
#  '3012': {'ID': '3012',
#   'NM': 'State Representative 92',
#   'OT': 'A',
#   'OO': '135',
#   'DT': 'Connecticut 92',
#   'D': '92'},
#  '3015': {'ID': '3015',
#   'NM': 'State Representative 93',
#   'OT': 'A',
#   'OO': '136',
#   'DT': 'Connecticut 93',
#   'D': '93'},
#  '3020': {'ID': '3020',
#   'NM': 'State Representative 94',
#   'OT': 'A',
#   'OO': '137',
#   'DT': 'Connecticut 94',
#   'D': '94'},
#  '3023': {'ID': '3023',
#   'NM': 'State Representative 95',
#   'OT': 'A',
#   'OO': '138',
#   'DT': 'Connecticut 95',
#   'D': '95'},
#  '3025': {'ID': '3025',
#   'NM': 'State Representative 96',
#   'OT': 'A',
#   'OO': '139',
#   'DT': 'Connecticut 96',
#   'D': '96'},
#  '3028': {'ID': '3028',
#   'NM': 'State Representative 97',
#   'OT': 'A',
#   'OO': '140',
#   'DT': 'Connecticut 97',
#   'D': '97'},
#  '3030': {'ID': '3030',
#   'NM': 'State Representative 98',
#   'OT': 'A',
#   'OO': '141',
#   'DT': 'Connecticut 98',
#   'D': '98'},
#  '3033': {'ID': '3033',
#   'NM': 'State Representative 99',
#   'OT': 'A',
#   'OO': '142',
#   'DT': 'Connecticut 99',
#   'D': '99'},
#  '3035': {'ID': '3035',
#   'NM': 'State Representative 100',
#   'OT': 'A',
#   'OO': '143',
#   'DT': 'Connecticut 100',
#   'D': '100'},
#  '3037': {'ID': '3037',
#   'NM': 'State Representative 101',
#   'OT': 'A',
#   'OO': '144',
#   'DT': 'Connecticut 101',
#   'D': '101'},
#  '3040': {'ID': '3040',
#   'NM': 'State Representative 102',
#   'OT': 'A',
#   'OO': '145',
#   'DT': 'Connecticut 102',
#   'D': '102'},
#  '3042': {'ID': '3042',
#   'NM': 'State Representative 103',
#   'OT': 'A',
#   'OO': '146',
#   'DT': 'Connecticut 103',
#   'D': '103'},
#  '3180': {'ID': '3180',
#   'NM': 'State Representative 104',
#   'OT': 'A',
#   'OO': '147',
#   'DT': 'Connecticut 104',
#   'D': '104'},
#  '3047': {'ID': '3047',
#   'NM': 'State Representative 105',
#   'OT': 'A',
#   'OO': '148',
#   'DT': 'Connecticut 105',
#   'D': '105'},
#  '3048': {'ID': '3048',
#   'NM': 'State Representative 106',
#   'OT': 'A',
#   'OO': '149',
#   'DT': 'Connecticut 106',
#   'D': '106'},
#  '3049': {'ID': '3049',
#   'NM': 'State Representative 107',
#   'OT': 'A',
#   'OO': '150',
#   'DT': 'Connecticut 107',
#   'D': '107'},
#  '3050': {'ID': '3050',
#   'NM': 'State Representative 108',
#   'OT': 'A',
#   'OO': '151',
#   'DT': 'Connecticut 108',
#   'D': '108'},
#  '3051': {'ID': '3051',
#   'NM': 'State Representative 109',
#   'OT': 'A',
#   'OO': '152',
#   'DT': 'Connecticut 109',
#   'D': '109'},
#  '3052': {'ID': '3052',
#   'NM': 'State Representative 110',
#   'OT': 'A',
#   'OO': '153',
#   'DT': 'Connecticut 110',
#   'D': '110'},
#  '3053': {'ID': '3053',
#   'NM': 'State Representative 111',
#   'OT': 'A',
#   'OO': '154',
#   'DT': 'Connecticut 111',
#   'D': '111'},
#  '3054': {'ID': '3054',
#   'NM': 'State Representative 112',
#   'OT': 'A',
#   'OO': '155',
#   'DT': 'Connecticut 112',
#   'D': '112'},
#  '3055': {'ID': '3055',
#   'NM': 'State Representative 113',
#   'OT': 'A',
#   'OO': '156',
#   'DT': 'Connecticut 113',
#   'D': '113'},
#  '3056': {'ID': '3056',
#   'NM': 'State Representative 114',
#   'OT': 'A',
#   'OO': '157',
#   'DT': 'Connecticut 114',
#   'D': '114'},
#  '3057': {'ID': '3057',
#   'NM': 'State Representative 115',
#   'OT': 'A',
#   'OO': '158',
#   'DT': 'Connecticut 115',
#   'D': '115'},
#  '3058': {'ID': '3058',
#   'NM': 'State Representative 116',
#   'OT': 'A',
#   'OO': '159',
#   'DT': 'Connecticut 116',
#   'D': '116'},
#  '3059': {'ID': '3059',
#   'NM': 'State Representative 117',
#   'OT': 'A',
#   'OO': '160',
#   'DT': 'Connecticut 117',
#   'D': '117'},
#  '3060': {'ID': '3060',
#   'NM': 'State Representative 118',
#   'OT': 'A',
#   'OO': '161',
#   'DT': 'Connecticut 118',
#   'D': '118'},
#  '3061': {'ID': '3061',
#   'NM': 'State Representative 119',
#   'OT': 'A',
#   'OO': '162',
#   'DT': 'Connecticut 119',
#   'D': '119'},
#  '3062': {'ID': '3062',
#   'NM': 'State Representative 120',
#   'OT': 'A',
#   'OO': '163',
#   'DT': 'Connecticut 120',
#   'D': '120'},
#  '3063': {'ID': '3063',
#   'NM': 'State Representative 121',
#   'OT': 'A',
#   'OO': '164',
#   'DT': 'Connecticut 121',
#   'D': '121'},
#  '3064': {'ID': '3064',
#   'NM': 'State Representative 122',
#   'OT': 'A',
#   'OO': '165',
#   'DT': 'Connecticut 122',
#   'D': '122'},
#  '3065': {'ID': '3065',
#   'NM': 'State Representative 123',
#   'OT': 'A',
#   'OO': '166',
#   'DT': 'Connecticut 123',
#   'D': '123'},
#  '3066': {'ID': '3066',
#   'NM': 'State Representative 124',
#   'OT': 'A',
#   'OO': '167',
#   'DT': 'Connecticut 124',
#   'D': '124'},
#  '3067': {'ID': '3067',
#   'NM': 'State Representative 125',
#   'OT': 'A',
#   'OO': '168',
#   'DT': 'Connecticut 125',
#   'D': '125'},
#  '3069': {'ID': '3069',
#   'NM': 'State Representative 126',
#   'OT': 'A',
#   'OO': '169',
#   'DT': 'Connecticut 126',
#   'D': '126'},
#  '3070': {'ID': '3070',
#   'NM': 'State Representative 127',
#   'OT': 'A',
#   'OO': '170',
#   'DT': 'Connecticut 127',
#   'D': '127'},
#  '3071': {'ID': '3071',
#   'NM': 'State Representative 128',
#   'OT': 'A',
#   'OO': '171',
#   'DT': 'Connecticut 128',
#   'D': '128'},
#  '3072': {'ID': '3072',
#   'NM': 'State Representative 129',
#   'OT': 'A',
#   'OO': '172',
#   'DT': 'Connecticut 129',
#   'D': '129'},
#  '3073': {'ID': '3073',
#   'NM': 'State Representative 130',
#   'OT': 'A',
#   'OO': '173',
#   'DT': 'Connecticut 130',
#   'D': '130'},
#  '3074': {'ID': '3074',
#   'NM': 'State Representative 131',
#   'OT': 'A',
#   'OO': '174',
#   'DT': 'Connecticut 131',
#   'D': '131'},
#  '3075': {'ID': '3075',
#   'NM': 'State Representative 132',
#   'OT': 'A',
#   'OO': '175',
#   'DT': 'Connecticut 132',
#   'D': '132'},
#  '3076': {'ID': '3076',
#   'NM': 'State Representative 133',
#   'OT': 'A',
#   'OO': '176',
#   'DT': 'Connecticut 133',
#   'D': '133'},
#  '3077': {'ID': '3077',
#   'NM': 'State Representative 134',
#   'OT': 'A',
#   'OO': '177',
#   'DT': 'Connecticut 134',
#   'D': '134'},
#  '3078': {'ID': '3078',
#   'NM': 'State Representative 135',
#   'OT': 'A',
#   'OO': '178',
#   'DT': 'Connecticut 135',
#   'D': '135'},
#  '3080': {'ID': '3080',
#   'NM': 'State Representative 136',
#   'OT': 'A',
#   'OO': '179',
#   'DT': 'Connecticut 136',
#   'D': '136'},
#  '3081': {'ID': '3081',
#   'NM': 'State Representative 137',
#   'OT': 'A',
#   'OO': '180',
#   'DT': 'Connecticut 137',
#   'D': '137'},
#  '3082': {'ID': '3082',
#   'NM': 'State Representative 138',
#   'OT': 'A',
#   'OO': '181',
#   'DT': 'Connecticut 138',
#   'D': '138'},
#  '3084': {'ID': '3084',
#   'NM': 'State Representative 139',
#   'OT': 'A',
#   'OO': '182',
#   'DT': 'Connecticut 139',
#   'D': '139'},
#  '3085': {'ID': '3085',
#   'NM': 'State Representative 140',
#   'OT': 'A',
#   'OO': '183',
#   'DT': 'Connecticut 140',
#   'D': '140'},
#  '3087': {'ID': '3087',
#   'NM': 'State Representative 141',
#   'OT': 'A',
#   'OO': '184',
#   'DT': 'Connecticut 141',
#   'D': '141'},
#  '3088': {'ID': '3088',
#   'NM': 'State Representative 142',
#   'OT': 'A',
#   'OO': '185',
#   'DT': 'Connecticut 142',
#   'D': '142'},
#  '3090': {'ID': '3090',
#   'NM': 'State Representative 143',
#   'OT': 'A',
#   'OO': '186',
#   'DT': 'Connecticut 143',
#   'D': '143'},
#  '3091': {'ID': '3091',
#   'NM': 'State Representative 144',
#   'OT': 'A',
#   'OO': '187',
#   'DT': 'Connecticut 144',
#   'D': '144'},
#  '3093': {'ID': '3093',
#   'NM': 'State Representative 145',
#   'OT': 'A',
#   'OO': '188',
#   'DT': 'Connecticut 145',
#   'D': '145'},
#  '3095': {'ID': '3095',
#   'NM': 'State Representative 146',
#   'OT': 'A',
#   'OO': '189',
#   'DT': 'Connecticut 146',
#   'D': '146'},
#  '3096': {'ID': '3096',
#   'NM': 'State Representative 147',
#   'OT': 'A',
#   'OO': '190',
#   'DT': 'Connecticut 147',
#   'D': '147'},
#  '3098': {'ID': '3098',
#   'NM': 'State Representative 148',
#   'OT': 'A',
#   'OO': '191',
#   'DT': 'Connecticut 148',
#   'D': '148'},
#  '3099': {'ID': '3099',
#   'NM': 'State Representative 149',
#   'OT': 'A',
#   'OO': '192',
#   'DT': 'Connecticut 149',
#   'D': '149'},
#  '3100': {'ID': '3100',
#   'NM': 'State Representative 150',
#   'OT': 'A',
#   'OO': '193',
#   'DT': 'Connecticut 150',
#   'D': '150'},
#  '3101': {'ID': '3101',
#   'NM': 'State Representative 151',
#   'OT': 'A',
#   'OO': '194',
#   'DT': 'Connecticut 151',
#   'D': '151'},
#  '2952': {'ID': '2952',
#   'NM': 'Secretary of the State',
#   'OT': 'SW',
#   'OO': '195',
#   'DT': '',
#   'D': '0'},
#  '2953': {'ID': '2953',
#   'NM': 'Treasurer',
#   'OT': 'SW',
#   'OO': '196',
#   'DT': '',
#   'D': '0'},
#  '2954': {'ID': '2954',
#   'NM': 'Comptroller',
#   'OT': 'SW',
#   'OO': '197',
#   'DT': '',
#   'D': '0'},
#  '2955': {'ID': '2955',
#   'NM': 'Attorney General',
#   'OT': 'SW',
#   'OO': '198',
#   'DT': '',
#   'D': '0'},
#  '3183': {'ID': '3183',
#   'NM': 'Judge of Probate 01',
#   'OT': 'PD',
#   'OO': '199',
#   'DT': 'Connecticut 01',
#   'D': '1'},
#  '2957': {'ID': '2957',
#   'NM': 'Judge of Probate 02',
#   'OT': 'PD',
#   'OO': '200',
#   'DT': 'Connecticut 02',
#   'D': '2'},
#  '2958': {'ID': '2958',
#   'NM': 'Judge of Probate 03',
#   'OT': 'PD',
#   'OO': '201',
#   'DT': 'Connecticut 03',
#   'D': '3'},
#  '2959': {'ID': '2959',
#   'NM': 'Judge of Probate 04',
#   'OT': 'PD',
#   'OO': '202',
#   'DT': 'Connecticut 04',
#   'D': '4'},
#  '2960': {'ID': '2960',
#   'NM': 'Judge of Probate 05',
#   'OT': 'PD',
#   'OO': '203',
#   'DT': 'Connecticut 05',
#   'D': '5'},
#  '2961': {'ID': '2961',
#   'NM': 'Judge of Probate 06',
#   'OT': 'PD',
#   'OO': '204',
#   'DT': 'Connecticut 06',
#   'D': '6'},
#  '2962': {'ID': '2962',
#   'NM': 'Judge of Probate 07',
#   'OT': 'PD',
#   'OO': '205',
#   'DT': 'Connecticut 07',
#   'D': '7'},
#  '2963': {'ID': '2963',
#   'NM': 'Judge of Probate 08',
#   'OT': 'PD',
#   'OO': '206',
#   'DT': 'Connecticut 08',
#   'D': '8'},
#  '2964': {'ID': '2964',
#   'NM': 'Judge of Probate 09',
#   'OT': 'PD',
#   'OO': '207',
#   'DT': 'Connecticut 09',
#   'D': '9'},
#  '2965': {'ID': '2965',
#   'NM': 'Judge of Probate 10',
#   'OT': 'PD',
#   'OO': '208',
#   'DT': 'Connecticut 10',
#   'D': '10'},
#  '2966': {'ID': '2966',
#   'NM': 'Judge of Probate 11',
#   'OT': 'PD',
#   'OO': '209',
#   'DT': 'Connecticut 11',
#   'D': '11'},
#  '3293': {'ID': '3293',
#   'NM': 'Judge of Probate to Fill Vacancy 11',
#   'OT': 'PD',
#   'OO': '210',
#   'DT': 'Connecticut 11',
#   'D': '11'},
#  '2967': {'ID': '2967',
#   'NM': 'Judge of Probate 12',
#   'OT': 'PD',
#   'OO': '211',
#   'DT': 'Connecticut 12',
#   'D': '12'},
#  '2968': {'ID': '2968',
#   'NM': 'Judge of Probate 13',
#   'OT': 'PD',
#   'OO': '212',
#   'DT': 'Connecticut 13',
#   'D': '13'},
#  '3230': {'ID': '3230',
#   'NM': 'Judge of Probate 14',
#   'OT': 'PD',
#   'OO': '213',
#   'DT': 'Connecticut 14',
#   'D': '14'},
#  '2970': {'ID': '2970',
#   'NM': 'Judge of Probate 15',
#   'OT': 'PD',
#   'OO': '214',
#   'DT': 'Connecticut 15',
#   'D': '15'},
#  '2971': {'ID': '2971',
#   'NM': 'Judge of Probate 16',
#   'OT': 'PD',
#   'OO': '215',
#   'DT': 'Connecticut 16',
#   'D': '16'},
#  '2979': {'ID': '2979',
#   'NM': 'Judge of Probate 17',
#   'OT': 'PD',
#   'OO': '216',
#   'DT': 'Connecticut 17',
#   'D': '17'},
#  '2974': {'ID': '2974',
#   'NM': 'Judge of Probate 18',
#   'OT': 'PD',
#   'OO': '217',
#   'DT': 'Connecticut 18',
#   'D': '18'},
#  '2980': {'ID': '2980',
#   'NM': 'Judge of Probate 19',
#   'OT': 'PD',
#   'OO': '218',
#   'DT': 'Connecticut 19',
#   'D': '19'},
#  '2982': {'ID': '2982',
#   'NM': 'Judge of Probate 20',
#   'OT': 'PD',
#   'OO': '219',
#   'DT': 'Connecticut 20',
#   'D': '20'},
#  '2984': {'ID': '2984',
#   'NM': 'Judge of Probate 21',
#   'OT': 'PD',
#   'OO': '220',
#   'DT': 'Connecticut 21',
#   'D': '21'},
#  '2988': {'ID': '2988',
#   'NM': 'Judge of Probate 22',
#   'OT': 'PD',
#   'OO': '221',
#   'DT': 'Connecticut 22',
#   'D': '22'},
#  '2992': {'ID': '2992',
#   'NM': 'Judge of Probate 24',
#   'OT': 'PD',
#   'OO': '222',
#   'DT': 'Connecticut 24',
#   'D': '24'},
#  '2994': {'ID': '2994',
#   'NM': 'Judge of Probate 25',
#   'OT': 'PD',
#   'OO': '223',
#   'DT': 'Connecticut 25',
#   'D': '25'},
#  '2995': {'ID': '2995',
#   'NM': 'Judge of Probate 26',
#   'OT': 'PD',
#   'OO': '224',
#   'DT': 'Connecticut 26',
#   'D': '26'},
#  '2997': {'ID': '2997',
#   'NM': 'Judge of Probate 27',
#   'OT': 'PD',
#   'OO': '225',
#   'DT': 'Connecticut 27',
#   'D': '27'},
#  '2999': {'ID': '2999',
#   'NM': 'Judge of Probate 28',
#   'OT': 'PD',
#   'OO': '226',
#   'DT': 'Connecticut 28',
#   'D': '28'},
#  '3000': {'ID': '3000',
#   'NM': 'Judge of Probate 29',
#   'OT': 'PD',
#   'OO': '227',
#   'DT': 'Connecticut 29',
#   'D': '29'},
#  '2990': {'ID': '2990',
#   'NM': 'Judge of Probate 23',
#   'OT': 'PD',
#   'OO': '228',
#   'DT': 'Connecticut 23',
#   'D': '23'},
#  '3003': {'ID': '3003',
#   'NM': 'Judge of Probate 30',
#   'OT': 'PD',
#   'OO': '229',
#   'DT': 'Connecticut 30',
#   'D': '30'},
#  '3007': {'ID': '3007',
#   'NM': 'Judge of Probate 31',
#   'OT': 'PD',
#   'OO': '230',
#   'DT': 'Connecticut 31',
#   'D': '31'},
#  '3009': {'ID': '3009',
#   'NM': 'Judge of Probate 32',
#   'OT': 'PD',
#   'OO': '231',
#   'DT': 'Connecticut 32',
#   'D': '32'},
#  '3010': {'ID': '3010',
#   'NM': 'Judge of Probate 33',
#   'OT': 'PD',
#   'OO': '232',
#   'DT': 'Connecticut 33',
#   'D': '33'},
#  '3011': {'ID': '3011',
#   'NM': 'Judge of Probate 34',
#   'OT': 'PD',
#   'OO': '233',
#   'DT': 'Connecticut 34',
#   'D': '34'},
#  '3013': {'ID': '3013',
#   'NM': 'Judge of Probate 35',
#   'OT': 'PD',
#   'OO': '234',
#   'DT': 'Connecticut 35',
#   'D': '35'},
#  '3014': {'ID': '3014',
#   'NM': 'Judge of Probate 36',
#   'OT': 'PD',
#   'OO': '235',
#   'DT': 'Connecticut 36',
#   'D': '36'},
#  '3016': {'ID': '3016',
#   'NM': 'Judge of Probate 37',
#   'OT': 'PD',
#   'OO': '236',
#   'DT': 'Connecticut 37',
#   'D': '37'},
#  '3017': {'ID': '3017',
#   'NM': 'Judge of Probate 38',
#   'OT': 'PD',
#   'OO': '237',
#   'DT': 'Connecticut 38',
#   'D': '38'},
#  '3018': {'ID': '3018',
#   'NM': 'Judge of Probate 39',
#   'OT': 'PD',
#   'OO': '238',
#   'DT': 'Connecticut 39',
#   'D': '39'},
#  '3019': {'ID': '3019',
#   'NM': 'Judge of Probate 40',
#   'OT': 'PD',
#   'OO': '239',
#   'DT': 'Connecticut 40',
#   'D': '40'},
#  '3021': {'ID': '3021',
#   'NM': 'Judge of Probate 41',
#   'OT': 'PD',
#   'OO': '240',
#   'DT': 'Connecticut 41',
#   'D': '41'},
#  '3046': {'ID': '3046',
#   'NM': 'Judge of Probate 42',
#   'OT': 'PD',
#   'OO': '241',
#   'DT': 'Connecticut 42',
#   'D': '42'},
#  '3024': {'ID': '3024',
#   'NM': 'Judge of Probate 43',
#   'OT': 'PD',
#   'OO': '242',
#   'DT': 'Connecticut 43',
#   'D': '43'},
#  '3026': {'ID': '3026',
#   'NM': 'Judge of Probate 44',
#   'OT': 'PD',
#   'OO': '243',
#   'DT': 'Connecticut 44',
#   'D': '44'},
#  '3027': {'ID': '3027',
#   'NM': 'Judge of Probate 45',
#   'OT': 'PD',
#   'OO': '244',
#   'DT': 'Connecticut 45',
#   'D': '45'},
#  '3029': {'ID': '3029',
#   'NM': 'Judge of Probate 46',
#   'OT': 'PD',
#   'OO': '245',
#   'DT': 'Connecticut 46',
#   'D': '46'},
#  '3031': {'ID': '3031',
#   'NM': 'Judge of Probate 47',
#   'OT': 'PD',
#   'OO': '246',
#   'DT': 'Connecticut 47',
#   'D': '47'},
#  '3032': {'ID': '3032',
#   'NM': 'Judge of Probate 48',
#   'OT': 'PD',
#   'OO': '247',
#   'DT': 'Connecticut 48',
#   'D': '48'},
#  '3034': {'ID': '3034',
#   'NM': 'Judge of Probate 49',
#   'OT': 'PD',
#   'OO': '248',
#   'DT': 'Connecticut 49',
#   'D': '49'},
#  '3292': {'ID': '3292',
#   'NM': 'Judge of Probate to Fill Vacancy 49',
#   'OT': 'PD',
#   'OO': '249',
#   'DT': 'Connecticut 49',
#   'D': '49'},
#  '3036': {'ID': '3036',
#   'NM': 'Judge of Probate 50',
#   'OT': 'PD',
#   'OO': '250',
#   'DT': 'Connecticut 50',
#   'D': '50'},
#  '3038': {'ID': '3038',
#   'NM': 'Judge of Probate 51',
#   'OT': 'PD',
#   'OO': '251',
#   'DT': 'Connecticut 51',
#   'D': '51'},
#  '3039': {'ID': '3039',
#   'NM': 'Judge of Probate 52',
#   'OT': 'PD',
#   'OO': '252',
#   'DT': 'Connecticut 52',
#   'D': '52'},
#  '3041': {'ID': '3041',
#   'NM': 'Judge of Probate 53',
#   'OT': 'PD',
#   'OO': '253',
#   'DT': 'Connecticut 53',
#   'D': '53'},
#  '3043': {'ID': '3043',
#   'NM': 'Judge of Probate 54',
#   'OT': 'PD',
#   'OO': '254',
#   'DT': 'Connecticut 54',
#   'D': '54'},
#  '3316': {'ID': '3316',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '255',
#   'DT': '',
#   'D': '0'},
#  '3367': {'ID': '3367',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '256',
#   'DT': '',
#   'D': '0'},
#  '3195': {'ID': '3195',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '257',
#   'DT': '',
#   'D': '0'},
#  '3347': {'ID': '3347',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '258',
#   'DT': '',
#   'D': '0'},
#  '3196': {'ID': '3196',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '259',
#   'DT': '',
#   'D': '0'},
#  '3187': {'ID': '3187',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '260',
#   'DT': '',
#   'D': '0'},
#  '3192': {'ID': '3192',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '261',
#   'DT': '',
#   'D': '0'},
#  '3205': {'ID': '3205',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '262',
#   'DT': '',
#   'D': '0'},
#  '2879': {'ID': '2879',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '263',
#   'DT': '',
#   'D': '0'},
#  '3365': {'ID': '3365',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '264',
#   'DT': '',
#   'D': '0'},
#  '3185': {'ID': '3185',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '265',
#   'DT': '',
#   'D': '0'},
#  '3189': {'ID': '3189',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '266',
#   'DT': '',
#   'D': '0'},
#  '3197': {'ID': '3197',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '267',
#   'DT': '',
#   'D': '0'},
#  '3194': {'ID': '3194',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '268',
#   'DT': '',
#   'D': '0'},
#  '3198': {'ID': '3198',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '269',
#   'DT': '',
#   'D': '0'},
#  '3361': {'ID': '3361',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '270',
#   'DT': '',
#   'D': '0'},
#  '3223': {'ID': '3223',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '271',
#   'DT': '',
#   'D': '0'},
#  '3218': {'ID': '3218',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '272',
#   'DT': '',
#   'D': '0'},
#  '3217': {'ID': '3217',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '273',
#   'DT': '',
#   'D': '0'},
#  '2883': {'ID': '2883',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '274',
#   'DT': '',
#   'D': '0'},
#  '3377': {'ID': '3377',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '275',
#   'DT': '',
#   'D': '0'},
#  '3204': {'ID': '3204',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '276',
#   'DT': '',
#   'D': '0'},
#  '3219': {'ID': '3219',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '277',
#   'DT': '',
#   'D': '0'},
#  '3222': {'ID': '3222',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '278',
#   'DT': '',
#   'D': '0'},
#  '3224': {'ID': '3224',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '279',
#   'DT': '',
#   'D': '0'},
#  '3226': {'ID': '3226',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '280',
#   'DT': '',
#   'D': '0'},
#  '3228': {'ID': '3228',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '281',
#   'DT': '',
#   'D': '0'},
#  '3215': {'ID': '3215',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '282',
#   'DT': '',
#   'D': '0'},
#  '3233': {'ID': '3233',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '283',
#   'DT': '',
#   'D': '0'},
#  '3235': {'ID': '3235',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '284',
#   'DT': '',
#   'D': '0'},
#  '3190': {'ID': '3190',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '285',
#   'DT': '',
#   'D': '0'},
#  '3238': {'ID': '3238',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '286',
#   'DT': '',
#   'D': '0'},
#  '3243': {'ID': '3243',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '287',
#   'DT': '',
#   'D': '0'},
#  '3245': {'ID': '3245',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '288',
#   'DT': '',
#   'D': '0'},
#  '3247': {'ID': '3247',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '289',
#   'DT': '',
#   'D': '0'},
#  '3248': {'ID': '3248',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '290',
#   'DT': '',
#   'D': '0'},
#  '3249': {'ID': '3249',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '291',
#   'DT': '',
#   'D': '0'},
#  '3252': {'ID': '3252',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '292',
#   'DT': '',
#   'D': '0'},
#  '3253': {'ID': '3253',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '293',
#   'DT': '',
#   'D': '0'},
#  '3254': {'ID': '3254',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '294',
#   'DT': '',
#   'D': '0'},
#  '3265': {'ID': '3265',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '295',
#   'DT': '',
#   'D': '0'},
#  '3266': {'ID': '3266',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '296',
#   'DT': '',
#   'D': '0'},
#  '3297': {'ID': '3297',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '297',
#   'DT': '',
#   'D': '0'},
#  '3269': {'ID': '3269',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '298',
#   'DT': '',
#   'D': '0'},
#  '3272': {'ID': '3272',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '299',
#   'DT': '',
#   'D': '0'},
#  '3276': {'ID': '3276',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '300',
#   'DT': '',
#   'D': '0'},
#  '3277': {'ID': '3277',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '301',
#   'DT': '',
#   'D': '0'},
#  '3280': {'ID': '3280',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '302',
#   'DT': '',
#   'D': '0'},
#  '3281': {'ID': '3281',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '303',
#   'DT': '',
#   'D': '0'},
#  '3283': {'ID': '3283',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '304',
#   'DT': '',
#   'D': '0'},
#  '3284': {'ID': '3284',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '305',
#   'DT': '',
#   'D': '0'},
#  '3286': {'ID': '3286',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '306',
#   'DT': '',
#   'D': '0'},
#  '3287': {'ID': '3287',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '307',
#   'DT': '',
#   'D': '0'},
#  '3288': {'ID': '3288',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '308',
#   'DT': '',
#   'D': '0'},
#  '3289': {'ID': '3289',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '309',
#   'DT': '',
#   'D': '0'},
#  '3294': {'ID': '3294',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '310',
#   'DT': '',
#   'D': '0'},
#  '3295': {'ID': '3295',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '311',
#   'DT': '',
#   'D': '0'},
#  '3296': {'ID': '3296',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '312',
#   'DT': '',
#   'D': '0'},
#  '3298': {'ID': '3298',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '313',
#   'DT': '',
#   'D': '0'},
#  '3299': {'ID': '3299',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '314',
#   'DT': '',
#   'D': '0'},
#  '3300': {'ID': '3300',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '315',
#   'DT': '',
#   'D': '0'},
#  '3302': {'ID': '3302',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '316',
#   'DT': '',
#   'D': '0'},
#  '3303': {'ID': '3303',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '317',
#   'DT': '',
#   'D': '0'},
#  '3304': {'ID': '3304',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '318',
#   'DT': '',
#   'D': '0'},
#  '3306': {'ID': '3306',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '319',
#   'DT': '',
#   'D': '0'},
#  '3307': {'ID': '3307',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '320',
#   'DT': '',
#   'D': '0'},
#  '3309': {'ID': '3309',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '321',
#   'DT': '',
#   'D': '0'},
#  '3311': {'ID': '3311',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '322',
#   'DT': '',
#   'D': '0'},
#  '3313': {'ID': '3313',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '323',
#   'DT': '',
#   'D': '0'},
#  '3314': {'ID': '3314',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '324',
#   'DT': '',
#   'D': '0'},
#  '3315': {'ID': '3315',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '325',
#   'DT': '',
#   'D': '0'},
#  '3317': {'ID': '3317',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '326',
#   'DT': '',
#   'D': '0'},
#  '3318': {'ID': '3318',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '327',
#   'DT': '',
#   'D': '0'},
#  '3320': {'ID': '3320',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '328',
#   'DT': '',
#   'D': '0'},
#  '3321': {'ID': '3321',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '329',
#   'DT': '',
#   'D': '0'},
#  '3259': {'ID': '3259',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '330',
#   'DT': '',
#   'D': '0'},
#  '3333': {'ID': '3333',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '331',
#   'DT': '',
#   'D': '0'},
#  '3339': {'ID': '3339',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '332',
#   'DT': '',
#   'D': '0'},
#  '3340': {'ID': '3340',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '333',
#   'DT': '',
#   'D': '0'},
#  '3341': {'ID': '3341',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '334',
#   'DT': '',
#   'D': '0'},
#  '3348': {'ID': '3348',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '335',
#   'DT': '',
#   'D': '0'},
#  '3349': {'ID': '3349',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '336',
#   'DT': '',
#   'D': '0'},
#  '3285': {'ID': '3285',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '337',
#   'DT': '',
#   'D': '0'},
#  '3350': {'ID': '3350',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '338',
#   'DT': '',
#   'D': '0'},
#  '3301': {'ID': '3301',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '339',
#   'DT': '',
#   'D': '0'},
#  '3357': {'ID': '3357',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '340',
#   'DT': '',
#   'D': '0'},
#  '3212': {'ID': '3212',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '341',
#   'DT': '',
#   'D': '0'},
#  '3214': {'ID': '3214',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '342',
#   'DT': '',
#   'D': '0'},
#  '3370': {'ID': '3370',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '343',
#   'DT': '',
#   'D': '0'},
#  '3371': {'ID': '3371',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '344',
#   'DT': '',
#   'D': '0'},
#  '3372': {'ID': '3372',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '345',
#   'DT': '',
#   'D': '0'},
#  '3346': {'ID': '3346',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '346',
#   'DT': '',
#   'D': '0'},
#  '3355': {'ID': '3355',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '347',
#   'DT': '',
#   'D': '0'},
#  '3356': {'ID': '3356',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '348',
#   'DT': '',
#   'D': '0'},
#  '3345': {'ID': '3345',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '349',
#   'DT': '',
#   'D': '0'},
#  '3362': {'ID': '3362',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '350',
#   'DT': '',
#   'D': '0'},
#  '3343': {'ID': '3343',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '351',
#   'DT': '',
#   'D': '0'},
#  '3358': {'ID': '3358',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '352',
#   'DT': '',
#   'D': '0'},
#  '3363': {'ID': '3363',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '353',
#   'DT': '',
#   'D': '0'},
#  '3376': {'ID': '3376',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '354',
#   'DT': '',
#   'D': '0'},
#  '3186': {'ID': '3186',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '355',
#   'DT': '',
#   'D': '0'},
#  '3378': {'ID': '3378',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '356',
#   'DT': '',
#   'D': '0'},
#  '3380': {'ID': '3380',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '357',
#   'DT': '',
#   'D': '0'},
#  '3366': {'ID': '3366',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '358',
#   'DT': '',
#   'D': '0'},
#  '3373': {'ID': '3373',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '359',
#   'DT': '',
#   'D': '0'},
#  '3270': {'ID': '3270',
#   'NM': 'NonPartisan Board of Education',
#   'OT': 'SM',
#   'OO': '360',
#   'DT': '',
#   'D': '0'},
#  '3351': {'ID': '3351',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '361',
#   'DT': '',
#   'D': '0'},
#  '3382': {'ID': '3382',
#   'NM': 'Registrar of Voters',
#   'OT': 'SM',
#   'OO': '362',
#   'DT': '',
#   'D': '0'},
#  '3322': {'ID': '3322',
#   'NM': 'Board of Education',
#   'OT': 'SM',
#   'OO': '363',
#   'DT': '',
#   'D': '0'},
#  '3330': {'ID': '3330',
#   'NM': 'Non Partisan Representative Town Meeting District I',
#   'OT': 'SM',
#   'OO': '364',
#   'DT': '',
#   'D': '0'},
#  '3331': {'ID': '3331',
#   'NM': 'Non Partisan Representative Town Meeting District II',
#   'OT': 'SM',
#   'OO': '365',
#   'DT': '',
#   'D': '0'},
#  '3328': {'ID': '3328',
#   'NM': 'Non Partisan Representative Town Meeting District III',
#   'OT': 'SM',
#   'OO': '366',
#   'DT': '',
#   'D': '0'},
#  '3329': {'ID': '3329',
#   'NM': 'Non Partisan Representative Town Meeting District IV',
#   'OT': 'SM',
#   'OO': '367',
#   'DT': '',
#   'D': '0'},
#  '3327': {'ID': '3327',
#   'NM': 'Non Partisan Representative Town Meeting District V',
#   'OT': 'SM',
#   'OO': '368',
#   'DT': '',
#   'D': '0'},
#  '3332': {'ID': '3332',
#   'NM': 'Non Partisan Representative Town Meeting District VI',
#   'OT': 'SM',
#   'OO': '369',
#   'DT': '',
#   'D': '0'},
#  '3383': {'ID': '3383',
#   'NM': 'Selectman',
#   'OT': 'SM',
#   'OO': '370',
#   'DT': '',
#   'D': '0'},
#  '3344': {'ID': '3344',
#   'NM': 'Board of Education',
#   'OT': 'SM',
#   'OO': '371',
#   'DT': '',
#   'D': '0'}}

# %%
def get_office(e_data, office_id):
    
    ck = "office_id:%s" % office_id
    cv = get_cache_val(e_data, ck)
    if cv is not None: return cv

    ret = dictify(e_data["lookup_data"]["officeList"])[str(office_id)]
    
    set_cache_val(e_data, ck, ret)
    
    return ret

get_office(general_2018, '2901')
# Out:
# {'ID': '2901',
#  'NM': 'Governor and Lieutenant Governor',
#  'OT': 'SW',
#  'OO': '1',
#  'DT': '',
#  'D': '0'}

# %%
general_2018["election_data"]["stateVotes"]
# Out:
# {'2879': [{'8785': {'V': '838', 'TO': '58.89%'}},
#   {'8786': {'V': '585', 'TO': '41.11%'}}],
#  '2883': [{'8738': {'V': '3702', 'TO': '52.33%'}},
#   {'8739': {'V': '3373', 'TO': '47.67%'}}],
#  '2901': [{'9577': {'V': '676649', 'TO': '48.10%'}},
#   {'9579': {'V': '624750', 'TO': '44.41%'}},
#   {'10025': {'V': '17861', 'TO': '1.27%'}},
#   {'9954': {'V': '25388', 'TO': '1.80%'}},
#   {'9909': {'V': '6086', 'TO': '0.43%'}},
#   {'10039': {'V': '1254', 'TO': '0.09%'}},
#   {'9952': {'V': '54741', 'TO': '3.89%'}},
#   {'10049': {'V': '74', 'TO': '0.01%'}}],
#  '2903': [{'8921': {'V': '787685', 'TO': '56.80%'}},
#   {'9662': {'V': '545717', 'TO': '39.35%'}},
#   {'9943': {'V': '37894', 'TO': '2.73%'}},
#   {'8952': {'V': '8838', 'TO': '0.64%'}},
#   {'8951': {'V': '6618', 'TO': '0.48%'}},
#   {'10051': {'V': '70', 'TO': '0.01%'}},
#   {'10042': {'V': '18', 'TO': '0.00%'}}],
#  '2910': [{'8953': {'V': '166155', 'TO': '60.61%'}},
#   {'8954': {'V': '96024', 'TO': '35.03%'}},
#   {'9723': {'V': '8932', 'TO': '3.26%'}},
#   {'8955': {'V': '3029', 'TO': '1.10%'}}],
#  '2911': [{'8957': {'V': '167659', 'TO': '57.99%'}},
#   {'8958': {'V': '102483', 'TO': '35.45%'}},
#   {'9724': {'V': '12072', 'TO': '4.18%'}},
#   {'8959': {'V': '3305', 'TO': '1.14%'}},
#   {'9502': {'V': '3595', 'TO': '1.24%'}}],
#  '2912': [{'8960': {'V': '163211', 'TO': '60.40%'}},
#   {'8961': {'V': '95667', 'TO': '35.40%'}},
#   {'9770': {'V': '11361', 'TO': '4.20%'}}],
#  '2913': [{'8962': {'V': '168726', 'TO': '61.21%'}},
#   {'8963': {'V': '103175', 'TO': '37.43%'}},
#   {'9750': {'V': '3746', 'TO': '1.36%'}},
#   {'10043': {'V': '4', 'TO': '0.00%'}}],
#  '2914': [{'9553': {'V': '142901', 'TO': '52.80%'}},
#   {'9663': {'V': '115146', 'TO': '42.54%'}},
#   {'9771': {'V': '8324', 'TO': '3.08%'}},
#   {'9680': {'V': '4280', 'TO': '1.58%'}},
#   {'10044': {'V': '13', 'TO': '0.00%'}}],
#  '2915': [{'8969': {'V': '15612', 'TO': '73.98%'}},
#   {'8970': {'V': '5044', 'TO': '23.90%'}},
#   {'8956': {'V': '447', 'TO': '2.12%'}}],
#  '2917': [{'8972': {'V': '22018', 'TO': '60.69%'}},
#   {'8973': {'V': '13464', 'TO': '37.11%'}},
#   {'9794': {'V': '796', 'TO': '2.19%'}}],
#  '2918': [{'8974': {'V': '22303', 'TO': '52.00%'}},
#   {'8975': {'V': '18612', 'TO': '43.40%'}},
#   {'9764': {'V': '954', 'TO': '2.22%'}},
#   {'9795': {'V': '1020', 'TO': '2.38%'}}],
#  '2919': [{'8976': {'V': '30988', 'TO': '65.68%'}},
#   {'8977': {'V': '15471', 'TO': '32.79%'}},
#   {'9931': {'V': '721', 'TO': '1.53%'}}],
#  '2920': [{'8978': {'V': '16087', 'TO': '58.63%'}},
#   {'8979': {'V': '10263', 'TO': '37.41%'}},
#   {'9716': {'V': '1086', 'TO': '3.96%'}}],
#  '2921': [{'8980': {'V': '17416', 'TO': '43.02%'}},
#   {'8981': {'V': '21072', 'TO': '52.06%'}},
#   {'9732': {'V': '1060', 'TO': '2.62%'}},
#   {'9796': {'V': '932', 'TO': '2.30%'}}],
#  '2922': [{'8982': {'V': '20091', 'TO': '43.20%'}},
#   {'8983': {'V': '25242', 'TO': '54.27%'}},
#   {'9751': {'V': '1176', 'TO': '2.53%'}}],
#  '2923': [{'9551': {'V': '22734', 'TO': '54.22%'}},
#   {'9664': {'V': '17674', 'TO': '42.15%'}},
#   {'9914': {'V': '1519', 'TO': '3.62%'}}],
#  '2924': [{'8988': {'V': '19284', 'TO': '84.11%'}},
#   {'8989': {'V': '2745', 'TO': '11.97%'}},
#   {'9854': {'V': '898', 'TO': '3.92%'}}],
#  '2925': [{'8990': {'V': '23787', 'TO': '77.88%'}},
#   {'8991': {'V': '6758', 'TO': '22.12%'}}],
#  '2926': [{'8992': {'V': '24289', 'TO': '49.37%'}},
#   {'8993': {'V': '22967', 'TO': '46.68%'}},
#   {'9733': {'V': '976', 'TO': '1.98%'}},
#   {'9797': {'V': '966', 'TO': '1.96%'}}],
#  '2927': [{'8994': {'V': '18381', 'TO': '49.40%'}},
#   {'8995': {'V': '16866', 'TO': '45.33%'}},
#   {'9741': {'V': '1121', 'TO': '3.01%'}},
#   {'9549': {'V': '842', 'TO': '2.26%'}}],
#  '2928': [{'8996': {'V': '20502', 'TO': '47.89%'}},
#   {'9665': {'V': '20888', 'TO': '48.79%'}},
#   {'9868': {'V': '854', 'TO': '1.99%'}},
#   {'9869': {'V': '570', 'TO': '1.33%'}}],
#  '2929': [{'8999': {'V': '16426', 'TO': '84.72%'}},
#   {'9690': {'V': '2963', 'TO': '15.28%'}}],
#  '2930': [{'9554': {'V': '17162', 'TO': '40.55%'}},
#   {'9001': {'V': '23099', 'TO': '54.58%'}},
#   {'9717': {'V': '1170', 'TO': '2.76%'}},
#   {'9681': {'V': '889', 'TO': '2.10%'}}],
#  '2931': [{'9555': {'V': '17623', 'TO': '47.66%'}},
#   {'9005': {'V': '17544', 'TO': '47.45%'}},
#   {'9718': {'V': '823', 'TO': '2.23%'}},
#   {'9799': {'V': '987', 'TO': '2.67%'}}],
#  '2932': [{'9006': {'V': '16502', 'TO': '43.24%'}},
#   {'9007': {'V': '19584', 'TO': '51.32%'}},
#   {'9719': {'V': '774', 'TO': '2.03%'}},
#   {'9800': {'V': '1303', 'TO': '3.41%'}}],
#  '2933': [{'9008': {'V': '19769', 'TO': '53.49%'}},
#   {'9009': {'V': '14817', 'TO': '40.09%'}},
#   {'9720': {'V': '1620', 'TO': '4.38%'}},
#   {'9801': {'V': '750', 'TO': '2.03%'}}],
#  '2934': [{'9010': {'V': '18203', 'TO': '45.61%'}},
#   {'9011': {'V': '19598', 'TO': '49.11%'}},
#   {'9772': {'V': '961', 'TO': '2.41%'}},
#   {'9802': {'V': '1148', 'TO': '2.88%'}}],
#  '2935': [{'9012': {'V': '18805', 'TO': '43.34%'}},
#   {'9013': {'V': '24589', 'TO': '56.66%'}}],
#  '2936': [{'9014': {'V': '19130', 'TO': '57.09%'}},
#   {'9015': {'V': '13155', 'TO': '39.26%'}},
#   {'10048': {'V': '665', 'TO': '1.98%'}},
#   {'9803': {'V': '557', 'TO': '1.66%'}}],
#  '2937': [{'9016': {'V': '14456', 'TO': '86.80%'}},
#   {'9593': {'V': '2199', 'TO': '13.20%'}}],
#  '2938': [{'9019': {'V': '16400', 'TO': '51.50%'}},
#   {'9020': {'V': '14077', 'TO': '44.21%'}},
#   {'9701': {'V': '786', 'TO': '2.47%'}},
#   {'9804': {'V': '581', 'TO': '1.82%'}}],
#  '2939': [{'9021': {'V': '23629', 'TO': '61.05%'}},
#   {'9022': {'V': '13627', 'TO': '35.21%'}},
#   {'9870': {'V': '815', 'TO': '2.11%'}},
#   {'9805': {'V': '634', 'TO': '1.64%'}}],
#  '2940': [{'9023': {'V': '28159', 'TO': '53.40%'}},
#   {'9024': {'V': '23525', 'TO': '44.61%'}},
#   {'9871': {'V': '1049', 'TO': '1.99%'}}],
#  '2941': [{'9025': {'V': '22161', 'TO': '64.79%'}},
#   {'9026': {'V': '11101', 'TO': '32.46%'}},
#   {'9806': {'V': '548', 'TO': '1.60%'}},
#   {'9027': {'V': '392', 'TO': '1.15%'}}],
#  '2942': [{'9029': {'V': '22610', 'TO': '46.51%'}},
#   {'9030': {'V': '24105', 'TO': '49.59%'}},
#   {'9774': {'V': '726', 'TO': '1.49%'}},
#   {'9807': {'V': '1172', 'TO': '2.41%'}}],
#  '2943': [{'9031': {'V': '17794', 'TO': '52.97%'}},
#   {'9032': {'V': '13706', 'TO': '40.80%'}},
#   {'9747': {'V': '1121', 'TO': '3.34%'}},
#   {'9808': {'V': '973', 'TO': '2.90%'}}],
#  '2944': [{'9033': {'V': '19039', 'TO': '44.14%'}},
#   {'9034': {'V': '22068', 'TO': '51.16%'}},
#   {'9742': {'V': '972', 'TO': '2.25%'}},
#   {'9752': {'V': '1053', 'TO': '2.44%'}}],
#  '2945': [{'9035': {'V': '15762', 'TO': '41.34%'}},
#   {'9036': {'V': '21317', 'TO': '55.91%'}},
#   {'9682': {'V': '1050', 'TO': '2.75%'}}],
#  '2946': [{'9037': {'V': '17501', 'TO': '38.81%'}},
#   {'9038': {'V': '27598', 'TO': '61.19%'}}],
#  '2947': [{'9039': {'V': '25280', 'TO': '50.08%'}},
#   {'9040': {'V': '23906', 'TO': '47.36%'}},
#   {'9809': {'V': '1289', 'TO': '2.55%'}}],
#  '2948': [{'9557': {'V': '16939', 'TO': '41.53%'}},
#   {'9043': {'V': '22826', 'TO': '55.96%'}},
#   {'9753': {'V': '1027', 'TO': '2.52%'}}],
#  '2949': [{'9044': {'V': '19999', 'TO': '44.67%'}},
#   {'9045': {'V': '22837', 'TO': '51.00%'}},
#   {'9971': {'V': '1065', 'TO': '2.38%'}},
#   {'9972': {'V': '874', 'TO': '1.95%'}}],
#  '2950': [{'9046': {'V': '22261', 'TO': '50.43%'}},
#   {'9047': {'V': '21002', 'TO': '47.58%'}},
#   {'10033': {'V': '643', 'TO': '1.46%'}},
#   {'9028': {'V': '238', 'TO': '0.54%'}}],
#  '2951': [{'9076': {'V': '4419', 'TO': '100.00%'}}],
#  '2952': [{'8924': {'V': '735743', 'TO': '53.80%'}},
#   {'8935': {'V': '557616', 'TO': '40.77%'}},
#   {'9745': {'V': '28324', 'TO': '2.07%'}},
#   {'9678': {'V': '23163', 'TO': '1.69%'}},
#   {'9911': {'V': '10361', 'TO': '0.76%'}},
#   {'9767': {'V': '12469', 'TO': '0.91%'}}],
#  '2953': [{'9567': {'V': '717002', 'TO': '52.77%'}},
#   {'9671': {'V': '569737', 'TO': '41.94%'}},
#   {'9734': {'V': '31089', 'TO': '2.29%'}},
#   {'9677': {'V': '23074', 'TO': '1.70%'}},
#   {'9912': {'V': '15514', 'TO': '1.14%'}},
#   {'10052': {'V': '2196', 'TO': '0.16%'}}],
#  '2954': [{'8926': {'V': '718033', 'TO': '52.96%'}},
#   {'9672': {'V': '563099', 'TO': '41.53%'}},
#   {'9765': {'V': '28773', 'TO': '2.12%'}},
#   {'9676': {'V': '22411', 'TO': '1.65%'}},
#   {'9913': {'V': '13165', 'TO': '0.97%'}},
#   {'9768': {'V': '10360', 'TO': '0.76%'}}],
#  '2955': [{'9568': {'V': '691496', 'TO': '50.73%'}},
#   {'9673': {'V': '605504', 'TO': '44.42%'}},
#   {'9735': {'V': '23844', 'TO': '1.75%'}},
#   {'9679': {'V': '27856', 'TO': '2.04%'}},
#   {'9769': {'V': '14358', 'TO': '1.05%'}}],
#  '2957': [{'9407': {'V': '23318', 'TO': '100.00%'}}],
#  '2958': [{'9408': {'V': '17307', 'TO': '100.00%'}}],
#  '2959': [{'9409': {'V': '18557', 'TO': '63.92%'}},
#   {'9410': {'V': '10474', 'TO': '36.08%'}}],
#  '2960': [{'9411': {'V': '10900', 'TO': '100.00%'}}],
#  '2961': [{'9412': {'V': '14932', 'TO': '100.00%'}}],
#  '2962': [{'9414': {'V': '22242', 'TO': '100.00%'}}],
#  '2963': [{'9415': {'V': '13712', 'TO': '61.53%'}},
#   {'9416': {'V': '8572', 'TO': '38.47%'}}],
#  '2964': [{'9417': {'V': '15637', 'TO': '47.80%'}},
#   {'9418': {'V': '17076', 'TO': '52.20%'}}],
#  '2965': [{'9419': {'V': '11186', 'TO': '100.00%'}}],
#  '2966': [{'9420': {'V': '10841', 'TO': '44.60%'}},
#   {'9421': {'V': '13465', 'TO': '55.40%'}}],
#  '2967': [{'9484': {'V': '10461', 'TO': '56.61%'}},
#   {'9422': {'V': '8018', 'TO': '43.39%'}}],
#  '2968': [{'9423': {'V': '19309', 'TO': '100.00%'}}],
#  '2970': [{'9425': {'V': '21657', 'TO': '100.00%'}}],
#  '2971': [{'9426': {'V': '10396', 'TO': '60.00%'}},
#   {'9427': {'V': '6931', 'TO': '40.00%'}}],
#  '2974': [{'9430': {'V': '14972', 'TO': '47.61%'}},
#   {'9429': {'V': '16475', 'TO': '52.39%'}}],
#  '2979': [{'9428': {'V': '12054', 'TO': '100.00%'}}],
#  '2980': [{'9432': {'V': '20006', 'TO': '100.00%'}}],
#  '2981': [{'9239': {'V': '2900', 'TO': '32.27%'}},
#   {'9240': {'V': '5818', 'TO': '64.75%'}},
#   {'9687': {'V': '268', 'TO': '2.98%'}}],
#  '2982': [{'9433': {'V': '20941', 'TO': '100.00%'}}],
#  '2983': [{'9237': {'V': '4396', 'TO': '47.28%'}},
#   {'9238': {'V': '4640', 'TO': '49.91%'}},
#   {'9756': {'V': '261', 'TO': '2.81%'}}],
#  '2984': [{'9435': {'V': '9036', 'TO': '42.58%'}},
#   {'9434': {'V': '12187', 'TO': '57.42%'}}],
#  '2985': [{'9235': {'V': '4190', 'TO': '35.49%'}},
#   {'9236': {'V': '7615', 'TO': '64.51%'}}],
#  '2986': [{'9241': {'V': '3927', 'TO': '54.05%'}},
#   {'9242': {'V': '3156', 'TO': '43.44%'}},
#   {'9757': {'V': '183', 'TO': '2.52%'}}],
#  '2987': [{'9243': {'V': '3338', 'TO': '30.98%'}},
#   {'9244': {'V': '7089', 'TO': '65.79%'}},
#   {'9688': {'V': '289', 'TO': '2.68%'}},
#   {'9898': {'V': '59', 'TO': '0.55%'}}],
#  '2988': [{'9436': {'V': '26616', 'TO': '100.00%'}}],
#  '2989': [{'9245': {'V': '4286', 'TO': '41.22%'}},
#   {'9246': {'V': '5586', 'TO': '53.73%'}},
#   {'9785': {'V': '252', 'TO': '2.42%'}},
#   {'9758': {'V': '273', 'TO': '2.63%'}}],
#  '2990': [{'9956': {'V': '9281', 'TO': '36.30%'}},
#   {'9437': {'V': '16289', 'TO': '63.70%'}}],
#  '2991': [{'9247': {'V': '5401', 'TO': '59.35%'}},
#   {'9248': {'V': '3699', 'TO': '40.65%'}}],
#  '2992': [{'9439': {'V': '13258', 'TO': '100.00%'}}],
#  '2993': [{'9249': {'V': '4765', 'TO': '51.06%'}},
#   {'9250': {'V': '4251', 'TO': '45.55%'}},
#   {'9889': {'V': '199', 'TO': '2.13%'}},
#   {'9863': {'V': '117', 'TO': '1.25%'}}],
#  '2994': [{'9440': {'V': '17327', 'TO': '100.00%'}}],
#  '2995': [{'9441': {'V': '8605', 'TO': '49.12%'}},
#   {'9442': {'V': '8915', 'TO': '50.88%'}}],
#  '2996': [{'9251': {'V': '3513', 'TO': '100.00%'}}],
#  '2997': [{'9569': {'V': '6864', 'TO': '49.65%'}},
#   {'9446': {'V': '6961', 'TO': '50.35%'}}],
#  '2998': [{'9252': {'V': '4763', 'TO': '52.05%'}},
#   {'9253': {'V': '3857', 'TO': '42.15%'}},
#   {'9710': {'V': '337', 'TO': '3.68%'}},
#   {'9938': {'V': '194', 'TO': '2.12%'}}],
#  '2999': [{'9447': {'V': '13534', 'TO': '100.00%'}}],
#  '3000': [{'9448': {'V': '15523', 'TO': '100.00%'}}],
#  '3001': [{'9254': {'V': '3961', 'TO': '36.34%'}},
#   {'9255': {'V': '6506', 'TO': '59.68%'}},
#   {'9759': {'V': '290', 'TO': '2.66%'}},
#   {'9866': {'V': '144', 'TO': '1.32%'}}],
#  '3002': [{'9256': {'V': '4308', 'TO': '35.66%'}},
#   {'9257': {'V': '7428', 'TO': '61.49%'}},
#   {'9760': {'V': '344', 'TO': '2.85%'}}],
#  '3003': [{'9450': {'V': '18117', 'TO': '60.69%'}},
#   {'9449': {'V': '11736', 'TO': '39.31%'}}],
#  '3004': [{'9258': {'V': '6218', 'TO': '66.52%'}},
#   {'9259': {'V': '2786', 'TO': '29.81%'}},
#   {'9738': {'V': '343', 'TO': '3.67%'}}],
#  '3005': [{'9260': {'V': '4367', 'TO': '36.42%'}},
#   {'9261': {'V': '7348', 'TO': '61.28%'}},
#   {'9689': {'V': '275', 'TO': '2.29%'}}],
#  '3006': [{'9262': {'V': '4789', 'TO': '43.23%'}},
#   {'9263': {'V': '5683', 'TO': '51.30%'}},
#   {'9890': {'V': '361', 'TO': '3.26%'}},
#   {'9761': {'V': '246', 'TO': '2.22%'}}],
#  '3007': [{'9451': {'V': '9823', 'TO': '66.62%'}},
#   {'9452': {'V': '4922', 'TO': '33.38%'}}],
#  '3008': [{'9264': {'V': '7841', 'TO': '92.14%'}},
#   {'9891': {'V': '669', 'TO': '7.86%'}}],
#  '3009': [{'9454': {'V': '10349', 'TO': '48.82%'}},
#   {'9453': {'V': '10850', 'TO': '51.18%'}}],
#  '3010': [{'9455': {'V': '20935', 'TO': '100.00%'}}],
#  '3011': [{'9456': {'V': '13069', 'TO': '59.05%'}},
#   {'9457': {'V': '9064', 'TO': '40.95%'}}],
#  '3012': [{'9266': {'V': '6221', 'TO': '86.13%'}},
#   {'9265': {'V': '627', 'TO': '8.68%'}},
#   {'9857': {'V': '344', 'TO': '4.76%'}},
#   {'9899': {'V': '31', 'TO': '0.43%'}}],
#  '3013': [{'9458': {'V': '13460', 'TO': '100.00%'}}],
#  '3014': [{'9459': {'V': '15522', 'TO': '100.00%'}}],
#  '3015': [{'9267': {'V': '4782', 'TO': '93.91%'}},
#   {'9268': {'V': '310', 'TO': '6.09%'}}],
#  '3016': [{'9460': {'V': '20311', 'TO': '100.00%'}}],
#  '3017': [{'9461': {'V': '27577', 'TO': '100.00%'}}],
#  '3018': [{'9462': {'V': '11836', 'TO': '100.00%'}}],
#  '3019': [{'9463': {'V': '17679', 'TO': '56.18%'}},
#   {'9464': {'V': '13788', 'TO': '43.82%'}}],
#  '3020': [{'9269': {'V': '6043', 'TO': '86.51%'}},
#   {'9270': {'V': '743', 'TO': '10.64%'}},
#   {'9711': {'V': '199', 'TO': '2.85%'}}],
#  '3021': [{'9465': {'V': '13928', 'TO': '100.00%'}}],
#  '3023': [{'9271': {'V': '3166', 'TO': '88.19%'}},
#   {'9272': {'V': '424', 'TO': '11.81%'}}],
#  '3024': [{'9467': {'V': '13147', 'TO': '100.00%'}}],
#  '3025': [{'9273': {'V': '6183', 'TO': '74.98%'}},
#   {'9274': {'V': '1598', 'TO': '19.38%'}},
#   {'9786': {'V': '465', 'TO': '5.64%'}}],
#  '3026': [{'9468': {'V': '20072', 'TO': '100.00%'}}],
#  '3027': [{'9469': {'V': '25290', 'TO': '100.00%'}}],
#  '3028': [{'9275': {'V': '4890', 'TO': '80.20%'}},
#   {'9276': {'V': '1207', 'TO': '19.80%'}}],
#  '3029': [{'9471': {'V': '11957', 'TO': '40.59%'}},
#   {'9470': {'V': '16905', 'TO': '57.38%'}},
#   {'9853': {'V': '599', 'TO': '2.03%'}}],
#  '3030': [{'9277': {'V': '8572', 'TO': '90.86%'}},
#   {'9712': {'V': '862', 'TO': '9.14%'}}],
#  '3031': [{'9472': {'V': '10155', 'TO': '52.01%'}},
#   {'9473': {'V': '8814', 'TO': '45.14%'}},
#   {'9923': {'V': '556', 'TO': '2.85%'}}],
#  '3032': [{'9474': {'V': '23068', 'TO': '100.00%'}}],
#  '3033': [{'9278': {'V': '4502', 'TO': '53.60%'}},
#   {'9537': {'V': '3407', 'TO': '40.56%'}},
#   {'9739': {'V': '384', 'TO': '4.57%'}},
#   {'9762': {'V': '107', 'TO': '1.27%'}}],
#  '3034': [{'9476': {'V': '16574', 'TO': '60.89%'}},
#   {'9475': {'V': '10105', 'TO': '37.12%'}},
#   {'9924': {'V': '540', 'TO': '1.98%'}}],
#  '3035': [{'9280': {'V': '5033', 'TO': '55.86%'}},
#   {'9667': {'V': '3534', 'TO': '39.22%'}},
#   {'9729': {'V': '443', 'TO': '4.92%'}}],
#  '3036': [{'9477': {'V': '11433', 'TO': '100.00%'}}],
#  '3037': [{'9282': {'V': '6241', 'TO': '49.93%'}},
#   {'9283': {'V': '6009', 'TO': '48.07%'}},
#   {'9834': {'V': '250', 'TO': '2.00%'}}],
#  '3038': [{'9570': {'V': '23180', 'TO': '56.86%'}},
#   {'9480': {'V': '16557', 'TO': '40.61%'}},
#   {'9864': {'V': '1031', 'TO': '2.53%'}}],
#  '3039': [{'9481': {'V': '13679', 'TO': '100.00%'}}],
#  '3040': [{'9297': {'V': '5856', 'TO': '52.85%'}},
#   {'9298': {'V': '4753', 'TO': '42.89%'}},
#   {'9974': {'V': '241', 'TO': '2.17%'}},
#   {'9915': {'V': '231', 'TO': '2.08%'}}],
#  '3041': [{'9482': {'V': '31822', 'TO': '100.00%'}}],
#  '3042': [{'9299': {'V': '5188', 'TO': '51.57%'}},
#   {'9300': {'V': '4680', 'TO': '46.52%'}},
#   {'9835': {'V': '193', 'TO': '1.92%'}}],
#  '3043': [{'9483': {'V': '17106', 'TO': '100.00%'}}],
#  '3046': [{'9466': {'V': '13144', 'TO': '100.00%'}}],
#  '3047': [{'9303': {'V': '3346', 'TO': '32.23%'}},
#   {'9304': {'V': '6697', 'TO': '64.51%'}},
#   {'9837': {'V': '338', 'TO': '3.26%'}}],
#  '3048': [{'9305': {'V': '5297', 'TO': '46.99%'}},
#   {'9306': {'V': '5697', 'TO': '50.54%'}},
#   {'9955': {'V': '278', 'TO': '2.47%'}}],
#  '3049': [{'9307': {'V': '4736', 'TO': '40.74%'}},
#   {'9308': {'V': '6556', 'TO': '56.39%'}},
#   {'9839': {'V': '334', 'TO': '2.87%'}}],
#  '3050': [{'9309': {'V': '6383', 'TO': '100.00%'}}],
#  '3051': [{'9310': {'V': '3555', 'TO': '59.54%'}},
#   {'9311': {'V': '2066', 'TO': '34.60%'}},
#   {'9730': {'V': '252', 'TO': '4.22%'}},
#   {'9939': {'V': '98', 'TO': '1.64%'}}],
#  '3052': [{'9312': {'V': '2367', 'TO': '69.01%'}},
#   {'9313': {'V': '880', 'TO': '25.66%'}},
#   {'9740': {'V': '130', 'TO': '3.79%'}},
#   {'9940': {'V': '53', 'TO': '1.55%'}}],
#  '3053': [{'9315': {'V': '5888', 'TO': '48.21%'}},
#   {'9314': {'V': '6048', 'TO': '49.52%'}},
#   {'10034': {'V': '278', 'TO': '2.28%'}}],
#  '3054': [{'9316': {'V': '6932', 'TO': '86.73%'}},
#   {'9840': {'V': '1061', 'TO': '13.27%'}}],
#  '3055': [{'9317': {'V': '3347', 'TO': '34.94%'}},
#   {'9318': {'V': '6233', 'TO': '65.06%'}}],
#  '3056': [{'9319': {'V': '5033', 'TO': '43.78%'}},
#   {'9320': {'V': '6022', 'TO': '52.39%'}},
#   {'9860': {'V': '213', 'TO': '1.85%'}},
#   {'9841': {'V': '227', 'TO': '1.97%'}}],
#  '3057': [{'9321': {'V': '4814', 'TO': '67.27%'}},
#   {'9322': {'V': '2016', 'TO': '28.17%'}},
#   {'9788': {'V': '326', 'TO': '4.56%'}}],
#  '3058': [{'9323': {'V': '3643', 'TO': '71.60%'}},
#   {'9668': {'V': '1299', 'TO': '25.53%'}},
#   {'9789': {'V': '146', 'TO': '2.87%'}}],
#  '3059': [{'9325': {'V': '4626', 'TO': '42.46%'}},
#   {'9326': {'V': '5823', 'TO': '53.45%'}},
#   {'9861': {'V': '241', 'TO': '2.21%'}},
#   {'9842': {'V': '204', 'TO': '1.87%'}}],
#  '3060': [{'9327': {'V': '5404', 'TO': '53.42%'}},
#   {'9328': {'V': '4421', 'TO': '43.70%'}},
#   {'9843': {'V': '292', 'TO': '2.89%'}}],
#  '3061': [{'9329': {'V': '5044', 'TO': '44.52%'}},
#   {'9330': {'V': '6063', 'TO': '53.51%'}},
#   {'9790': {'V': '224', 'TO': '1.98%'}}],
#  '3062': [{'9331': {'V': '5222', 'TO': '49.80%'}},
#   {'9332': {'V': '5028', 'TO': '47.95%'}},
#   {'9844': {'V': '181', 'TO': '1.73%'}},
#   {'9925': {'V': '55', 'TO': '0.52%'}}],
#  '3063': [{'9333': {'V': '5376', 'TO': '70.27%'}},
#   {'9334': {'V': '2164', 'TO': '28.29%'}},
#   {'9917': {'V': '110', 'TO': '1.44%'}}],
#  '3064': [{'9335': {'V': '4430', 'TO': '38.74%'}},
#   {'9336': {'V': '7006', 'TO': '61.26%'}}],
#  '3065': [{'9337': {'V': '4868', 'TO': '44.35%'}},
#   {'9338': {'V': '5705', 'TO': '51.97%'}},
#   {'9918': {'V': '194', 'TO': '1.77%'}},
#   {'9845': {'V': '210', 'TO': '1.91%'}}],
#  '3066': [{'9340': {'V': '3971', 'TO': '89.66%'}},
#   {'9339': {'V': '458', 'TO': '10.34%'}}],
#  '3067': [{'9341': {'V': '4959', 'TO': '43.19%'}},
#   {'9342': {'V': '6522', 'TO': '56.81%'}}],
#  '3068': [{'9079': {'V': '5245', 'TO': '50.57%'}},
#   {'9082': {'V': '4623', 'TO': '44.57%'}},
#   {'9775': {'V': '264', 'TO': '2.55%'}},
#   {'9810': {'V': '240', 'TO': '2.31%'}}],
#  '3069': [{'9564': {'V': '5362', 'TO': '84.32%'}},
#   {'9950': {'V': '997', 'TO': '15.68%'}}],
#  '3070': [{'9346': {'V': '3965', 'TO': '73.13%'}},
#   {'9347': {'V': '1341', 'TO': '24.73%'}},
#   {'9791': {'V': '116', 'TO': '2.14%'}}],
#  '3071': [{'9348': {'V': '2366', 'TO': '88.18%'}},
#   {'9669': {'V': '317', 'TO': '11.82%'}}],
#  '3072': [{'9350': {'V': '4507', 'TO': '82.20%'}},
#   {'9351': {'V': '976', 'TO': '17.80%'}}],
#  '3073': [{'9352': {'V': '3202', 'TO': '89.84%'}},
#   {'9353': {'V': '362', 'TO': '10.16%'}}],
#  '3074': [{'9354': {'V': '3371', 'TO': '32.35%'}},
#   {'9355': {'V': '7048', 'TO': '67.65%'}}],
#  '3075': [{'9356': {'V': '5432', 'TO': '45.40%'}},
#   {'9357': {'V': '6186', 'TO': '51.70%'}},
#   {'9846': {'V': '347', 'TO': '2.90%'}}],
#  '3076': [{'9358': {'V': '5845', 'TO': '61.36%'}},
#   {'9359': {'V': '3241', 'TO': '34.03%'}},
#   {'9713': {'V': '236', 'TO': '2.48%'}},
#   {'9847': {'V': '203', 'TO': '2.13%'}}],
#  '3077': [{'9360': {'V': '5251', 'TO': '47.82%'}},
#   {'9361': {'V': '5516', 'TO': '50.24%'}},
#   {'9848': {'V': '213', 'TO': '1.94%'}}],
#  '3078': [{'9362': {'V': '6449', 'TO': '52.82%'}},
#   {'9363': {'V': '5393', 'TO': '44.17%'}},
#   {'9919': {'V': '118', 'TO': '0.97%'}},
#   {'9849': {'V': '183', 'TO': '1.50%'}},
#   {'9748': {'V': '66', 'TO': '0.54%'}}],
#  '3079': [{'9558': {'V': '2975', 'TO': '100.00%'}}],
#  '3080': [{'9364': {'V': '7945', 'TO': '61.34%'}},
#   {'9365': {'V': '4704', 'TO': '36.32%'}},
#   {'9850': {'V': '304', 'TO': '2.35%'}}],
#  '3081': [{'9366': {'V': '6076', 'TO': '66.60%'}},
#   {'9367': {'V': '2662', 'TO': '29.18%'}},
#   {'9793': {'V': '247', 'TO': '2.71%'}},
#   {'9851': {'V': '138', 'TO': '1.51%'}}],
#  '3082': [{'9368': {'V': '4658', 'TO': '49.23%'}},
#   {'9369': {'V': '4395', 'TO': '46.45%'}},
#   {'9731': {'V': '168', 'TO': '1.78%'}},
#   {'9941': {'V': '240', 'TO': '2.54%'}}],
#  '3083': [{'9090': {'V': '2733', 'TO': '79.26%'}},
#   {'9092': {'V': '335', 'TO': '9.72%'}},
#   {'9944': {'V': '321', 'TO': '9.31%'}},
#   {'9945': {'V': '59', 'TO': '1.71%'}}],
#  '3084': [{'9370': {'V': '3925', 'TO': '49.61%'}},
#   {'9371': {'V': '3467', 'TO': '43.83%'}},
#   {'9792': {'V': '284', 'TO': '3.59%'}},
#   {'9920': {'V': '235', 'TO': '2.97%'}}],
#  '3085': [{'9565': {'V': '3844', 'TO': '69.95%'}},
#   {'9373': {'V': '974', 'TO': '17.73%'}},
#   {'9714': {'V': '579', 'TO': '10.54%'}},
#   {'9951': {'V': '98', 'TO': '1.78%'}}],
#  '3086': [{'9559': {'V': '6474', 'TO': '84.98%'}},
#   {'9099': {'V': '1144', 'TO': '15.02%'}}],
#  '3087': [{'9374': {'V': '7237', 'TO': '86.86%'}},
#   {'9942': {'V': '1095', 'TO': '13.14%'}}],
#  '3088': [{'9375': {'V': '5790', 'TO': '52.69%'}},
#   {'9376': {'V': '4797', 'TO': '43.65%'}},
#   {'9715': {'V': '203', 'TO': '1.85%'}},
#   {'9852': {'V': '199', 'TO': '1.81%'}}],
#  '3089': [{'9100': {'V': '3563', 'TO': '84.41%'}},
#   {'9101': {'V': '516', 'TO': '12.22%'}},
#   {'9703': {'V': '142', 'TO': '3.36%'}}],
#  '3090': [{'9485': {'V': '5586', 'TO': '47.23%'}},
#   {'9377': {'V': '5833', 'TO': '49.32%'}},
#   {'9922': {'V': '147', 'TO': '1.24%'}},
#   {'9892': {'V': '261', 'TO': '2.21%'}}],
#  '3091': [{'9486': {'V': '7242', 'TO': '100.00%'}}],
#  '3092': [{'9102': {'V': '4098', 'TO': '94.58%'}},
#   {'9725': {'V': '143', 'TO': '3.30%'}},
#   {'9495': {'V': '92', 'TO': '2.12%'}}],
#  '3093': [{'9380': {'V': '4580', 'TO': '82.60%'}},
#   {'9381': {'V': '965', 'TO': '17.40%'}}],
#  '3094': [{'9103': {'V': '4597', 'TO': '37.66%'}},
#   {'9104': {'V': '7610', 'TO': '62.34%'}}],
#  '3095': [{'9566': {'V': '5913', 'TO': '72.37%'}},
#   {'9383': {'V': '2257', 'TO': '27.63%'}}],
#  '3096': [{'9384': {'V': '6187', 'TO': '58.85%'}},
#   {'9670': {'V': '4153', 'TO': '39.50%'}},
#   {'9893': {'V': '173', 'TO': '1.65%'}}],
#  '3097': [{'9105': {'V': '6042', 'TO': '88.04%'}},
#   {'9700': {'V': '821', 'TO': '11.96%'}}],
#  '3098': [{'9386': {'V': '5013', 'TO': '75.76%'}},
#   {'9387': {'V': '1604', 'TO': '24.24%'}}],
#  '3099': [{'9388': {'V': '6971', 'TO': '100.00%'}}],
#  '3100': [{'9389': {'V': '4859', 'TO': '52.12%'}},
#   {'9390': {'V': '4272', 'TO': '45.82%'}},
#   {'9894': {'V': '192', 'TO': '2.06%'}}],
#  '3101': [{'9391': {'V': '4786', 'TO': '43.78%'}},
#   {'9392': {'V': '5918', 'TO': '54.14%'}},
#   {'9966': {'V': '227', 'TO': '2.08%'}}],
#  '3102': [{'9106': {'V': '5236', 'TO': '100.00%'}}],
#  '3103': [{'9107': {'V': '4547', 'TO': '100.00%'}}],
#  '3104': [{'9108': {'V': '5327', 'TO': '59.18%'}},
#   {'9109': {'V': '3345', 'TO': '37.16%'}},
#   {'9704': {'V': '329', 'TO': '3.66%'}}],
#  '3105': [{'9110': {'V': '5799', 'TO': '56.09%'}},
#   {'9111': {'V': '4053', 'TO': '39.20%'}},
#   {'9726': {'V': '232', 'TO': '2.24%'}},
#   {'9811': {'V': '255', 'TO': '2.47%'}}],
#  '3106': [{'9112': {'V': '4976', 'TO': '43.53%'}},
#   {'9113': {'V': '5929', 'TO': '51.87%'}},
#   {'9776': {'V': '187', 'TO': '1.64%'}},
#   {'9812': {'V': '339', 'TO': '2.97%'}}],
#  '3107': [{'9114': {'V': '9268', 'TO': '95.59%'}},
#   {'9872': {'V': '428', 'TO': '4.41%'}}],
#  '3108': [{'9115': {'V': '7625', 'TO': '59.44%'}},
#   {'9116': {'V': '4935', 'TO': '38.47%'}},
#   {'9604': {'V': '218', 'TO': '1.70%'}},
#   {'9496': {'V': '51', 'TO': '0.40%'}}],
#  '3109': [{'9117': {'V': '5929', 'TO': '47.67%'}},
#   {'9118': {'V': '6004', 'TO': '48.28%'}},
#   {'9947': {'V': '230', 'TO': '1.85%'}},
#   {'9962': {'V': '274', 'TO': '2.20%'}}],
#  '3110': [{'9560': {'V': '7608', 'TO': '71.88%'}},
#   {'9120': {'V': '2783', 'TO': '26.29%'}},
#   {'9932': {'V': '194', 'TO': '1.83%'}}],
#  '3123': [{'9121': {'V': '9515', 'TO': '100.00%'}}],
#  '3124': [{'9122': {'V': '7220', 'TO': '100.00%'}}],
#  '3125': [{'9123': {'V': '6323', 'TO': '53.96%'}},
#   {'9124': {'V': '4918', 'TO': '41.97%'}},
#   {'9727': {'V': '290', 'TO': '2.47%'}},
#   {'9933': {'V': '187', 'TO': '1.60%'}}],
#  '3126': [{'9125': {'V': '2989', 'TO': '34.25%'}},
#   {'9126': {'V': '5297', 'TO': '60.70%'}},
#   {'9683': {'V': '441', 'TO': '5.05%'}}],
#  '3127': [{'9131': {'V': '5566', 'TO': '43.11%'}},
#   {'9132': {'V': '6854', 'TO': '53.08%'}},
#   {'9874': {'V': '184', 'TO': '1.43%'}},
#   {'9813': {'V': '308', 'TO': '2.39%'}}],
#  '3128': [{'9133': {'V': '3945', 'TO': '56.73%'}},
#   {'9134': {'V': '2699', 'TO': '38.81%'}},
#   {'9736': {'V': '310', 'TO': '4.46%'}}],
#  '3129': [{'9135': {'V': '3075', 'TO': '91.33%'}},
#   {'9777': {'V': '216', 'TO': '6.42%'}},
#   {'9497': {'V': '76', 'TO': '2.26%'}}],
#  '3130': [{'9136': {'V': '3440', 'TO': '64.92%'}},
#   {'9137': {'V': '1601', 'TO': '30.21%'}},
#   {'9855': {'V': '258', 'TO': '4.87%'}}],
#  '3131': [{'9138': {'V': '5215', 'TO': '47.77%'}},
#   {'9139': {'V': '5171', 'TO': '47.37%'}},
#   {'9778': {'V': '276', 'TO': '2.53%'}},
#   {'9814': {'V': '254', 'TO': '2.33%'}}],
#  '3132': [{'9140': {'V': '6273', 'TO': '54.89%'}},
#   {'9141': {'V': '4691', 'TO': '41.04%'}},
#   {'9705': {'V': '290', 'TO': '2.54%'}},
#   {'9934': {'V': '175', 'TO': '1.53%'}}],
#  '3133': [{'9561': {'V': '5817', 'TO': '55.72%'}},
#   {'9144': {'V': '4622', 'TO': '44.28%'}}],
#  '3134': [{'9145': {'V': '5499', 'TO': '46.82%'}},
#   {'10041': {'V': '5848', 'TO': '49.79%'}},
#   {'9779': {'V': '399', 'TO': '3.40%'}}],
#  '3135': [{'9147': {'V': '6303', 'TO': '48.58%'}},
#   {'9148': {'V': '6192', 'TO': '47.72%'}},
#   {'9706': {'V': '237', 'TO': '1.83%'}},
#   {'9935': {'V': '243', 'TO': '1.87%'}}],
#  '3136': [{'9149': {'V': '4655', 'TO': '40.46%'}},
#   {'9150': {'V': '6298', 'TO': '54.74%'}},
#   {'9875': {'V': '266', 'TO': '2.31%'}},
#   {'9815': {'V': '286', 'TO': '2.49%'}}],
#  '3137': [{'9151': {'V': '5356', 'TO': '62.09%'}},
#   {'9152': {'V': '3096', 'TO': '35.89%'}},
#   {'9936': {'V': '174', 'TO': '2.02%'}}],
#  '3138': [{'9153': {'V': '5183', 'TO': '45.41%'}},
#   {'9154': {'V': '5631', 'TO': '49.33%'}},
#   {'9876': {'V': '295', 'TO': '2.58%'}},
#   {'9816': {'V': '305', 'TO': '2.67%'}}],
#  '3139': [{'9155': {'V': '5461', 'TO': '45.96%'}},
#   {'9156': {'V': '5979', 'TO': '50.32%'}},
#   {'9817': {'V': '261', 'TO': '2.20%'}},
#   {'9157': {'V': '181', 'TO': '1.52%'}}],
#  '3140': [{'9158': {'V': '6338', 'TO': '49.01%'}},
#   {'9159': {'V': '6078', 'TO': '47.00%'}},
#   {'9877': {'V': '234', 'TO': '1.81%'}},
#   {'9818': {'V': '282', 'TO': '2.18%'}}],
#  '3141': [{'9160': {'V': '5244', 'TO': '46.73%'}},
#   {'9161': {'V': '5473', 'TO': '48.77%'}},
#   {'9929': {'V': '212', 'TO': '1.89%'}},
#   {'9819': {'V': '293', 'TO': '2.61%'}}],
#  '3142': [{'9575': {'V': '5088', 'TO': '46.04%'}},
#   {'9164': {'V': '5362', 'TO': '48.52%'}},
#   {'9820': {'V': '339', 'TO': '3.07%'}},
#   {'9590': {'V': '262', 'TO': '2.37%'}}],
#  '3143': [{'9165': {'V': '4136', 'TO': '93.98%'}},
#   {'9766': {'V': '265', 'TO': '6.02%'}}],
#  '3144': [{'9166': {'V': '3572', 'TO': '54.66%'}},
#   {'9167': {'V': '2557', 'TO': '39.13%'}},
#   {'9728': {'V': '243', 'TO': '3.72%'}},
#   {'9821': {'V': '163', 'TO': '2.49%'}}],
#  '3145': [{'9168': {'V': '5526', 'TO': '61.85%'}},
#   {'9169': {'V': '2961', 'TO': '33.14%'}},
#   {'9763': {'V': '302', 'TO': '3.38%'}},
#   {'9822': {'V': '145', 'TO': '1.62%'}}],
#  '3146': [{'9170': {'V': '3616', 'TO': '40.33%'}},
#   {'9171': {'V': '4810', 'TO': '53.65%'}},
#   {'9961': {'V': '264', 'TO': '2.94%'}},
#   {'9823': {'V': '275', 'TO': '3.07%'}}],
#  '3147': [{'9562': {'V': '6369', 'TO': '54.96%'}},
#   {'9174': {'V': '4913', 'TO': '42.39%'}},
#   {'9948': {'V': '307', 'TO': '2.65%'}}],
#  '3148': [{'9175': {'V': '2774', 'TO': '35.83%'}},
#   {'9176': {'V': '4441', 'TO': '57.36%'}},
#   {'9737': {'V': '224', 'TO': '2.89%'}},
#   {'9824': {'V': '303', 'TO': '3.91%'}}],
#  '3149': [{'9177': {'V': '4035', 'TO': '46.11%'}},
#   {'9178': {'V': '4410', 'TO': '50.39%'}},
#   {'9949': {'V': '306', 'TO': '3.50%'}}],
#  '3150': [{'9179': {'V': '3422', 'TO': '60.99%'}},
#   {'9180': {'V': '1846', 'TO': '32.90%'}},
#   {'9749': {'V': '199', 'TO': '3.55%'}},
#   {'9862': {'V': '144', 'TO': '2.57%'}}],
#  '3151': [{'9181': {'V': '4343', 'TO': '40.08%'}},
#   {'9182': {'V': '5829', 'TO': '53.80%'}},
#   {'9780': {'V': '335', 'TO': '3.09%'}},
#   {'9826': {'V': '328', 'TO': '3.03%'}}],
#  '3152': [{'9183': {'V': '5641', 'TO': '51.54%'}},
#   {'9184': {'V': '4628', 'TO': '42.29%'}},
#   {'9746': {'V': '388', 'TO': '3.55%'}},
#   {'9879': {'V': '287', 'TO': '2.62%'}}],
#  '3153': [{'9185': {'V': '4325', 'TO': '88.19%'}},
#   {'9744': {'V': '579', 'TO': '11.81%'}}],
#  '3154': [{'9186': {'V': '5662', 'TO': '56.94%'}},
#   {'9187': {'V': '4282', 'TO': '43.06%'}}],
#  '3155': [{'9189': {'V': '3577', 'TO': '43.07%'}},
#   {'9188': {'V': '4110', 'TO': '49.49%'}},
#   {'9960': {'V': '300', 'TO': '3.61%'}},
#   {'9964': {'V': '318', 'TO': '3.83%'}}],
#  '3156': [{'9190': {'V': '3307', 'TO': '35.30%'}},
#   {'9191': {'V': '5433', 'TO': '58.00%'}},
#   {'9856': {'V': '213', 'TO': '2.27%'}},
#   {'9827': {'V': '248', 'TO': '2.65%'}},
#   {'9897': {'V': '166', 'TO': '1.77%'}}],
#  '3157': [{'9192': {'V': '5508', 'TO': '48.98%'}},
#   {'9193': {'V': '5110', 'TO': '45.44%'}},
#   {'9707': {'V': '368', 'TO': '3.27%'}},
#   {'9937': {'V': '259', 'TO': '2.30%'}}],
#  '3158': [{'9194': {'V': '5956', 'TO': '92.64%'}},
#   {'9781': {'V': '473', 'TO': '7.36%'}}],
#  '3159': [{'9195': {'V': '5219', 'TO': '42.78%'}},
#   {'9196': {'V': '6668', 'TO': '54.66%'}},
#   {'9930': {'V': '313', 'TO': '2.57%'}}],
#  '3160': [{'9197': {'V': '4846', 'TO': '54.11%'}},
#   {'9198': {'V': '3602', 'TO': '40.22%'}},
#   {'9702': {'V': '304', 'TO': '3.39%'}},
#   {'9828': {'V': '204', 'TO': '2.28%'}}],
#  '3161': [{'9574': {'V': '3978', 'TO': '37.83%'}},
#   {'9200': {'V': '6538', 'TO': '62.17%'}}],
#  '3162': [{'9201': {'V': '4079', 'TO': '51.12%'}},
#   {'9202': {'V': '3438', 'TO': '43.08%'}},
#   {'9708': {'V': '230', 'TO': '2.88%'}},
#   {'9829': {'V': '233', 'TO': '2.92%'}}],
#  '3163': [{'9203': {'V': '3608', 'TO': '42.59%'}},
#   {'9204': {'V': '4411', 'TO': '52.07%'}},
#   {'9709': {'V': '211', 'TO': '2.49%'}},
#   {'9830': {'V': '242', 'TO': '2.86%'}}],
#  '3164': [{'9563': {'V': '5454', 'TO': '52.86%'}},
#   {'9207': {'V': '4606', 'TO': '44.64%'}},
#   {'9831': {'V': '257', 'TO': '2.49%'}}],
#  '3165': [{'9505': {'V': '4078', 'TO': '39.63%'}},
#   {'9208': {'V': '5926', 'TO': '57.59%'}},
#   {'9832': {'V': '286', 'TO': '2.78%'}}],
#  '3166': [{'9209': {'V': '5092', 'TO': '40.54%'}},
#   {'9210': {'V': '6871', 'TO': '54.70%'}},
#   {'9880': {'V': '325', 'TO': '2.59%'}},
#   {'9867': {'V': '273', 'TO': '2.17%'}}],
#  '3167': [{'9211': {'V': '3443', 'TO': '35.89%'}},
#   {'9212': {'V': '5868', 'TO': '61.16%'}},
#   {'9754': {'V': '283', 'TO': '2.95%'}}],
#  '3168': [{'9213': {'V': '5665', 'TO': '48.57%'}},
#   {'9214': {'V': '5455', 'TO': '46.77%'}},
#   {'9881': {'V': '212', 'TO': '1.82%'}},
#   {'9755': {'V': '332', 'TO': '2.85%'}}],
#  '3169': [{'9215': {'V': '3388', 'TO': '47.70%'}},
#   {'9216': {'V': '3214', 'TO': '45.25%'}},
#   {'9782': {'V': '273', 'TO': '3.84%'}},
#   {'9882': {'V': '143', 'TO': '2.01%'}},
#   {'9865': {'V': '85', 'TO': '1.20%'}}],
#  '3170': [{'9217': {'V': '5172', 'TO': '41.22%'}},
#   {'9218': {'V': '6900', 'TO': '54.99%'}},
#   {'9884': {'V': '222', 'TO': '1.77%'}},
#   {'9883': {'V': '253', 'TO': '2.02%'}}],
#  '3171': [{'9219': {'V': '3911', 'TO': '39.86%'}},
#   {'9220': {'V': '5301', 'TO': '54.02%'}},
#   {'9783': {'V': '239', 'TO': '2.44%'}},
#   {'9833': {'V': '362', 'TO': '3.69%'}}],
#  '3172': [{'9221': {'V': '2949', 'TO': '28.02%'}},
#   {'9222': {'V': '7261', 'TO': '68.99%'}},
#   {'9886': {'V': '166', 'TO': '1.58%'}},
#   {'9887': {'V': '148', 'TO': '1.41%'}}],
#  '3173': [{'9223': {'V': '4501', 'TO': '38.05%'}},
#   {'9224': {'V': '7085', 'TO': '59.89%'}},
#   {'9888': {'V': '244', 'TO': '2.06%'}}],
#  '3174': [{'9225': {'V': '5901', 'TO': '100.00%'}}],
#  '3175': [{'9226': {'V': '3158', 'TO': '37.11%'}},
#   {'9227': {'V': '5018', 'TO': '58.97%'}},
#   {'9691': {'V': '334', 'TO': '3.92%'}}],
#  '3176': [{'9228': {'V': '3362', 'TO': '74.09%'}},
#   {'9229': {'V': '1072', 'TO': '23.62%'}},
#   {'9684': {'V': '104', 'TO': '2.29%'}}],
#  '3177': [{'9230': {'V': '3828', 'TO': '54.29%'}},
#   {'9231': {'V': '2883', 'TO': '40.89%'}},
#   {'9784': {'V': '198', 'TO': '2.81%'}},
#   {'9685': {'V': '142', 'TO': '2.01%'}}],
#  '3178': [{'9232': {'V': '2877', 'TO': '45.77%'}},
#   {'9233': {'V': '3168', 'TO': '50.40%'}},
#   {'9686': {'V': '241', 'TO': '3.83%'}}],
#  '3179': [{'9234': {'V': '2491', 'TO': '91.11%'}},
#   {'9692': {'V': '243', 'TO': '8.89%'}}],
#  '3180': [{'9301': {'V': '3785', 'TO': '52.19%'}},
#   {'9302': {'V': '3002', 'TO': '41.39%'}},
#   {'9787': {'V': '345', 'TO': '4.76%'}},
#   {'9836': {'V': '121', 'TO': '1.67%'}}],
#  '3182': [{'8971': {'V': '26542', 'TO': '100.00%'}}],
#  '3183': [{'9406': {'V': '18718', 'TO': '100.00%'}}],
#  '3185': [{'8793': {'V': '810', 'TO': '62.02%'}},
#   {'8792': {'V': '496', 'TO': '37.98%'}}],
#  '3186': [{'10038': {'V': '19520', 'TO': '68.80%'}},
#   {'8876': {'V': '8853', 'TO': '31.20%'}}],
#  '3187': [{'8754': {'V': '4195', 'TO': '44.04%'}},
#   {'8755': {'V': '5331', 'TO': '55.96%'}}],
#  '3189': [{'8907': {'V': '1415', 'TO': '94.33%'}},
#   {'10046': {'V': '5', 'TO': '0.33%'}},
#   {'10047': {'V': '80', 'TO': '5.33%'}}],
#  '3190': [{'8765': {'V': '351', 'TO': '48.35%'}},
#   {'8764': {'V': '375', 'TO': '51.65%'}}],
#  '3192': [{'8776': {'V': '964', 'TO': '37.67%'}},
#   {'9968': {'V': '1595', 'TO': '62.33%'}}],
#  '3194': [{'8752': {'V': '9483', 'TO': '70.08%'}},
#   {'8753': {'V': '4048', 'TO': '29.92%'}}],
#  '3195': [{'8734': {'V': '1263', 'TO': '61.85%'}},
#   {'8735': {'V': '779', 'TO': '38.15%'}}],
#  '3196': [{'8808': {'V': '786', 'TO': '44.48%'}},
#   {'8809': {'V': '981', 'TO': '55.52%'}}],
#  '3197': [{'8797': {'V': '1135', 'TO': '51.43%'}},
#   {'10053': {'V': '0', 'TO': '0.00%'}},
#   {'8796': {'V': '1072', 'TO': '48.57%'}}],
#  '3198': [{'8827': {'V': '2140', 'TO': '48.24%'}},
#   {'8828': {'V': '2296', 'TO': '51.76%'}}],
#  '3204': [{'8816': {'V': '1180', 'TO': '48.20%'}},
#   {'8904': {'V': '1268', 'TO': '51.80%'}}],
#  '3205': [{'8778': {'V': '7078', 'TO': '59.29%'}},
#   {'8777': {'V': '4860', 'TO': '40.71%'}}],
#  '3212': [{'8780': {'V': '15540', 'TO': '71.13%'}},
#   {'8779': {'V': '6306', 'TO': '28.87%'}}],
#  '3214': [{'8716': {'V': '1981', 'TO': '86.39%'}},
#   {'8717': {'V': '312', 'TO': '13.61%'}}],
#  '3215': [{'8819': {'V': '3380', 'TO': '46.76%'}},
#   {'8820': {'V': '3848', 'TO': '53.24%'}}],
#  '3217': [{'8801': {'V': '12377', 'TO': '52.37%'}},
#   {'8800': {'V': '11256', 'TO': '47.63%'}}],
#  '3218': [{'8794': {'V': '1332', 'TO': '35.48%'}},
#   {'8795': {'V': '2422', 'TO': '64.52%'}}],
#  '3219': [{'8896': {'V': '2508', 'TO': '41.86%'}},
#   {'8751': {'V': '3194', 'TO': '53.31%'}},
#   {'9967': {'V': '289', 'TO': '4.82%'}}],
#  '3222': [{'8856': {'V': '1118', 'TO': '68.05%'}},
#   {'8855': {'V': '525', 'TO': '31.95%'}}],
#  '3223': [{'8836': {'V': '293', 'TO': '56.56%'}},
#   {'8835': {'V': '225', 'TO': '43.44%'}}],
#  '3224': [{'8872': {'V': '1235', 'TO': '52.26%'}},
#   {'8873': {'V': '1128', 'TO': '47.74%'}}],
#  '3226': [{'8767': {'V': '6708', 'TO': '55.83%'}},
#   {'8766': {'V': '5046', 'TO': '42.00%'}},
#   {'9902': {'V': '260', 'TO': '2.16%'}}],
#  '3228': [{'8726': {'V': '10180', 'TO': '49.91%'}},
#   {'8725': {'V': '10215', 'TO': '50.09%'}}],
#  '3230': [{'9424': {'V': '13185', 'TO': '100.00%'}}],
#  '3233': [{'8756': {'V': '4998', 'TO': '56.62%'}},
#   {'8757': {'V': '3829', 'TO': '43.38%'}}],
#  '3235': [{'8840': {'V': '966', 'TO': '48.40%'}},
#   {'8839': {'V': '1030', 'TO': '51.60%'}}],
#  '3238': [{'8770': {'V': '8987', 'TO': '53.16%'}},
#   {'8771': {'V': '7920', 'TO': '46.84%'}}],
#  '3243': [{'8834': {'V': '2628', 'TO': '56.46%'}},
#   {'8833': {'V': '2027', 'TO': '43.54%'}}],
#  '3245': [{'8891': {'V': '2746', 'TO': '59.62%'}},
#   {'8892': {'V': '1860', 'TO': '40.38%'}}],
#  '3247': [{'8758': {'V': '1920', 'TO': '45.94%'}},
#   {'8759': {'V': '2259', 'TO': '54.06%'}}],
#  '3248': [{'8841': {'V': '1554', 'TO': '75.69%'}},
#   {'8842': {'V': '499', 'TO': '24.31%'}}],
#  '3249': [{'8763': {'V': '2395', 'TO': '43.90%'}},
#   {'8762': {'V': '3060', 'TO': '56.10%'}}],
#  '3252': [{'8879': {'V': '1826', 'TO': '61.21%'}},
#   {'8878': {'V': '1115', 'TO': '37.38%'}},
#   {'9693': {'V': '42', 'TO': '1.41%'}}],
#  '3253': [{'8701': {'V': '1993', 'TO': '52.95%'}},
#   {'8915': {'V': '1705', 'TO': '45.30%'}},
#   {'9926': {'V': '66', 'TO': '1.75%'}}],
#  '3254': [{'8849': {'V': '6837', 'TO': '55.99%'}},
#   {'8850': {'V': '5374', 'TO': '44.01%'}}],
#  '3259': [{'8860': {'V': '975', 'TO': '30.49%'}},
#   {'8859': {'V': '2223', 'TO': '69.51%'}}],
#  '3265': [{'8728': {'V': '2141', 'TO': '46.67%'}},
#   {'8906': {'V': '2447', 'TO': '53.33%'}}],
#  '3266': [{'8727': {'V': '1625', 'TO': '76.80%'}},
#   {'9900': {'V': '491', 'TO': '23.20%'}}],
#  '3269': [{'8713': {'V': '493', 'TO': '46.25%'}},
#   {'8712': {'V': '573', 'TO': '53.75%'}}],
#  '3270': [{'9548': {'V': '211', 'TO': '12.47%'}},
#   {'9550': {'V': '253', 'TO': '14.95%'}},
#   {'9546': {'V': '137', 'TO': '8.10%'}},
#   {'9545': {'V': '382', 'TO': '22.58%'}},
#   {'9547': {'V': '352', 'TO': '20.80%'}},
#   {'9544': {'V': '357', 'TO': '21.10%'}}],
#  '3272': [{'8718': {'V': '7214', 'TO': '53.85%'}},
#   {'8719': {'V': '6182', 'TO': '46.15%'}}],
#  '3276': [{'8823': {'V': '2108', 'TO': '44.49%'}},
#   {'8824': {'V': '2630', 'TO': '55.51%'}}],
#  '3277': [{'8854': {'V': '1002', 'TO': '100.00%'}}],
#  '3280': [{'8898': {'V': '346', 'TO': '65.53%'}},
#   {'8899': {'V': '182', 'TO': '34.47%'}}],
#  '3281': [{'8721': {'V': '21708', 'TO': '80.52%'}},
#   {'8720': {'V': '5253', 'TO': '19.48%'}}],
#  '3283': [{'8736': {'V': '3253', 'TO': '53.39%'}},
#   {'8737': {'V': '2840', 'TO': '46.61%'}}],
#  '3284': [{'8743': {'V': '1358', 'TO': '49.45%'}},
#   {'8742': {'V': '1388', 'TO': '50.55%'}}],
#  '3285': [{'8903': {'V': '435', 'TO': '43.54%'}},
#   {'8782': {'V': '564', 'TO': '56.46%'}}],
#  '3286': [{'8882': {'V': '1484', 'TO': '37.08%'}},
#   {'8883': {'V': '2518', 'TO': '62.92%'}}],
#  '3287': [{'8865': {'V': '8048', 'TO': '48.92%'}},
#   {'8866': {'V': '8403', 'TO': '51.08%'}}],
#  '3288': [{'8802': {'V': '3082', 'TO': '49.13%'}},
#   {'8803': {'V': '3191', 'TO': '50.87%'}}],
#  '3289': [{'8874': {'V': '960', 'TO': '34.57%'}},
#   {'8875': {'V': '1817', 'TO': '65.43%'}}],
#  '3292': [{'9504': {'V': '17894', 'TO': '100.00%'}}],
#  '3293': [{'9905': {'V': '3850', 'TO': '39.60%'}},
#   {'9906': {'V': '5873', 'TO': '60.40%'}}],
#  '3294': [{'8863': {'V': '5567', 'TO': '45.35%'}},
#   {'8864': {'V': '6709', 'TO': '54.65%'}}],
#  '3295': [{'8871': {'V': '8307', 'TO': '46.08%'}},
#   {'8870': {'V': '9198', 'TO': '51.02%'}},
#   {'9904': {'V': '523', 'TO': '2.90%'}}],
#  '3296': [{'8869': {'V': '518', 'TO': '45.00%'}},
#   {'8868': {'V': '633', 'TO': '55.00%'}}],
#  '3297': [{'8710': {'V': '1073', 'TO': '54.25%'}},
#   {'8711': {'V': '905', 'TO': '45.75%'}}],
#  '3298': [{'8733': {'V': '6103', 'TO': '45.39%'}},
#   {'8732': {'V': '7342', 'TO': '54.61%'}}],
#  '3299': [{'8750': {'V': '2170', 'TO': '49.84%'}},
#   {'8749': {'V': '2184', 'TO': '50.16%'}}],
#  '3300': [{'8769': {'V': '498', 'TO': '54.07%'}},
#   {'8768': {'V': '423', 'TO': '45.93%'}}],
#  '3301': [{'8774': {'V': '13431', 'TO': '51.34%'}},
#   {'8775': {'V': '12732', 'TO': '48.66%'}}],
#  '3302': [{'8790': {'V': '1413', 'TO': '46.96%'}},
#   {'8791': {'V': '1596', 'TO': '53.04%'}}],
#  '3303': [{'8867': {'V': '247', 'TO': '83.73%'}},
#   {'9927': {'V': '48', 'TO': '16.27%'}}],
#  '3304': [{'8880': {'V': '8947', 'TO': '66.31%'}},
#   {'8881': {'V': '4545', 'TO': '33.69%'}}],
#  '3306': [{'8731': {'V': '439', 'TO': '44.66%'}},
#   {'8730': {'V': '544', 'TO': '55.34%'}}],
#  '3307': [{'8861': {'V': '1810', 'TO': '50.79%'}},
#   {'8862': {'V': '1754', 'TO': '49.21%'}}],
#  '3309': [{'8772': {'V': '696', 'TO': '42.94%'}},
#   {'8773': {'V': '925', 'TO': '57.06%'}}],
#  '3311': [{'8783': {'V': '3010', 'TO': '49.66%'}},
#   {'8784': {'V': '3051', 'TO': '50.34%'}}],
#  '3313': [{'9572': {'V': '855', 'TO': '42.54%'}},
#   {'8829': {'V': '1155', 'TO': '57.46%'}}],
#  '3314': [{'8821': {'V': '2154', 'TO': '34.41%'}},
#   {'8822': {'V': '4106', 'TO': '65.59%'}}],
#  '3315': [{'8844': {'V': '1257', 'TO': '42.93%'}},
#   {'8845': {'V': '1671', 'TO': '57.07%'}}],
#  '3316': [{'8708': {'V': '2896', 'TO': '49.84%'}},
#   {'9674': {'V': '2341', 'TO': '40.29%'}},
#   {'10045': {'V': '574', 'TO': '9.88%'}}],
#  '3317': [{'8843': {'V': '338', 'TO': '46.05%'}},
#   {'8895': {'V': '396', 'TO': '53.95%'}}],
#  '3318': [{'8798': {'V': '11097', 'TO': '65.38%'}},
#   {'8799': {'V': '5875', 'TO': '34.62%'}}],
#  '3320': [{'8901': {'V': '291', 'TO': '34.85%'}},
#   {'8760': {'V': '544', 'TO': '65.15%'}}],
#  '3321': [{'8815': {'V': '4721', 'TO': '41.56%'}},
#   {'8814': {'V': '6639', 'TO': '58.44%'}}],
#  '3322': [{'9976': {'V': '4551', 'TO': '28.38%'}},
#   {'9977': {'V': '5323', 'TO': '33.20%'}},
#   {'9978': {'V': '6160', 'TO': '38.42%'}}],
#  '3327': [{'9988': {'V': '783', 'TO': '8.90%'}},
#   {'9989': {'V': '878', 'TO': '9.98%'}},
#   {'9990': {'V': '860', 'TO': '9.78%'}},
#   {'9991': {'V': '946', 'TO': '10.76%'}},
#   {'9992': {'V': '729', 'TO': '8.29%'}},
#   {'9993': {'V': '969', 'TO': '11.02%'}},
#   {'9994': {'V': '959', 'TO': '10.90%'}},
#   {'9995': {'V': '819', 'TO': '9.31%'}},
#   {'9996': {'V': '916', 'TO': '10.42%'}},
#   {'9997': {'V': '936', 'TO': '10.64%'}}],
#  '3328': [{'10019': {'V': '958', 'TO': '16.62%'}},
#   {'10020': {'V': '959', 'TO': '16.63%'}},
#   {'10021': {'V': '979', 'TO': '16.98%'}},
#   {'10022': {'V': '914', 'TO': '15.85%'}},
#   {'10023': {'V': '974', 'TO': '16.90%'}},
#   {'10024': {'V': '981', 'TO': '17.02%'}}],
#  '3329': [{'9979': {'V': '932', 'TO': '11.79%'}},
#   {'9980': {'V': '792', 'TO': '10.02%'}},
#   {'9981': {'V': '860', 'TO': '10.88%'}},
#   {'9982': {'V': '836', 'TO': '10.58%'}},
#   {'9983': {'V': '939', 'TO': '11.88%'}},
#   {'9984': {'V': '788', 'TO': '9.97%'}},
#   {'9985': {'V': '925', 'TO': '11.70%'}},
#   {'9986': {'V': '953', 'TO': '12.06%'}},
#   {'9987': {'V': '878', 'TO': '11.11%'}}],
#  '3330': [{'10004': {'V': '1049', 'TO': '17.07%'}},
#   {'10005': {'V': '1108', 'TO': '18.03%'}},
#   {'10006': {'V': '1007', 'TO': '16.38%'}},
#   {'10007': {'V': '997', 'TO': '16.22%'}},
#   {'10008': {'V': '1013', 'TO': '16.48%'}},
#   {'10009': {'V': '972', 'TO': '15.82%'}}],
#  '3331': [{'10010': {'V': '738', 'TO': '9.29%'}},
#   {'10011': {'V': '743', 'TO': '9.35%'}},
#   {'10012': {'V': '962', 'TO': '12.11%'}},
#   {'10013': {'V': '882', 'TO': '11.10%'}},
#   {'10014': {'V': '909', 'TO': '11.44%'}},
#   {'10015': {'V': '917', 'TO': '11.54%'}},
#   {'10016': {'V': '977', 'TO': '12.30%'}},
#   {'10017': {'V': '929', 'TO': '11.69%'}},
#   {'10018': {'V': '889', 'TO': '11.19%'}}],
#  '3332': [{'9998': {'V': '1042', 'TO': '17.14%'}},
#   {'9999': {'V': '987', 'TO': '16.23%'}},
#   {'10000': {'V': '974', 'TO': '16.02%'}},
#   {'10001': {'V': '1048', 'TO': '17.23%'}},
#   {'10002': {'V': '981', 'TO': '16.13%'}},
#   {'10003': {'V': '1049', 'TO': '17.25%'}}],
#  '3333': [{'8813': {'V': '2423', 'TO': '39.75%'}},
#   {'8812': {'V': '3673', 'TO': '60.25%'}}],
#  '3339': [{'9571': {'V': '3033', 'TO': '41.68%'}},
#   {'8890': {'V': '3947', 'TO': '54.25%'}},
#   {'9928': {'V': '296', 'TO': '4.07%'}}],
#  '3340': [{'8714': {'V': '1419', 'TO': '48.23%'}},
#   {'8897': {'V': '1523', 'TO': '51.77%'}}],
#  '3341': [{'8748': {'V': '3999', 'TO': '43.63%'}},
#   {'8911': {'V': '5166', 'TO': '56.37%'}}],
#  '3343': [{'8832': {'V': '1731', 'TO': '36.68%'}},
#   {'8831': {'V': '2988', 'TO': '63.32%'}}],
#  '3344': [{'10028': {'V': '25778', 'TO': '28.46%'}},
#   {'10029': {'V': '23378', 'TO': '25.81%'}},
#   {'10030': {'V': '27904', 'TO': '30.81%'}},
#   {'10037': {'V': '3499', 'TO': '3.86%'}},
#   {'10032': {'V': '5842', 'TO': '6.45%'}},
#   {'10031': {'V': '4165', 'TO': '4.60%'}}],
#  '3345': [{'8811': {'V': '6729', 'TO': '54.38%'}},
#   {'8810': {'V': '5268', 'TO': '42.58%'}},
#   {'9903': {'V': '376', 'TO': '3.04%'}}],
#  '3346': [{'8715': {'V': '4487', 'TO': '54.06%'}},
#   {'9975': {'V': '3813', 'TO': '45.94%'}}],
#  '3347': [{'8908': {'V': '868', 'TO': '48.30%'}},
#   {'8848': {'V': '929', 'TO': '51.70%'}}],
#  '3348': [{'8740': {'V': '348', 'TO': '44.11%'}},
#   {'8741': {'V': '441', 'TO': '55.89%'}}],
#  '3349': [{'8910': {'V': '1977', 'TO': '51.55%'}},
#   {'8761': {'V': '1858', 'TO': '48.45%'}}],
#  '3350': [{'8744': {'V': '595', 'TO': '71.51%'}},
#   {'8745': {'V': '237', 'TO': '28.49%'}}],
#  '3351': [{'8722': {'V': '493', 'TO': '48.86%'}},
#   {'8723': {'V': '516', 'TO': '51.14%'}}],
#  '3355': [{'8887': {'V': '2647', 'TO': '54.66%'}},
#   {'8888': {'V': '2196', 'TO': '45.34%'}}],
#  '3356': [{'8885': {'V': '9856', 'TO': '72.95%'}},
#   {'8886': {'V': '3655', 'TO': '27.05%'}}],
#  '3357': [{'8914': {'V': '435', 'TO': '51.79%'}},
#   {'8781': {'V': '405', 'TO': '48.21%'}}],
#  '3358': [{'8900': {'V': '869', 'TO': '38.23%'}},
#   {'8729': {'V': '1404', 'TO': '61.77%'}}],
#  '3361': [{'8838': {'V': '1054', 'TO': '56.51%'}},
#   {'8837': {'V': '811', 'TO': '43.49%'}}],
#  '3362': [{'9957': {'V': '618', 'TO': '51.93%'}},
#   {'8909': {'V': '572', 'TO': '48.07%'}}],
#  '3363': [{'8789': {'V': '6423', 'TO': '76.38%'}},
#   {'8912': {'V': '1986', 'TO': '23.62%'}}],
#  '3365': [{'8788': {'V': '4953', 'TO': '51.50%'}},
#   {'8787': {'V': '4664', 'TO': '48.50%'}}],
#  '3366': [{'8857': {'V': '2850', 'TO': '47.26%'}},
#   {'8858': {'V': '3180', 'TO': '52.74%'}}],
#  '3367': [{'8905': {'V': '540', 'TO': '48.39%'}},
#   {'8724': {'V': '576', 'TO': '51.61%'}}],
#  '3370': [{'8804': {'V': '4862', 'TO': '47.86%'}},
#   {'8805': {'V': '5296', 'TO': '52.14%'}}],
#  '3371': [{'8747': {'V': '11272', 'TO': '55.41%'}},
#   {'8746': {'V': '8626', 'TO': '42.40%'}},
#   {'9901': {'V': '444', 'TO': '2.18%'}}],
#  '3372': [{'8807': {'V': '3864', 'TO': '40.82%'}},
#   {'8806': {'V': '5601', 'TO': '59.18%'}}],
#  '3373': [{'8818': {'V': '19413', 'TO': '62.62%'}},
#   {'8817': {'V': '11586', 'TO': '37.38%'}}],
#  '3376': [{'9958': {'V': '1366', 'TO': '32.84%'}},
#   {'8826': {'V': '2793', 'TO': '67.16%'}}],
#  '3377': [{'8846': {'V': '6724', 'TO': '41.64%'}},
#   {'8847': {'V': '9423', 'TO': '58.36%'}}],
#  '3378': [{'8851': {'V': '1482', 'TO': '35.54%'}},
#   {'8852': {'V': '2688', 'TO': '64.46%'}}],
#  '3380': [{'8884': {'V': '4223', 'TO': '66.62%'}},
#   {'8913': {'V': '1724', 'TO': '27.20%'}},
#   {'9503': {'V': '392', 'TO': '6.18%'}}],
#  '3382': [{'8893': {'V': '1811', 'TO': '49.88%'}},
#   {'8894': {'V': '1820', 'TO': '50.12%'}}],
#  '3383': [{'10036': {'V': '1758', 'TO': '45.31%'}},
#   {'10035': {'V': '1937', 'TO': '49.92%'}},
#   {'9946': {'V': '185', 'TO': '4.77%'}}]}

# %%
def get_contest_table(edata, contest_id):
    
    ret = pd.DataFrame.from_dict(
        dictify(edata["election_data"]["stateVotes"][contest_id]),
        orient="index")
    
    ret["stateVotesId"] = contest_id
    
    return ret

get_contest_table(general_2018, '2879')
# Out:
#         V      TO stateVotesId
# 8785  838  58.89%         2879
# 8786  585  41.11%         2879

# %%
# Make a spreadsheet!
def make_sheet(e_data):

    """ Make a row for each candidate that includes:
            name
            office
            district
            total votes
            party
    """
    
    # each of these will get its own dataframe
    # with a candidate, party, votes, and pct
    stateVotes = e_data["election_data"]["stateVotes"]
    
    ret = pd.concat(list(map(lambda x: get_contest_table(e_data, x), 
                      list(stateVotes.keys()))))
    
    def get_cand_party_name_wrapper(x):
        return get_candidate_party_name(e_data, x)
    
    def make_row(e_data, row):
        row["candidate"] = get_candidate_name(e_data, row["index"])
        row["party"] = get_candidate_party_name(e_data, row["index"])
        row["office"] = get_office(e_data, row["stateVotesId"])["NM"]
        row["district"] = get_office(e_data, row["stateVotesId"])["D"]
        return row

    ret = ret.reset_index().apply(lambda x: make_row(e_data, x), axis=1)

    ret["electionID"] = e_data["lookup_data"]["election"]["ID"]
    ret["electionDescription"] = e_data["lookup_data"]["election"]["DNM"]
    ret["electionDate"] = e_data["lookup_data"]["election"]["DT"]
    
    return ret


#general_2018_sheet = make_sheet(get_election_data(31))
general_2018_sheet = make_sheet(general_2018)

# %%
general_2018_sheet.head()
# Out:
#    index      V      TO stateVotesId                       candidate  \
# 0   8785    838  58.89%         2879                Dianne F Ahlberg
# 1   8786    585  41.11%         2879                     Judy Davies
# 2   8738   3702  52.33%         2883                Dorothy A Mrowka
# 3   8739   3373  47.67%         2883                 Linda M Grzeika
# 4  10025  17861   1.27%         2901  Ned Lamont and Susan Bysiewicz
#
#                     party                            office district  \
# 0        Democratic Party               Registrar of Voters        0
# 1        Republican Party               Registrar of Voters        0
# 2        Democratic Party               Registrar of Voters        0
# 3        Republican Party               Registrar of Voters        0
# 4  Working Families Party  Governor and Lieutenant Governor        0
#
#   electionID           electionDescription electionDate
# 0         31  November 2018 State Election   11/06/2018
# 1         31  November 2018 State Election   11/06/2018
# 2         31  November 2018 State Election   11/06/2018
# 3         31  November 2018 State Election   11/06/2018
# 4         31  November 2018 State Election   11/06/2018

# %%
# Make separate spreadsheets

# %%
import re
def fname(election_id, office, district):
    ret = [election_id, re.sub("\W", "-", office.strip().lower())]
    if district is not None:
        ret[1] += "-%s" % district.strip().lower()
    return "%s.csv" % "/".join(ret)

# %%
def get_subsheet(election_sheet, stateVotesId):
    subframe = election_sheet[election_sheet["stateVotesId"] == str(stateVotesId)]
    
    assert len(subframe["office"].unique()) == 1
    assert len(subframe["district"].unique()) == 1

    office = list(subframe["office"].unique())[0]
    district = list(subframe["district"].unique())[0]
    
    return {
        "df":subframe,
        "office":office,
        "district":district,
        "fname":fname(election_sheet["electionID"].unique()[0], office, district)
    }

get_subsheet(general_2018_sheet, "2879")
# Out:
# {'df':   index    V      TO stateVotesId         candidate             party  \
#  0  8785  838  58.89%         2879  Dianne F Ahlberg  Democratic Party
#  1  8786  585  41.11%         2879       Judy Davies  Republican Party
#
#                  office district electionID           electionDescription  \
#  0  Registrar of Voters        0         31  November 2018 State Election
#  1  Registrar of Voters        0         31  November 2018 State Election
#
#    electionDate
#  0   11/06/2018
#  1   11/06/2018  ,
#  'office': 'Registrar of Voters',
#  'district': '0',
#  'fname': '31/registrar-of-voters-0.csv'}

# %%
# !mkdir -p "out"

# %%
general_2018_sheet.head()
# Out:
#    index      V      TO stateVotesId                       candidate  \
# 0   8785    838  58.89%         2879                Dianne F Ahlberg
# 1   8786    585  41.11%         2879                     Judy Davies
# 2   8738   3702  52.33%         2883                Dorothy A Mrowka
# 3   8739   3373  47.67%         2883                 Linda M Grzeika
# 4  10025  17861   1.27%         2901  Ned Lamont and Susan Bysiewicz
#
#                     party                            office district  \
# 0        Democratic Party               Registrar of Voters        0
# 1        Republican Party               Registrar of Voters        0
# 2        Democratic Party               Registrar of Voters        0
# 3        Republican Party               Registrar of Voters        0
# 4  Working Families Party  Governor and Lieutenant Governor        0
#
#   electionID           electionDescription electionDate
# 0         31  November 2018 State Election   11/06/2018
# 1         31  November 2018 State Election   11/06/2018
# 2         31  November 2018 State Election   11/06/2018
# 3         31  November 2018 State Election   11/06/2018
# 4         31  November 2018 State Election   11/06/2018

# %%
os.path.split('out/registrar-of-voters/0.csv')
# Out:
# ('out/registrar-of-voters', '0.csv')

# %%
import subprocess

for voteId in general_2018_sheet["stateVotesId"].unique().tolist():
    sub = get_subsheet(general_2018_sheet, voteId)
    dst = os.path.join("out", sub["fname"])
    subprocess.call(["mkdir","-p", os.path.split(dst)[0]])
    sub["df"].to_csv(dst)

# %%
sub
# Out:
# {'df':       index     V      TO stateVotesId          candidate  \
#  1009  10035  1937  49.92%         3383  Kristi L Sogofsky
#  1010  10036  1758  45.31%         3383         Ira Kaplan
#  1011   9946   185   4.77%         3383       Anne Manusky
#
#                        party     office district electionID  \
#  1009       Republican Party  Selectman        0         31
#  1010       Democratic Party  Selectman        0         31
#  1011  Petitioning Candidate  Selectman        0         31
#
#                 electionDescription electionDate
#  1009  November 2018 State Election   11/06/2018
#  1010  November 2018 State Election   11/06/2018
#  1011  November 2018 State Election   11/06/2018  ,
#  'office': 'Selectman',
#  'district': '0',
#  'fname': '31/selectman-0.csv'}

# %%
# !AWS_PROFILE=political-guide aws s3 sync out s3://polguide-election-results
